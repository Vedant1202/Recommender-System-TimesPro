# %%
import pandas as pd

# %%
df = pd.read_csv('20191212075617.sqliteonline.com.csv')

# %%
df.head(10)
# Out:
#    w_id STUDENT_UID                   STUDENT_NAME STUDENT_Password  \
# 0   1.0     2018844                   AMITA TIWARI            12345
# 1   NaN       TLPWE                              A     Tue-Wed-Thur
# 2   2.0     2018850              ANUSHA VIJAYKANTH            12345
# 3   NaN       TLPWE                              A     Tue-Wed-Thur
# 4   3.0     2018851                         ARCHNA            12345
# 5   NaN   New Delhi  TSW - NEW DELHI - NEHRU PLACE             IIMC
# 6   NaN       TLPWE                              A     Tue-Wed-Thur
# 7   4.0     2018855                      B SOWMYAA            12345
# 8   NaN       TLPWE                              A     Tue-Wed-Thur
# 9   5.0     2018861               CHUMKI MUKHERJEE            12345
#
#   STUDENT_city                     STUDENT_Centre STUDENT_Institute  \
# 0      Kolkata     TSW - Kolkata - Salt Lake City              IIMC
# 1    6:45-9:45                                NaN               NaN
# ...

# %%
df2 = pd.read_csv('20191212074932.sqliteonline.com.csv')

# %%
df2.head(10)
# Out:
#    id       City Cityalias1 Cityalias2 Cityalias3 Cityalias4 Cityalias5  \
# 0   0  BANGALORE  bangaluru        NaN        NaN        NaN        NaN
# 1   1  BANGALORE  bangaluru        NaN        NaN        NaN        NaN
# 2   2  BANGALORE  bangaluru        NaN        NaN        NaN        NaN
# 3   3    Calicut  Kozhikode        NaN        NaN        NaN        NaN
# 4   4    Chennai     madras        NaN        NaN        NaN        NaN
# 5   5    Gurgaon   Gurugram    Gudgaon        NaN        NaN        NaN
# 6   6    Gurgaon   Gurugram    Gudgaon        NaN        NaN        NaN
# 7   7  Hyderabad        HYD        NaN        NaN        NaN        NaN
# 8   8  Hyderabad        HYD  telangana        NaN        NaN        NaN
# 9   9  Hyderabad        HYD  telangana        NaN        NaN        NaN
#
#                               Center     centeralias1      centeralias2  \
# 0    TSW - Bangalore - Sarjapur Road    Sarjapur Road          Sarjapur
# ...
