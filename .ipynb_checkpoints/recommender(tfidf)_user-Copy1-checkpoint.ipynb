# %%
import pandas as pd
import numpy as np

# %%
import pymysql

# %%
from rake_nltk import Rake
from random import randint

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel

# %%
connection = pymysql.connect(host='localhost',
                             user='root',
                             password='',
                             db='times_shiksha2')

df = pd.read_sql('SELECT * FROM mdl_course', con=connection)

# %%
df = df.copy()[['id', 'fullname', 'summary']]

# %%
summarylist = []
for line in df['summary']:
    line = line.replace('\n','').replace('\r','').replace('\t','').lower()
    summarylist.append(line)
    
df['summary'] = summarylist

# %%
df['fullname'] = df['fullname'].str.lower()

# %%
df.head()
# Out:
#    id              fullname                                            summary
# 0   1          timesshiksha                             a great place to start
# 1   6        microsoft word  microsoft word is agraphicalwordprocessing pro...
# 2   7       microsoft excel  microsoftexcelis aspreadsheet programusedto st...
# 3   8  microsoft powerpoint  power pointis apresentation program softwarepa...
# 4  12     powerful speaking  powerful speakingis an invaluable set of skill...

# %%
df.isna().sum()
# Out:
# id          0
# fullname    0
# summary     0
# dtype: int64

# %%
def concatenate_list(list):
    result= ''
    for element in list:
        result += ' ' + str(element)
    return result

# %%
# initializing the new column
df['Key_words'] = ""

for index, row in df.iterrows():
    plot = str(row['summary'])
    
    # instantiating Rake, by default it uses english stopwords from NLTK
    # and discards all puntuation characters as well
    r = Rake()

    # extracting the words by passing the text
    r.extract_keywords_from_text(plot)

    # getting the dictionary whith key words as keys and their scores as values
    key_words_dict_scores = r.get_word_degrees()
    
    # assigning the key words to the new column for the corresponding movie
    row['Key_words'] = concatenate_list(list(key_words_dict_scores.keys()))
    df['Key_words'][index] = row['Key_words'].strip()
    
# dropping the Plot column
df.drop(columns = ['summary'], inplace = True)
# Out:
# C:\Users\mumtl5\AppData\Local\Continuum\anaconda3\envs\recommender\lib\site-packages\ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
tf = TfidfVectorizer(analyzer='word', ngram_range=(1, 3), min_df=0, stop_words='english')

# %%
tfidf_matrix = tf.fit_transform(df['Key_words'])

# %%
df.head()
# Out:
#    id              fullname                                          Key_words
# 0   1          timesshiksha                                  great place start
# 1   6        microsoft word  itspurpose helpful tools type save documents l...
# 2   7       microsoft excel  favourite feature rowssome features1 excel for...
# 3   8  microsoft powerpoint  display information inserted andformatted allo...
# 4  12     powerful speaking  thispowerful speakingcourse should1focus peopl...

# %%
cosine_similarities = linear_kernel(tfidf_matrix, tfidf_matrix) 
results = {}
for idx, row in df.iterrows():
    similar_indices = cosine_similarities[idx].argsort()[:-100:-1] 
    similar_items = [(cosine_similarities[idx][i], df['fullname'][i]) for i in similar_indices] 
    results[row['fullname']] = {'id': row['id'], 'similarities': similar_items[1:]}

# %%
results
# Out:
# {'timesshiksha': {'id': 1,
#   'similarities': [(0.03108797179007013, 'microsoft powerpoint'),
#    (0.0, 'adwords essential training'),
#    (0.0, 'microsoft dynamics crm customization config'),
#    (0.0, 'time management'),
#    (0.0, 'project management fundamentals'),
#    (0.0, 'yammer 2018 essential training'),
#    (0.0, 'email communication'),
#    (0.0, 'google drive essential training tutorial'),
#    (0.0, 'analytics essential training'),
#    (0.0, 'creating a business plan'),
#    (0.0, 'sales secrets for small business'),
#    (0.0, 'cbt nuggets microsoft sharepoint'),
#    (0.0, 'cbt nuggets - mpls fundamentals'),
#    (0.0, 'cbt nuggets cloud computing'),
#    (0.0, 'powerful speaking'),
#    (0.0, 'microsoft excel'),
#    (0.0, 'microsoft word'),
#    (0.0, 'google cloud platform fundamentals'),
#    (0.0, 'cloud computing'),
#    (0.0, 'html'),
#    (0.0, 'microsoft office 365'),
#    (0.0, 'tpl - learning management system'),
#    (0.0, 'stress management at workplace'),
#    (0.0, 'campusnexus crm'),
#    (0.0, 'leadership'),
#    (0.0, 'helpful technique while operating computers'),
#    (0.0, 'microsoft onedrive'),
#    (0.0, 'microsoft sharepoint'),
#    (0.0, 'excel 2016 pivot tables in depth'),
#    (0.0, 'techniques and concepts of big data'),
#    (0.0, 'complete beginners introduction to sql'),
#    (0.0, 'sample'),
#    (0.0, 'et cases'),
#    (0.0, 'strategy - innovation'),
#    (0.0, 'hrm'),
#    (0.0, 'analytics'),
#    (0.0, 'business-intellegence features in depth'),
#    (0.0, 'marketing with facebook and twitter')]},
#  'microsoft word': {'id': 6,
#   'similarities': [(0.02127814188250297, 'microsoft powerpoint'),
#    (0.017865862864608957, 'microsoft office 365'),
#    (0.01778329404525629, 'microsoft dynamics crm customization config'),
#    (0.01713636386917567, 'yammer 2018 essential training'),
#    (0.011838091921246225, 'microsoft sharepoint'),
#    (0.010954319869803079, 'google drive essential training tutorial'),
#    (0.00784549323917507, 'email communication'),
#    (0.0, 'adwords essential training'),
#    (0.0, 'time management'),
#    (0.0, 'project management fundamentals'),
#    (0.0, 'analytics essential training'),
#    (0.0, 'cloud computing'),
#    (0.0, 'creating a business plan'),
#    (0.0, 'google cloud platform fundamentals'),
#    (0.0, 'cbt nuggets - mpls fundamentals'),
#    (0.0, 'cbt nuggets cloud computing'),
#    (0.0, 'powerful speaking'),
#    (0.0, 'microsoft excel'),
#    (0.0, 'cbt nuggets microsoft sharepoint'),
#    (0.0, 'marketing with facebook and twitter'),
#    (0.0, 'sales secrets for small business'),
#    (0.0, 'html'),
#    (0.0, 'tpl - learning management system'),
#    (0.0, 'stress management at workplace'),
#    (0.0, 'campusnexus crm'),
#    (0.0, 'leadership'),
#    (0.0, 'helpful technique while operating computers'),
#    (0.0, 'microsoft onedrive'),
#    (0.0, 'excel 2016 pivot tables in depth'),
#    (0.0, 'complete beginners introduction to sql'),
#    (0.0, 'sample'),
#    (0.0, 'et cases'),
#    (0.0, 'strategy - innovation'),
#    (0.0, 'hrm'),
#    (0.0, 'analytics'),
#    (0.0, 'business-intellegence features in depth'),
#    (0.0, 'techniques and concepts of big data'),
#    (0.0, 'timesshiksha')]},
#  'microsoft excel': {'id': 7,
#   'similarities': [(0.016785065984257837, 'excel 2016 pivot tables in depth'),
#    (0.0124404182327976, 'email communication'),
#    (0.010956826818232531, 'microsoft sharepoint'),
#    (0.010441302062703255, 'microsoft office 365'),
#    (0.008579125199100479, 'google drive essential training tutorial'),
#    (0.008343462238635394, 'microsoft onedrive'),
#    (0.006767407101504312, 'microsoft dynamics crm customization config'),
#    (0.006553425007093747, 'complete beginners introduction to sql'),
#    (0.006168385569507459, 'business-intellegence features in depth'),
#    (0.0, 'cbt nuggets cloud computing'),
#    (0.0, 'powerful speaking'),
#    (0.0, 'time management'),
#    (0.0, 'cbt nuggets - mpls fundamentals'),
#    (0.0, 'cbt nuggets microsoft sharepoint'),
#    (0.0, 'creating a business plan'),
#    (0.0, 'adwords essential training'),
#    (0.0, 'analytics essential training'),
#    (0.0, 'microsoft powerpoint'),
#    (0.0, 'microsoft word'),
#    (0.0, 'yammer 2018 essential training'),
#    (0.0, 'project management fundamentals'),
#    (0.0, 'cloud computing'),
#    (0.0, 'marketing with facebook and twitter'),
#    (0.0, 'google cloud platform fundamentals'),
#    (0.0, 'sales secrets for small business'),
#    (0.0, 'html'),
#    (0.0, 'techniques and concepts of big data'),
#    (0.0, 'analytics'),
#    (0.0, 'hrm'),
#    (0.0, 'strategy - innovation'),
#    (0.0, 'et cases'),
#    (0.0, 'sample'),
#    (0.0, 'helpful technique while operating computers'),
#    (0.0, 'leadership'),
#    (0.0, 'campusnexus crm'),
#    (0.0, 'stress management at workplace'),
#    (0.0, 'tpl - learning management system'),
#    (0.0, 'timesshiksha')]},
#  'microsoft powerpoint': {'id': 8,
#   'similarities': [(0.03108797179007013, 'timesshiksha'),
#    (0.021660635907515383, 'microsoft dynamics crm customization config'),
#    (0.02127814188250297, 'microsoft word'),
#    (0.019157505044844696, 'yammer 2018 essential training'),
#    (0.01609733997202804, 'excel 2016 pivot tables in depth'),
#    (0.013671243818585678, 'complete beginners introduction to sql'),
#    (0.012868004592484016, 'business-intellegence features in depth'),
#    (0.009391326004291317, 'time management'),
#    (0.008594931151104705, 'adwords essential training'),
#    (0.007952176189963365, 'microsoft sharepoint'),
#    (0.00794817393062047, 'marketing with facebook and twitter'),
#    (0.0073585069473527335, 'google drive essential training tutorial'),
#    (0.006961866658890943, 'powerful speaking'),
#    (0.0062283074181738955, 'email communication'),
#    (0.005733484993989474, 'html'),
#    (0.0052274479744645035, 'microsoft office 365'),
#    (0.005109689380715637, 'techniques and concepts of big data'),
#    (0.0, 'sample'),
#    (0.0, 'analytics essential training'),
#    (0.0, 'tpl - learning management system'),
#    (0.0, 'microsoft excel'),
#    (0.0, 'stress management at workplace'),
#    (0.0, 'cbt nuggets cloud computing'),
#    (0.0, 'cbt nuggets - mpls fundamentals'),
#    (0.0, 'cbt nuggets microsoft sharepoint'),
#    (0.0, 'creating a business plan'),
#    (0.0, 'campusnexus crm'),
#    (0.0, 'leadership'),
#    (0.0, 'et cases'),
#    (0.0, 'project management fundamentals'),
#    (0.0, 'helpful technique while operating computers'),
#    (0.0, 'microsoft onedrive'),
#    (0.0, 'google cloud platform fundamentals'),
#    (0.0, 'sales secrets for small business'),
#    (0.0, 'analytics'),
#    (0.0, 'hrm'),
#    (0.0, 'strategy - innovation'),
#    (0.0, 'cloud computing')]},
#  'powerful speaking': {'id': 12,
#   'similarities': [(0.011344940233265304, 'analytics essential training'),
#    (0.011260136305227993, 'yammer 2018 essential training'),
#    (0.010550156864895957, 'microsoft dynamics crm customization config'),
#    (0.009804232396579958, 'sales secrets for small business'),
#    (0.009411423986220894, 'microsoft sharepoint'),
#    (0.006961866658890943, 'microsoft powerpoint'),
#    (0.0, 'cloud computing'),
#    (0.0, 'time management'),
#    (0.0, 'project management fundamentals'),
#    (0.0, 'email communication'),
#    (0.0, 'google drive essential training tutorial'),
#    (0.0, 'creating a business plan'),
#    (0.0, 'adwords essential training'),
#    (0.0, 'cbt nuggets microsoft sharepoint'),
#    (0.0, 'cbt nuggets - mpls fundamentals'),
#    (0.0, 'cbt nuggets cloud computing'),
#    (0.0, 'microsoft excel'),
#    (0.0, 'microsoft word'),
#    (0.0, 'google cloud platform fundamentals'),
#    (0.0, 'marketing with facebook and twitter'),
#    (0.0, 'html'),
#    (0.0, 'techniques and concepts of big data'),
#    (0.0, 'tpl - learning management system'),
#    (0.0, 'stress management at workplace'),
#    (0.0, 'campusnexus crm'),
#    (0.0, 'leadership'),
#    (0.0, 'helpful technique while operating computers'),
#    (0.0, 'microsoft onedrive'),
#    (0.0, 'microsoft office 365'),
#    (0.0, 'excel 2016 pivot tables in depth'),
#    (0.0, 'complete beginners introduction to sql'),
#    (0.0, 'sample'),
#    (0.0, 'et cases'),
#    (0.0, 'strategy - innovation'),
#    (0.0, 'hrm'),
#    (0.0, 'analytics'),
#    (0.0, 'business-intellegence features in depth'),
#    (0.0, 'timesshiksha')]},
#  'cbt nuggets cloud computing': {'id': 14,
#   'similarities': [(0.0, 'adwords essential training'),
#    (0.0, 'microsoft dynamics crm customization config'),
#    (0.0, 'time management'),
#    (0.0, 'project management fundamentals'),
#    (0.0, 'yammer 2018 essential training'),
#    (0.0, 'email communication'),
#    (0.0, 'google drive essential training tutorial'),
#    (0.0, 'analytics essential training'),
#    (0.0, 'creating a business plan'),
#    (0.0, 'sales secrets for small business'),
#    (0.0, 'cbt nuggets microsoft sharepoint'),
#    (0.0, 'cbt nuggets - mpls fundamentals'),
#    (0.0, 'cbt nuggets cloud computing'),
#    (0.0, 'powerful speaking'),
#    (0.0, 'microsoft powerpoint'),
#    (0.0, 'microsoft excel'),
#    (0.0, 'microsoft word'),
#    (0.0, 'google cloud platform fundamentals'),
#    (0.0, 'marketing with facebook and twitter'),
#    (0.0, 'html'),
#    (0.0, 'microsoft office 365'),
#    (0.0, 'tpl - learning management system'),
#    (0.0, 'stress management at workplace'),
#    (0.0, 'campusnexus crm'),
#    (0.0, 'leadership'),
#    (0.0, 'helpful technique while operating computers'),
#    (0.0, 'microsoft onedrive'),
#    (0.0, 'microsoft sharepoint'),
#    (0.0, 'excel 2016 pivot tables in depth'),
#    (0.0, 'techniques and concepts of big data'),
#    (0.0, 'complete beginners introduction to sql'),
#    (0.0, 'sample'),
#    (0.0, 'et cases'),
#    (0.0, 'strategy - innovation'),
#    (0.0, 'hrm'),
#    (0.0, 'analytics'),
#    (0.0, 'business-intellegence features in depth'),
#    (0.0, 'timesshiksha')]},
#  'cbt nuggets - mpls fundamentals': {'id': 15,
#   'similarities': [(0.0, 'adwords essential training'),
#    (0.0, 'microsoft dynamics crm customization config'),
#    (0.0, 'time management'),
#    (0.0, 'project management fundamentals'),
#    (0.0, 'yammer 2018 essential training'),
#    (0.0, 'email communication'),
#    (0.0, 'google drive essential training tutorial'),
#    (0.0, 'analytics essential training'),
#    (0.0, 'creating a business plan'),
#    (0.0, 'sales secrets for small business'),
#    (0.0, 'cbt nuggets microsoft sharepoint'),
#    (0.0, 'cbt nuggets - mpls fundamentals'),
#    (0.0, 'cbt nuggets cloud computing'),
#    (0.0, 'powerful speaking'),
#    (0.0, 'microsoft powerpoint'),
#    (0.0, 'microsoft excel'),
#    (0.0, 'microsoft word'),
#    (0.0, 'google cloud platform fundamentals'),
#    (0.0, 'marketing with facebook and twitter'),
#    (0.0, 'html'),
#    (0.0, 'microsoft office 365'),
#    (0.0, 'tpl - learning management system'),
#    (0.0, 'stress management at workplace'),
#    (0.0, 'campusnexus crm'),
#    (0.0, 'leadership'),
#    (0.0, 'helpful technique while operating computers'),
#    (0.0, 'microsoft onedrive'),
#    (0.0, 'microsoft sharepoint'),
#    (0.0, 'excel 2016 pivot tables in depth'),
#    (0.0, 'techniques and concepts of big data'),
#    (0.0, 'complete beginners introduction to sql'),
#    (0.0, 'sample'),
#    (0.0, 'et cases'),
#    (0.0, 'strategy - innovation'),
#    (0.0, 'hrm'),
#    (0.0, 'analytics'),
#    (0.0, 'business-intellegence features in depth'),
#    (0.0, 'timesshiksha')]},
#  'cbt nuggets microsoft sharepoint': {'id': 16,
#   'similarities': [(0.0, 'adwords essential training'),
#    (0.0, 'microsoft dynamics crm customization config'),
#    (0.0, 'time management'),
#    (0.0, 'project management fundamentals'),
#    (0.0, 'yammer 2018 essential training'),
#    (0.0, 'email communication'),
#    (0.0, 'google drive essential training tutorial'),
#    (0.0, 'analytics essential training'),
#    (0.0, 'creating a business plan'),
#    (0.0, 'sales secrets for small business'),
#    (0.0, 'cbt nuggets microsoft sharepoint'),
#    (0.0, 'cbt nuggets - mpls fundamentals'),
#    (0.0, 'cbt nuggets cloud computing'),
#    (0.0, 'powerful speaking'),
#    (0.0, 'microsoft powerpoint'),
#    (0.0, 'microsoft excel'),
#    (0.0, 'microsoft word'),
#    (0.0, 'google cloud platform fundamentals'),
#    (0.0, 'marketing with facebook and twitter'),
#    (0.0, 'html'),
#    (0.0, 'microsoft office 365'),
#    (0.0, 'tpl - learning management system'),
#    (0.0, 'stress management at workplace'),
#    (0.0, 'campusnexus crm'),
#    (0.0, 'leadership'),
#    (0.0, 'helpful technique while operating computers'),
#    (0.0, 'microsoft onedrive'),
#    (0.0, 'microsoft sharepoint'),
#    (0.0, 'excel 2016 pivot tables in depth'),
#    (0.0, 'techniques and concepts of big data'),
#    (0.0, 'complete beginners introduction to sql'),
#    (0.0, 'sample'),
#    (0.0, 'et cases'),
#    (0.0, 'strategy - innovation'),
#    (0.0, 'hrm'),
#    (0.0, 'analytics'),
#    (0.0, 'business-intellegence features in depth'),
#    (0.0, 'timesshiksha')]},
#  'creating a business plan': {'id': 18,
#   'similarities': [(0.02647230395290067,
#     'marketing with facebook and twitter'),
#    (0.02180262192988628, 'microsoft dynamics crm customization config'),
#    (0.015401507971672149, 'sales secrets for small business'),
#    (0.008423218296821636, 'business-intellegence features in depth'),
#    (0.008095618556061801, 'stress management at workplace'),
#    (0.007200180450852355, 'techniques and concepts of big data'),
#    (0.007152740148527754, 'google drive essential training tutorial'),
#    (0.007100236990320576, 'complete beginners introduction to sql'),
#    (0.0, 'cbt nuggets microsoft sharepoint'),
#    (0.0, 'cbt nuggets - mpls fundamentals'),
#    (0.0, 'cbt nuggets cloud computing'),
#    (0.0, 'adwords essential training'),
#    (0.0, 'analytics essential training'),
#    (0.0, 'powerful speaking'),
#    (0.0, 'email communication'),
#    (0.0, 'yammer 2018 essential training'),
#    (0.0, 'microsoft powerpoint'),
#    (0.0, 'microsoft excel'),
#    (0.0, 'project management fundamentals'),
#    (0.0, 'microsoft word'),
#    (0.0, 'time management'),
#    (0.0, 'cloud computing'),
#    (0.0, 'google cloud platform fundamentals'),
#    (0.0, 'html'),
#    (0.0, 'analytics'),
#    (0.0, 'hrm'),
#    (0.0, 'strategy - innovation'),
#    (0.0, 'et cases'),
#    (0.0, 'sample'),
#    (0.0, 'excel 2016 pivot tables in depth'),
#    (0.0, 'microsoft office 365'),
#    (0.0, 'microsoft sharepoint'),
#    (0.0, 'microsoft onedrive'),
#    (0.0, 'helpful technique while operating computers'),
#    (0.0, 'leadership'),
#    (0.0, 'campusnexus crm'),
#    (0.0, 'tpl - learning management system'),
#    (0.0, 'timesshiksha')]},
#  'adwords essential training': {'id': 19,
#   'similarities': [(0.03322282414315095, 'html'),
#    (0.02746619832949375, 'analytics essential training'),
#    (0.01700748313126698, 'google drive essential training tutorial'),
#    (0.009824760196299064, 'time management'),
#    (0.009705381638094415, 'email communication'),
#    (0.00866641125700674, 'sales secrets for small business'),
#    (0.008653767852678577, 'yammer 2018 essential training'),
#    (0.008594931151104705, 'microsoft powerpoint'),
#    (0.0, 'google cloud platform fundamentals'),
#    (0.0, 'microsoft dynamics crm customization config'),
#    (0.0, 'project management fundamentals'),
#    (0.0, 'microsoft word'),
#    (0.0, 'microsoft excel'),
#    (0.0, 'creating a business plan'),
#    (0.0, 'cbt nuggets microsoft sharepoint'),
#    (0.0, 'cbt nuggets - mpls fundamentals'),
#    (0.0, 'cbt nuggets cloud computing'),
#    (0.0, 'powerful speaking'),
#    (0.0, 'cloud computing'),
#    (0.0, 'marketing with facebook and twitter'),
#    (0.0, 'techniques and concepts of big data'),
#    (0.0, 'business-intellegence features in depth'),
#    (0.0, 'tpl - learning management system'),
#    (0.0, 'stress management at workplace'),
#    (0.0, 'campusnexus crm'),
#    (0.0, 'leadership'),
#    (0.0, 'helpful technique while operating computers'),
#    (0.0, 'microsoft onedrive'),
#    (0.0, 'microsoft sharepoint'),
#    (0.0, 'microsoft office 365'),
#    (0.0, 'excel 2016 pivot tables in depth'),
#    (0.0, 'complete beginners introduction to sql'),
#    (0.0, 'sample'),
#    (0.0, 'et cases'),
#    (0.0, 'strategy - innovation'),
#    (0.0, 'hrm'),
#    (0.0, 'analytics'),
#    (0.0, 'timesshiksha')]},
#  'analytics essential training': {'id': 20,
#   'similarities': [(0.02746619832949375, 'adwords essential training'),
#    (0.019303039584758017, 'yammer 2018 essential training'),
#    (0.0189683919021663, 'google drive essential training tutorial'),
#    (0.012958731906235867, 'microsoft sharepoint'),
#    (0.011344940233265304, 'powerful speaking'),
#    (0.01082438130619209, 'email communication'),
#    (0.009964413061433083, 'html'),
#    (0.009528713457019795, 'marketing with facebook and twitter'),
#    (0.009042967601286497, 'microsoft dynamics crm customization config'),
#    (0.0, 'cbt nuggets microsoft sharepoint'),
#    (0.0, 'google cloud platform fundamentals'),
#    (0.0, 'cbt nuggets - mpls fundamentals'),
#    (0.0, 'cbt nuggets cloud computing'),
#    (0.0, 'microsoft powerpoint'),
#    (0.0, 'microsoft excel'),
#    (0.0, 'microsoft word'),
#    (0.0, 'project management fundamentals'),
#    (0.0, 'time management'),
#    (0.0, 'creating a business plan'),
#    (0.0, 'cloud computing'),
#    (0.0, 'sales secrets for small business'),
#    (0.0, 'techniques and concepts of big data'),
#    (0.0, 'tpl - learning management system'),
#    (0.0, 'stress management at workplace'),
#    (0.0, 'campusnexus crm'),
#    (0.0, 'leadership'),
#    (0.0, 'helpful technique while operating computers'),
#    (0.0, 'microsoft onedrive'),
#    (0.0, 'microsoft office 365'),
#    (0.0, 'excel 2016 pivot tables in depth'),
#    (0.0, 'complete beginners introduction to sql'),
#    (0.0, 'sample'),
#    (0.0, 'et cases'),
#    (0.0, 'strategy - innovation'),
#    (0.0, 'hrm'),
#    (0.0, 'analytics'),
#    (0.0, 'business-intellegence features in depth'),
#    (0.0, 'timesshiksha')]},
#  'google drive essential training tutorial': {'id': 21,
#   'similarities': [(0.05463013118332469, 'microsoft onedrive'),
#    (0.027582446929493496, 'yammer 2018 essential training'),
#    (0.01949927972959015, 'stress management at workplace'),
#    (0.0189683919021663, 'analytics essential training'),
#    (0.01700748313126698, 'adwords essential training'),
#    (0.010954319869803079, 'microsoft word'),
#    (0.00943577156386661, 'microsoft dynamics crm customization config'),
#    (0.009028231931821977, 'cloud computing'),
#    (0.008648787722924583, 'microsoft sharepoint'),
#    (0.008579125199100479, 'microsoft excel'),
#    (0.00824185748203897, 'microsoft office 365'),
#    (0.0073585069473527335, 'microsoft powerpoint'),
#    (0.007152740148527754, 'creating a business plan'),
#    (0.006391868747117867, 'techniques and concepts of big data'),
#    (0.006303145209393716, 'complete beginners introduction to sql'),
#    (0.006048754541627474, 'sales secrets for small business'),
#    (0.0, 'cbt nuggets cloud computing'),
#    (0.0, 'project management fundamentals'),
#    (0.0, 'cbt nuggets - mpls fundamentals'),
#    (0.0, 'cbt nuggets microsoft sharepoint'),
#    (0.0, 'powerful speaking'),
#    (0.0, 'email communication'),
#    (0.0, 'marketing with facebook and twitter'),
#    (0.0, 'time management'),
#    (0.0, 'google cloud platform fundamentals'),
#    (0.0, 'html'),
#    (0.0, 'business-intellegence features in depth'),
#    (0.0, 'analytics'),
#    (0.0, 'hrm'),
#    (0.0, 'strategy - innovation'),
#    (0.0, 'et cases'),
#    (0.0, 'sample'),
#    (0.0, 'excel 2016 pivot tables in depth'),
#    (0.0, 'helpful technique while operating computers'),
#    (0.0, 'leadership'),
#    (0.0, 'campusnexus crm'),
#    (0.0, 'tpl - learning management system'),
#    (0.0, 'timesshiksha')]},
#  'email communication': {'id': 22,
#   'similarities': [(0.037730790874581796, 'yammer 2018 essential training'),
#    (0.015057705090207216, 'cloud computing'),
#    (0.0124404182327976, 'microsoft excel'),
#    (0.011091761809252731, 'html'),
#    (0.01082438130619209, 'analytics essential training'),
#    (0.009705381638094415, 'adwords essential training'),
#    (0.008023605011608571, 'microsoft office 365'),
#    (0.007986523142247922, 'microsoft dynamics crm customization config'),
#    (0.00784549323917507, 'microsoft word'),
#    (0.0062283074181738955, 'microsoft powerpoint'),
#    (0.0, 'powerful speaking'),
#    (0.0, 'cbt nuggets cloud computing'),
#    (0.0, 'cbt nuggets - mpls fundamentals'),
#    (0.0, 'cbt nuggets microsoft sharepoint'),
#    (0.0, 'google cloud platform fundamentals'),
#    (0.0, 'google drive essential training tutorial'),
#    (0.0, 'project management fundamentals'),
#    (0.0, 'time management'),
#    (0.0, 'creating a business plan'),
#    (0.0, 'marketing with facebook and twitter'),
#    (0.0, 'sales secrets for small business'),
#    (0.0, 'techniques and concepts of big data'),
#    (0.0, 'tpl - learning management system'),
#    (0.0, 'stress management at workplace'),
#    (0.0, 'campusnexus crm'),
#    (0.0, 'leadership'),
#    (0.0, 'helpful technique while operating computers'),
#    (0.0, 'microsoft onedrive'),
#    (0.0, 'microsoft sharepoint'),
#    (0.0, 'excel 2016 pivot tables in depth'),
#    (0.0, 'complete beginners introduction to sql'),
#    (0.0, 'sample'),
#    (0.0, 'et cases'),
#    (0.0, 'strategy - innovation'),
#    (0.0, 'hrm'),
#    (0.0, 'analytics'),
#    (0.0, 'business-intellegence features in depth'),
#    (0.0, 'timesshiksha')]},
#  'yammer 2018 essential training': {'id': 23,
#   'similarities': [(0.037730790874581796, 'email communication'),
#    (0.02829658642249245, 'microsoft dynamics crm customization config'),
#    (0.027582446929493496, 'google drive essential training tutorial'),
#    (0.02654244516009299, 'microsoft office 365'),
#    (0.019303039584758017, 'analytics essential training'),
#    (0.019221927049358892, 'html'),
#    (0.019157505044844696, 'microsoft powerpoint'),
#    (0.01830944787908185, 'microsoft onedrive'),
#    (0.01713636386917567, 'microsoft word'),
#    (0.011260136305227993, 'powerful speaking'),
#    (0.009457485904147559, 'marketing with facebook and twitter'),
#    (0.008653767852678577, 'adwords essential training'),
#    (0.0069930550139616875, 'techniques and concepts of big data'),
#    (0.006895986597058094, 'complete beginners introduction to sql'),
#    (0.0064908203217044136, 'business-intellegence features in depth'),
#    (0.0, 'creating a business plan'),
#    (0.0, 'time management'),
#    (0.0, 'cbt nuggets microsoft sharepoint'),
#    (0.0, 'cbt nuggets - mpls fundamentals'),
#    (0.0, 'cbt nuggets cloud computing'),
#    (0.0, 'microsoft excel'),
#    (0.0, 'project management fundamentals'),
#    (0.0, 'cloud computing'),
#    (0.0, 'google cloud platform fundamentals'),
#    (0.0, 'sales secrets for small business'),
#    (0.0, 'analytics'),
#    (0.0, 'hrm'),
#    (0.0, 'strategy - innovation'),
#    (0.0, 'et cases'),
#    (0.0, 'sample'),
#    (0.0, 'excel 2016 pivot tables in depth'),
#    (0.0, 'microsoft sharepoint'),
#    (0.0, 'helpful technique while operating computers'),
#    (0.0, 'leadership'),
#    (0.0, 'campusnexus crm'),
#    (0.0, 'stress management at workplace'),
#    (0.0, 'tpl - learning management system'),
#    (0.0, 'timesshiksha')]},
#  'project management fundamentals': {'id': 24,
#   'similarities': [(0.017599377235525272, 'time management'),
#    (0.006375714575306797, 'stress management at workplace'),
#    (0.006354699761002589, 'cloud computing'),
#    (0.006087620443390566, 'microsoft sharepoint'),
#    (0.005774383754429558, 'microsoft dynamics crm customization config'),
#    (0.005591800571362515, 'complete beginners introduction to sql'),
#    (0.0, 'powerful speaking'),
#    (0.0, 'cbt nuggets cloud computing'),
#    (0.0, 'microsoft powerpoint'),
#    (0.0, 'cbt nuggets - mpls fundamentals'),
#    (0.0, 'google cloud platform fundamentals'),
#    (0.0, 'creating a business plan'),
#    (0.0, 'adwords essential training'),
#    (0.0, 'analytics essential training'),
#    (0.0, 'google drive essential training tutorial'),
#    (0.0, 'email communication'),
#    (0.0, 'yammer 2018 essential training'),
#    (0.0, 'microsoft excel'),
#    (0.0, 'microsoft word'),
#    (0.0, 'cbt nuggets microsoft sharepoint'),
#    (0.0, 'marketing with facebook and twitter'),
#    (0.0, 'sales secrets for small business'),
#    (0.0, 'excel 2016 pivot tables in depth'),
#    (0.0, 'tpl - learning management system'),
#    (0.0, 'campusnexus crm'),
#    (0.0, 'leadership'),
#    (0.0, 'helpful technique while operating computers'),
#    (0.0, 'microsoft onedrive'),
#    (0.0, 'microsoft office 365'),
#    (0.0, 'sample'),
#    (0.0, 'html'),
#    (0.0, 'et cases'),
#    (0.0, 'strategy - innovation'),
#    (0.0, 'hrm'),
#    (0.0, 'analytics'),
#    (0.0, 'business-intellegence features in depth'),
#    (0.0, 'techniques and concepts of big data'),
#    (0.0, 'timesshiksha')]},
#  'time management': {'id': 25,
#   'similarities': [(0.03185145074872411, 'sales secrets for small business'),
#    (0.023426541611360707, 'marketing with facebook and twitter'),
#    (0.017599377235525272, 'project management fundamentals'),
#    (0.01655131547531532, 'microsoft dynamics crm customization config'),
#    (0.011825818192667504, 'techniques and concepts of big data'),
#    (0.009824760196299064, 'adwords essential training'),
#    (0.009391326004291317, 'microsoft powerpoint'),
#    (0.007023898961253048, 'stress management at workplace'),
#    (0.00700074768454221, 'cloud computing'),
#    (0.0067065158585422205, 'microsoft sharepoint'),
#    (0.006160288664245515, 'complete beginners introduction to sql'),
#    (0.0, 'excel 2016 pivot tables in depth'),
#    (0.0, 'email communication'),
#    (0.0, 'microsoft word'),
#    (0.0, 'microsoft excel'),
#    (0.0, 'tpl - learning management system'),
#    (0.0, 'powerful speaking'),
#    (0.0, 'cbt nuggets cloud computing'),
#    (0.0, 'cbt nuggets - mpls fundamentals'),
#    (0.0, 'cbt nuggets microsoft sharepoint'),
#    (0.0, 'creating a business plan'),
#    (0.0, 'campusnexus crm'),
#    (0.0, 'analytics essential training'),
#    (0.0, 'google drive essential training tutorial'),
#    (0.0, 'leadership'),
#    (0.0, 'yammer 2018 essential training'),
#    (0.0, 'helpful technique while operating computers'),
#    (0.0, 'microsoft onedrive'),
#    (0.0, 'google cloud platform fundamentals'),
#    (0.0, 'html'),
#    (0.0, 'microsoft office 365'),
#    (0.0, 'business-intellegence features in depth'),
#    (0.0, 'analytics'),
#    (0.0, 'hrm'),
#    (0.0, 'strategy - innovation'),
#    (0.0, 'et cases'),
#    (0.0, 'sample'),
#    (0.0, 'timesshiksha')]},
#  'microsoft dynamics crm customization config': {'id': 26,
#   'similarities': [(0.03109789353265017,
#     'marketing with facebook and twitter'),
#    (0.02829658642249245, 'yammer 2018 essential training'),
#    (0.02180262192988628, 'creating a business plan'),
#    (0.021660635907515383, 'microsoft powerpoint'),
#    (0.019288356466714653, 'stress management at workplace'),
#    (0.01778329404525629, 'microsoft word'),
#    (0.01655131547531532, 'time management'),
#    (0.014449397244906799, 'business-intellegence features in depth'),
#    (0.013055212637363308, 'complete beginners introduction to sql'),
#    (0.010550156864895957, 'powerful speaking'),
#    (0.00943577156386661, 'google drive essential training tutorial'),
#    (0.009042967601286497, 'analytics essential training'),
#    (0.007986523142247922, 'email communication'),
#    (0.007814880827471584, 'sales secrets for small business'),
#    (0.007280328955481258, 'excel 2016 pivot tables in depth'),
#    (0.006767407101504312, 'microsoft excel'),
#    (0.00670312677584537, 'microsoft office 365'),
#    (0.006645185070856205, 'cloud computing'),
#    (0.00636589705397437, 'microsoft sharepoint'),
#    (0.005774383754429558, 'project management fundamentals'),
#    (0.0, 'html'),
#    (0.0, 'microsoft onedrive'),
#    (0.0, 'tpl - learning management system'),
#    (0.0, 'campusnexus crm'),
#    (0.0, 'leadership'),
#    (0.0, 'helpful technique while operating computers'),
#    (0.0, 'cbt nuggets cloud computing'),
#    (0.0, 'cbt nuggets - mpls fundamentals'),
#    (0.0, 'cbt nuggets microsoft sharepoint'),
#    (0.0, 'adwords essential training'),
#    (0.0, 'techniques and concepts of big data'),
#    (0.0, 'sample'),
#    (0.0, 'et cases'),
#    (0.0, 'strategy - innovation'),
#    (0.0, 'hrm'),
#    (0.0, 'analytics'),
#    (0.0, 'google cloud platform fundamentals'),
#    (0.0, 'timesshiksha')]},
#  'google cloud platform fundamentals': {'id': 27,
#   'similarities': [(0.0, 'adwords essential training'),
#    (0.0, 'microsoft dynamics crm customization config'),
#    (0.0, 'time management'),
#    (0.0, 'project management fundamentals'),
#    (0.0, 'yammer 2018 essential training'),
#    (0.0, 'email communication'),
#    (0.0, 'google drive essential training tutorial'),
#    (0.0, 'analytics essential training'),
#    (0.0, 'creating a business plan'),
#    (0.0, 'sales secrets for small business'),
#    (0.0, 'cbt nuggets microsoft sharepoint'),
#    (0.0, 'cbt nuggets - mpls fundamentals'),
#    (0.0, 'cbt nuggets cloud computing'),
#    (0.0, 'powerful speaking'),
#    (0.0, 'microsoft powerpoint'),
#    (0.0, 'microsoft excel'),
#    (0.0, 'microsoft word'),
#    (0.0, 'google cloud platform fundamentals'),
#    (0.0, 'marketing with facebook and twitter'),
#    (0.0, 'html'),
#    (0.0, 'microsoft office 365'),
#    (0.0, 'tpl - learning management system'),
#    (0.0, 'stress management at workplace'),
#    (0.0, 'campusnexus crm'),
#    (0.0, 'leadership'),
#    (0.0, 'helpful technique while operating computers'),
#    (0.0, 'microsoft onedrive'),
#    (0.0, 'microsoft sharepoint'),
#    (0.0, 'excel 2016 pivot tables in depth'),
#    (0.0, 'techniques and concepts of big data'),
#    (0.0, 'complete beginners introduction to sql'),
#    (0.0, 'sample'),
#    (0.0, 'et cases'),
#    (0.0, 'strategy - innovation'),
#    (0.0, 'hrm'),
#    (0.0, 'analytics'),
#    (0.0, 'business-intellegence features in depth'),
#    (0.0, 'timesshiksha')]},
#  'sales secrets for small business': {'id': 29,
#   'similarities': [(0.03185145074872411, 'time management'),
#    (0.015401507971672149, 'creating a business plan'),
#    (0.011193225633634214, 'marketing with facebook and twitter'),
#    (0.010078151888990885, 'microsoft onedrive'),
#    (0.009804232396579958, 'powerful speaking'),
#    (0.00866641125700674, 'adwords essential training'),
#    (0.007814880827471584, 'microsoft dynamics crm customization config'),
#    (0.007123141463276355, 'business-intellegence features in depth'),
#    (0.006846104918035031, 'stress management at workplace'),
#    (0.006088872697492702, 'techniques and concepts of big data'),
#    (0.006048754541627474, 'google drive essential training tutorial'),
#    (0.006004354953489098, 'complete beginners introduction to sql'),
#    (0.0, 'cbt nuggets cloud computing'),
#    (0.0, 'cbt nuggets - mpls fundamentals'),
#    (0.0, 'cbt nuggets microsoft sharepoint'),
#    (0.0, 'microsoft powerpoint'),
#    (0.0, 'microsoft excel'),
#    (0.0, 'analytics essential training'),
#    (0.0, 'email communication'),
#    (0.0, 'yammer 2018 essential training'),
#    (0.0, 'microsoft word'),
#    (0.0, 'project management fundamentals'),
#    (0.0, 'cloud computing'),
#    (0.0, 'google cloud platform fundamentals'),
#    (0.0, 'html'),
#    (0.0, 'analytics'),
#    (0.0, 'hrm'),
#    (0.0, 'strategy - innovation'),
#    (0.0, 'et cases'),
#    (0.0, 'sample'),
#    (0.0, 'excel 2016 pivot tables in depth'),
#    (0.0, 'microsoft office 365'),
#    (0.0, 'microsoft sharepoint'),
#    (0.0, 'helpful technique while operating computers'),
#    (0.0, 'leadership'),
#    (0.0, 'campusnexus crm'),
#    (0.0, 'tpl - learning management system'),
#    (0.0, 'timesshiksha')]},
#  'marketing with facebook and twitter': {'id': 30,
#   'similarities': [(0.03109789353265017,
#     'microsoft dynamics crm customization config'),
#    (0.02647230395290067, 'creating a business plan'),
#    (0.023426541611360707, 'time management'),
#    (0.02332795157904411, 'complete beginners introduction to sql'),
#    (0.011193225633634214, 'sales secrets for small business'),
#    (0.009968948764524173, 'excel 2016 pivot tables in depth'),
#    (0.009528713457019795, 'analytics essential training'),
#    (0.009457485904147559, 'yammer 2018 essential training'),
#    (0.00794817393062047, 'microsoft powerpoint'),
#    (0.0, 'cbt nuggets cloud computing'),
#    (0.0, 'cbt nuggets - mpls fundamentals'),
#    (0.0, 'cbt nuggets microsoft sharepoint'),
#    (0.0, 'powerful speaking'),
#    (0.0, 'google cloud platform fundamentals'),
#    (0.0, 'adwords essential training'),
#    (0.0, 'google drive essential training tutorial'),
#    (0.0, 'email communication'),
#    (0.0, 'project management fundamentals'),
#    (0.0, 'microsoft excel'),
#    (0.0, 'microsoft word'),
#    (0.0, 'cloud computing'),
#    (0.0, 'html'),
#    (0.0, 'microsoft sharepoint'),
#    (0.0, 'tpl - learning management system'),
#    (0.0, 'stress management at workplace'),
#    (0.0, 'campusnexus crm'),
#    (0.0, 'leadership'),
#    (0.0, 'helpful technique while operating computers'),
#    (0.0, 'microsoft onedrive'),
#    (0.0, 'microsoft office 365'),
#    (0.0, 'techniques and concepts of big data'),
#    (0.0, 'sample'),
#    (0.0, 'et cases'),
#    (0.0, 'strategy - innovation'),
#    (0.0, 'hrm'),
#    (0.0, 'analytics'),
#    (0.0, 'business-intellegence features in depth'),
#    (0.0, 'timesshiksha')]},
#  'techniques and concepts of big data': {'id': 31,
#   'similarities': [(0.012689901205177052,
#     'complete beginners introduction to sql'),
#    (0.011834114779026425, 'microsoft sharepoint'),
#    (0.011825818192667504, 'time management'),
#    (0.010452922843046, 'cloud computing'),
#    (0.009011504099177827, 'microsoft onedrive'),
#    (0.007234448639620971, 'stress management at workplace'),
#    (0.007219763334626501, 'html'),
#    (0.007200180450852355, 'creating a business plan'),
#    (0.0069930550139616875, 'yammer 2018 essential training'),
#    (0.006391868747117867, 'google drive essential training tutorial'),
#    (0.006088872697492702, 'sales secrets for small business'),
#    (0.005972159854408911, 'business-intellegence features in depth'),
#    (0.005109689380715637, 'microsoft powerpoint'),
#    (0.0, 'email communication'),
#    (0.0, 'microsoft word'),
#    (0.0, 'adwords essential training'),
#    (0.0, 'analytics essential training'),
#    (0.0, 'powerful speaking'),
#    (0.0, 'project management fundamentals'),
#    (0.0, 'cbt nuggets - mpls fundamentals'),
#    (0.0, 'cbt nuggets cloud computing'),
#    (0.0, 'microsoft excel'),
#    (0.0, 'cbt nuggets microsoft sharepoint'),
#    (0.0, 'marketing with facebook and twitter'),
#    (0.0, 'microsoft dynamics crm customization config'),
#    (0.0, 'google cloud platform fundamentals'),
#    (0.0, 'analytics'),
#    (0.0, 'hrm'),
#    (0.0, 'strategy - innovation'),
#    (0.0, 'et cases'),
#    (0.0, 'sample'),
#    (0.0, 'excel 2016 pivot tables in depth'),
#    (0.0, 'microsoft office 365'),
#    (0.0, 'helpful technique while operating computers'),
#    (0.0, 'leadership'),
#    (0.0, 'campusnexus crm'),
#    (0.0, 'tpl - learning management system'),
#    (0.0, 'timesshiksha')]},
#  'business-intellegence features in depth': {'id': 32,
#   'similarities': [(0.014449397244906799,
#     'microsoft dynamics crm customization config'),
#    (0.012868004592484016, 'microsoft powerpoint'),
#    (0.012459059251997608, 'complete beginners introduction to sql'),
#    (0.011504022416499298, 'stress management at workplace'),
#    (0.010467387023083464, 'microsoft office 365'),
#    (0.008423218296821636, 'creating a business plan'),
#    (0.007123141463276355, 'sales secrets for small business'),
#    (0.006701246662113969, 'html'),
#    (0.006635905805086771, 'excel 2016 pivot tables in depth'),
#    (0.0064908203217044136, 'yammer 2018 essential training'),
#    (0.006168385569507459, 'microsoft excel'),
#    (0.005972159854408911, 'techniques and concepts of big data'),
#    (0.0, 'google drive essential training tutorial'),
#    (0.0, 'email communication'),
#    (0.0, 'cloud computing'),
#    (0.0, 'analytics essential training'),
#    (0.0, 'adwords essential training'),
#    (0.0, 'project management fundamentals'),
#    (0.0, 'cbt nuggets - mpls fundamentals'),
#    (0.0, 'cbt nuggets cloud computing'),
#    (0.0, 'powerful speaking'),
#    (0.0, 'microsoft word'),
#    (0.0, 'cbt nuggets microsoft sharepoint'),
#    (0.0, 'marketing with facebook and twitter'),
#    (0.0, 'time management'),
#    (0.0, 'google cloud platform fundamentals'),
#    (0.0, 'analytics'),
#    (0.0, 'hrm'),
#    (0.0, 'strategy - innovation'),
#    (0.0, 'et cases'),
#    (0.0, 'sample'),
#    (0.0, 'microsoft sharepoint'),
#    (0.0, 'microsoft onedrive'),
#    (0.0, 'helpful technique while operating computers'),
#    (0.0, 'leadership'),
#    (0.0, 'campusnexus crm'),
#    (0.0, 'tpl - learning management system'),
#    (0.0, 'timesshiksha')]},
#  'analytics': {'id': 34,
#   'similarities': [(0.0, 'adwords essential training'),
#    (0.0, 'microsoft dynamics crm customization config'),
#    (0.0, 'time management'),
#    (0.0, 'project management fundamentals'),
#    (0.0, 'yammer 2018 essential training'),
#    (0.0, 'email communication'),
#    (0.0, 'google drive essential training tutorial'),
#    (0.0, 'analytics essential training'),
#    (0.0, 'creating a business plan'),
#    (0.0, 'sales secrets for small business'),
#    (0.0, 'cbt nuggets microsoft sharepoint'),
#    (0.0, 'cbt nuggets - mpls fundamentals'),
#    (0.0, 'cbt nuggets cloud computing'),
#    (0.0, 'powerful speaking'),
#    (0.0, 'microsoft powerpoint'),
#    (0.0, 'microsoft excel'),
#    (0.0, 'microsoft word'),
#    (0.0, 'google cloud platform fundamentals'),
#    (0.0, 'marketing with facebook and twitter'),
#    (0.0, 'html'),
#    (0.0, 'microsoft office 365'),
#    (0.0, 'tpl - learning management system'),
#    (0.0, 'stress management at workplace'),
#    (0.0, 'campusnexus crm'),
#    (0.0, 'leadership'),
#    (0.0, 'helpful technique while operating computers'),
#    (0.0, 'microsoft onedrive'),
#    (0.0, 'microsoft sharepoint'),
#    (0.0, 'excel 2016 pivot tables in depth'),
#    (0.0, 'techniques and concepts of big data'),
#    (0.0, 'complete beginners introduction to sql'),
#    (0.0, 'sample'),
#    (0.0, 'et cases'),
#    (0.0, 'strategy - innovation'),
#    (0.0, 'hrm'),
#    (0.0, 'analytics'),
#    (0.0, 'business-intellegence features in depth'),
#    (0.0, 'timesshiksha')]},
#  'hrm': {'id': 35,
#   'similarities': [(0.0, 'adwords essential training'),
#    (0.0, 'microsoft dynamics crm customization config'),
#    (0.0, 'time management'),
#    (0.0, 'project management fundamentals'),
#    (0.0, 'yammer 2018 essential training'),
#    (0.0, 'email communication'),
#    (0.0, 'google drive essential training tutorial'),
#    (0.0, 'analytics essential training'),
#    (0.0, 'creating a business plan'),
#    (0.0, 'sales secrets for small business'),
#    (0.0, 'cbt nuggets microsoft sharepoint'),
#    (0.0, 'cbt nuggets - mpls fundamentals'),
#    (0.0, 'cbt nuggets cloud computing'),
#    (0.0, 'powerful speaking'),
#    (0.0, 'microsoft powerpoint'),
#    (0.0, 'microsoft excel'),
#    (0.0, 'microsoft word'),
#    (0.0, 'google cloud platform fundamentals'),
#    (0.0, 'marketing with facebook and twitter'),
#    (0.0, 'html'),
#    (0.0, 'microsoft office 365'),
#    (0.0, 'tpl - learning management system'),
#    (0.0, 'stress management at workplace'),
#    (0.0, 'campusnexus crm'),
#    (0.0, 'leadership'),
#    (0.0, 'helpful technique while operating computers'),
#    (0.0, 'microsoft onedrive'),
#    (0.0, 'microsoft sharepoint'),
#    (0.0, 'excel 2016 pivot tables in depth'),
#    (0.0, 'techniques and concepts of big data'),
#    (0.0, 'complete beginners introduction to sql'),
#    (0.0, 'sample'),
#    (0.0, 'et cases'),
#    (0.0, 'strategy - innovation'),
#    (0.0, 'hrm'),
#    (0.0, 'analytics'),
#    (0.0, 'business-intellegence features in depth'),
#    (0.0, 'timesshiksha')]},
#  'strategy - innovation': {'id': 36,
#   'similarities': [(0.0, 'adwords essential training'),
#    (0.0, 'microsoft dynamics crm customization config'),
#    (0.0, 'time management'),
#    (0.0, 'project management fundamentals'),
#    (0.0, 'yammer 2018 essential training'),
#    (0.0, 'email communication'),
#    (0.0, 'google drive essential training tutorial'),
#    (0.0, 'analytics essential training'),
#    (0.0, 'creating a business plan'),
#    (0.0, 'sales secrets for small business'),
#    (0.0, 'cbt nuggets microsoft sharepoint'),
#    (0.0, 'cbt nuggets - mpls fundamentals'),
#    (0.0, 'cbt nuggets cloud computing'),
#    (0.0, 'powerful speaking'),
#    (0.0, 'microsoft powerpoint'),
#    (0.0, 'microsoft excel'),
#    (0.0, 'microsoft word'),
#    (0.0, 'google cloud platform fundamentals'),
#    (0.0, 'marketing with facebook and twitter'),
#    (0.0, 'html'),
#    (0.0, 'microsoft office 365'),
#    (0.0, 'tpl - learning management system'),
#    (0.0, 'stress management at workplace'),
#    (0.0, 'campusnexus crm'),
#    (0.0, 'leadership'),
#    (0.0, 'helpful technique while operating computers'),
#    (0.0, 'microsoft onedrive'),
#    (0.0, 'microsoft sharepoint'),
#    (0.0, 'excel 2016 pivot tables in depth'),
#    (0.0, 'techniques and concepts of big data'),
#    (0.0, 'complete beginners introduction to sql'),
#    (0.0, 'sample'),
#    (0.0, 'et cases'),
#    (0.0, 'strategy - innovation'),
#    (0.0, 'hrm'),
#    (0.0, 'analytics'),
#    (0.0, 'business-intellegence features in depth'),
#    (0.0, 'timesshiksha')]},
#  'et cases': {'id': 38,
#   'similarities': [(0.0, 'adwords essential training'),
#    (0.0, 'microsoft dynamics crm customization config'),
#    (0.0, 'time management'),
#    (0.0, 'project management fundamentals'),
#    (0.0, 'yammer 2018 essential training'),
#    (0.0, 'email communication'),
#    (0.0, 'google drive essential training tutorial'),
#    (0.0, 'analytics essential training'),
#    (0.0, 'creating a business plan'),
#    (0.0, 'sales secrets for small business'),
#    (0.0, 'cbt nuggets microsoft sharepoint'),
#    (0.0, 'cbt nuggets - mpls fundamentals'),
#    (0.0, 'cbt nuggets cloud computing'),
#    (0.0, 'powerful speaking'),
#    (0.0, 'microsoft powerpoint'),
#    (0.0, 'microsoft excel'),
#    (0.0, 'microsoft word'),
#    (0.0, 'google cloud platform fundamentals'),
#    (0.0, 'marketing with facebook and twitter'),
#    (0.0, 'html'),
#    (0.0, 'microsoft office 365'),
#    (0.0, 'tpl - learning management system'),
#    (0.0, 'stress management at workplace'),
#    (0.0, 'campusnexus crm'),
#    (0.0, 'leadership'),
#    (0.0, 'helpful technique while operating computers'),
#    (0.0, 'microsoft onedrive'),
#    (0.0, 'microsoft sharepoint'),
#    (0.0, 'excel 2016 pivot tables in depth'),
#    (0.0, 'techniques and concepts of big data'),
#    (0.0, 'complete beginners introduction to sql'),
#    (0.0, 'sample'),
#    (0.0, 'et cases'),
#    (0.0, 'strategy - innovation'),
#    (0.0, 'hrm'),
#    (0.0, 'analytics'),
#    (0.0, 'business-intellegence features in depth'),
#    (0.0, 'timesshiksha')]},
#  'sample': {'id': 39,
#   'similarities': [(0.0, 'adwords essential training'),
#    (0.0, 'microsoft dynamics crm customization config'),
#    (0.0, 'time management'),
#    (0.0, 'project management fundamentals'),
#    (0.0, 'yammer 2018 essential training'),
#    (0.0, 'email communication'),
#    (0.0, 'google drive essential training tutorial'),
#    (0.0, 'analytics essential training'),
#    (0.0, 'creating a business plan'),
#    (0.0, 'sales secrets for small business'),
#    (0.0, 'cbt nuggets microsoft sharepoint'),
#    (0.0, 'cbt nuggets - mpls fundamentals'),
#    (0.0, 'cbt nuggets cloud computing'),
#    (0.0, 'powerful speaking'),
#    (0.0, 'microsoft powerpoint'),
#    (0.0, 'microsoft excel'),
#    (0.0, 'microsoft word'),
#    (0.0, 'google cloud platform fundamentals'),
#    (0.0, 'marketing with facebook and twitter'),
#    (0.0, 'html'),
#    (0.0, 'microsoft office 365'),
#    (0.0, 'tpl - learning management system'),
#    (0.0, 'stress management at workplace'),
#    (0.0, 'campusnexus crm'),
#    (0.0, 'leadership'),
#    (0.0, 'helpful technique while operating computers'),
#    (0.0, 'microsoft onedrive'),
#    (0.0, 'microsoft sharepoint'),
#    (0.0, 'excel 2016 pivot tables in depth'),
#    (0.0, 'techniques and concepts of big data'),
#    (0.0, 'complete beginners introduction to sql'),
#    (0.0, 'sample'),
#    (0.0, 'et cases'),
#    (0.0, 'strategy - innovation'),
#    (0.0, 'hrm'),
#    (0.0, 'analytics'),
#    (0.0, 'business-intellegence features in depth'),
#    (0.0, 'timesshiksha')]},
#  'complete beginners introduction to sql': {'id': 41,
#   'similarities': [(0.02332795157904411,
#     'marketing with facebook and twitter'),
#    (0.013671243818585678, 'microsoft powerpoint'),
#    (0.013590377678593609, 'stress management at workplace'),
#    (0.013055212637363308, 'microsoft dynamics crm customization config'),
#    (0.012689901205177052, 'techniques and concepts of big data'),
#    (0.012459059251997608, 'business-intellegence features in depth'),
#    (0.007119548050189065, 'html'),
#    (0.007100236990320576, 'creating a business plan'),
#    (0.007050128523539538, 'excel 2016 pivot tables in depth'),
#    (0.006895986597058094, 'yammer 2018 essential training'),
#    (0.006553425007093747, 'microsoft excel'),
#    (0.00643506757712784, 'cloud computing'),
#    (0.006303145209393716, 'google drive essential training tutorial'),
#    (0.006164610510401622, 'microsoft sharepoint'),
#    (0.006160288664245515, 'time management'),
#    (0.006004354953489098, 'sales secrets for small business'),
#    (0.005591800571362515, 'project management fundamentals'),
#    (0.0, 'et cases'),
#    (0.0, 'adwords essential training'),
#    (0.0, 'microsoft word'),
#    (0.0, 'tpl - learning management system'),
#    (0.0, 'campusnexus crm'),
#    (0.0, 'powerful speaking'),
#    (0.0, 'cbt nuggets cloud computing'),
#    (0.0, 'cbt nuggets - mpls fundamentals'),
#    (0.0, 'cbt nuggets microsoft sharepoint'),
#    (0.0, 'leadership'),
#    (0.0, 'email communication'),
#    (0.0, 'analytics essential training'),
#    (0.0, 'strategy - innovation'),
#    (0.0, 'helpful technique while operating computers'),
#    (0.0, 'microsoft onedrive'),
#    (0.0, 'google cloud platform fundamentals'),
#    (0.0, 'microsoft office 365'),
#    (0.0, 'sample'),
#    (0.0, 'analytics'),
#    (0.0, 'hrm'),
#    (0.0, 'timesshiksha')]},
#  'excel 2016 pivot tables in depth': {'id': 42,
#   'similarities': [(0.016785065984257837, 'microsoft excel'),
#    (0.01609733997202804, 'microsoft powerpoint'),
#    (0.009968948764524173, 'marketing with facebook and twitter'),
#    (0.007280328955481258, 'microsoft dynamics crm customization config'),
#    (0.007050128523539538, 'complete beginners introduction to sql'),
#    (0.006635905805086771, 'business-intellegence features in depth'),
#    (0.0, 'analytics essential training'),
#    (0.0, 'time management'),
#    (0.0, 'project management fundamentals'),
#    (0.0, 'yammer 2018 essential training'),
#    (0.0, 'email communication'),
#    (0.0, 'google drive essential training tutorial'),
#    (0.0, 'microsoft word'),
#    (0.0, 'powerful speaking'),
#    (0.0, 'google cloud platform fundamentals'),
#    (0.0, 'creating a business plan'),
#    (0.0, 'cbt nuggets microsoft sharepoint'),
#    (0.0, 'cbt nuggets - mpls fundamentals'),
#    (0.0, 'cbt nuggets cloud computing'),
#    (0.0, 'adwords essential training'),
#    (0.0, 'cloud computing'),
#    (0.0, 'sales secrets for small business'),
#    (0.0, 'microsoft sharepoint'),
#    (0.0, 'tpl - learning management system'),
#    (0.0, 'stress management at workplace'),
#    (0.0, 'campusnexus crm'),
#    (0.0, 'leadership'),
#    (0.0, 'helpful technique while operating computers'),
#    (0.0, 'microsoft onedrive'),
#    (0.0, 'microsoft office 365'),
#    (0.0, 'html'),
#    (0.0, 'sample'),
#    (0.0, 'et cases'),
#    (0.0, 'strategy - innovation'),
#    (0.0, 'hrm'),
#    (0.0, 'analytics'),
#    (0.0, 'techniques and concepts of big data'),
#    (0.0, 'timesshiksha')]},
#  'microsoft office 365': {'id': 43,
#   'similarities': [(0.02654244516009299, 'yammer 2018 essential training'),
#    (0.017865862864608957, 'microsoft word'),
#    (0.012679796866727917, 'stress management at workplace'),
#    (0.010707407169730813, 'html'),
#    (0.010467387023083464, 'business-intellegence features in depth'),
#    (0.010441302062703255, 'microsoft excel'),
#    (0.00824185748203897, 'google drive essential training tutorial'),
#    (0.008023605011608571, 'email communication'),
#    (0.008015459045266854, 'microsoft onedrive'),
#    (0.00670312677584537, 'microsoft dynamics crm customization config'),
#    (0.0052274479744645035, 'microsoft powerpoint'),
#    (0.0, 'cloud computing'),
#    (0.0, 'project management fundamentals'),
#    (0.0, 'cbt nuggets microsoft sharepoint'),
#    (0.0, 'analytics essential training'),
#    (0.0, 'adwords essential training'),
#    (0.0, 'creating a business plan'),
#    (0.0, 'cbt nuggets - mpls fundamentals'),
#    (0.0, 'cbt nuggets cloud computing'),
#    (0.0, 'powerful speaking'),
#    (0.0, 'time management'),
#    (0.0, 'marketing with facebook and twitter'),
#    (0.0, 'google cloud platform fundamentals'),
#    (0.0, 'sales secrets for small business'),
#    (0.0, 'techniques and concepts of big data'),
#    (0.0, 'analytics'),
#    (0.0, 'hrm'),
#    (0.0, 'strategy - innovation'),
#    (0.0, 'et cases'),
#    (0.0, 'sample'),
#    (0.0, 'complete beginners introduction to sql'),
#    (0.0, 'excel 2016 pivot tables in depth'),
#    (0.0, 'microsoft sharepoint'),
#    (0.0, 'helpful technique while operating computers'),
#    (0.0, 'leadership'),
#    (0.0, 'campusnexus crm'),
#    (0.0, 'tpl - learning management system'),
#    (0.0, 'timesshiksha')]},
#  'microsoft sharepoint': {'id': 44,
#   'similarities': [(0.030024257494909633, 'cloud computing'),
#    (0.020334670873944447, 'stress management at workplace'),
#    (0.012958731906235867, 'analytics essential training'),
#    (0.011838091921246225, 'microsoft word'),
#    (0.011834114779026425, 'techniques and concepts of big data'),
#    (0.010956826818232531, 'microsoft excel'),
#    (0.009411423986220894, 'powerful speaking'),
#    (0.008648787722924583, 'google drive essential training tutorial'),
#    (0.008411211178473151, 'microsoft onedrive'),
#    (0.007952176189963365, 'microsoft powerpoint'),
#    (0.0067065158585422205, 'time management'),
#    (0.00636589705397437, 'microsoft dynamics crm customization config'),
#    (0.006164610510401622, 'complete beginners introduction to sql'),
#    (0.006087620443390566, 'project management fundamentals'),
#    (0.0, 'cbt nuggets microsoft sharepoint'),
#    (0.0, 'creating a business plan'),
#    (0.0, 'adwords essential training'),
#    (0.0, 'cbt nuggets - mpls fundamentals'),
#    (0.0, 'email communication'),
#    (0.0, 'cbt nuggets cloud computing'),
#    (0.0, 'yammer 2018 essential training'),
#    (0.0, 'marketing with facebook and twitter'),
#    (0.0, 'google cloud platform fundamentals'),
#    (0.0, 'sales secrets for small business'),
#    (0.0, 'html'),
#    (0.0, 'business-intellegence features in depth'),
#    (0.0, 'analytics'),
#    (0.0, 'hrm'),
#    (0.0, 'strategy - innovation'),
#    (0.0, 'et cases'),
#    (0.0, 'sample'),
#    (0.0, 'excel 2016 pivot tables in depth'),
#    (0.0, 'microsoft office 365'),
#    (0.0, 'helpful technique while operating computers'),
#    (0.0, 'leadership'),
#    (0.0, 'campusnexus crm'),
#    (0.0, 'tpl - learning management system'),
#    (0.0, 'timesshiksha')]},
#  'microsoft onedrive': {'id': 45,
#   'similarities': [(0.05463013118332469,
#     'google drive essential training tutorial'),
#    (0.01887904019433679, 'cloud computing'),
#    (0.01830944787908185, 'yammer 2018 essential training'),
#    (0.011949974174841156, 'html'),
#    (0.010078151888990885, 'sales secrets for small business'),
#    (0.009011504099177827, 'techniques and concepts of big data'),
#    (0.008411211178473151, 'microsoft sharepoint'),
#    (0.008343462238635394, 'microsoft excel'),
#    (0.008015459045266854, 'microsoft office 365'),
#    (0.0, 'adwords essential training'),
#    (0.0, 'email communication'),
#    (0.0, 'analytics essential training'),
#    (0.0, 'cbt nuggets microsoft sharepoint'),
#    (0.0, 'creating a business plan'),
#    (0.0, 'time management'),
#    (0.0, 'cbt nuggets - mpls fundamentals'),
#    (0.0, 'cbt nuggets cloud computing'),
#    (0.0, 'powerful speaking'),
#    (0.0, 'microsoft powerpoint'),
#    (0.0, 'microsoft word'),
#    (0.0, 'project management fundamentals'),
#    (0.0, 'marketing with facebook and twitter'),
#    (0.0, 'microsoft dynamics crm customization config'),
#    (0.0, 'google cloud platform fundamentals'),
#    (0.0, 'business-intellegence features in depth'),
#    (0.0, 'analytics'),
#    (0.0, 'hrm'),
#    (0.0, 'strategy - innovation'),
#    (0.0, 'et cases'),
#    (0.0, 'sample'),
#    (0.0, 'complete beginners introduction to sql'),
#    (0.0, 'excel 2016 pivot tables in depth'),
#    (0.0, 'helpful technique while operating computers'),
#    (0.0, 'leadership'),
#    (0.0, 'campusnexus crm'),
#    (0.0, 'stress management at workplace'),
#    (0.0, 'tpl - learning management system'),
#    (0.0, 'timesshiksha')]},
#  'helpful technique while operating computers': {'id': 46,
#   'similarities': [(0.0, 'adwords essential training'),
#    (0.0, 'microsoft dynamics crm customization config'),
#    (0.0, 'time management'),
#    (0.0, 'project management fundamentals'),
#    (0.0, 'yammer 2018 essential training'),
#    (0.0, 'email communication'),
#    (0.0, 'google drive essential training tutorial'),
#    (0.0, 'analytics essential training'),
#    (0.0, 'creating a business plan'),
#    (0.0, 'sales secrets for small business'),
#    (0.0, 'cbt nuggets microsoft sharepoint'),
#    (0.0, 'cbt nuggets - mpls fundamentals'),
#    (0.0, 'cbt nuggets cloud computing'),
#    (0.0, 'powerful speaking'),
#    (0.0, 'microsoft powerpoint'),
#    (0.0, 'microsoft excel'),
#    (0.0, 'microsoft word'),
#    (0.0, 'google cloud platform fundamentals'),
#    (0.0, 'marketing with facebook and twitter'),
#    (0.0, 'html'),
#    (0.0, 'microsoft office 365'),
#    (0.0, 'tpl - learning management system'),
#    (0.0, 'stress management at workplace'),
#    (0.0, 'campusnexus crm'),
#    (0.0, 'leadership'),
#    (0.0, 'helpful technique while operating computers'),
#    (0.0, 'microsoft onedrive'),
#    (0.0, 'microsoft sharepoint'),
#    (0.0, 'excel 2016 pivot tables in depth'),
#    (0.0, 'techniques and concepts of big data'),
#    (0.0, 'complete beginners introduction to sql'),
#    (0.0, 'sample'),
#    (0.0, 'et cases'),
#    (0.0, 'strategy - innovation'),
#    (0.0, 'hrm'),
#    (0.0, 'analytics'),
#    (0.0, 'business-intellegence features in depth'),
#    (0.0, 'timesshiksha')]},
#  'leadership': {'id': 47,
#   'similarities': [(0.0, 'adwords essential training'),
#    (0.0, 'microsoft dynamics crm customization config'),
#    (0.0, 'time management'),
#    (0.0, 'project management fundamentals'),
#    (0.0, 'yammer 2018 essential training'),
#    (0.0, 'email communication'),
#    (0.0, 'google drive essential training tutorial'),
#    (0.0, 'analytics essential training'),
#    (0.0, 'creating a business plan'),
#    (0.0, 'sales secrets for small business'),
#    (0.0, 'cbt nuggets microsoft sharepoint'),
#    (0.0, 'cbt nuggets - mpls fundamentals'),
#    (0.0, 'cbt nuggets cloud computing'),
#    (0.0, 'powerful speaking'),
#    (0.0, 'microsoft powerpoint'),
#    (0.0, 'microsoft excel'),
#    (0.0, 'microsoft word'),
#    (0.0, 'google cloud platform fundamentals'),
#    (0.0, 'marketing with facebook and twitter'),
#    (0.0, 'html'),
#    (0.0, 'microsoft office 365'),
#    (0.0, 'tpl - learning management system'),
#    (0.0, 'stress management at workplace'),
#    (0.0, 'campusnexus crm'),
#    (0.0, 'leadership'),
#    (0.0, 'helpful technique while operating computers'),
#    (0.0, 'microsoft onedrive'),
#    (0.0, 'microsoft sharepoint'),
#    (0.0, 'excel 2016 pivot tables in depth'),
#    (0.0, 'techniques and concepts of big data'),
#    (0.0, 'complete beginners introduction to sql'),
#    (0.0, 'sample'),
#    (0.0, 'et cases'),
#    (0.0, 'strategy - innovation'),
#    (0.0, 'hrm'),
#    (0.0, 'analytics'),
#    (0.0, 'business-intellegence features in depth'),
#    (0.0, 'timesshiksha')]},
#  'campusnexus crm': {'id': 48,
#   'similarities': [(0.0, 'adwords essential training'),
#    (0.0, 'microsoft dynamics crm customization config'),
#    (0.0, 'time management'),
#    (0.0, 'project management fundamentals'),
#    (0.0, 'yammer 2018 essential training'),
#    (0.0, 'email communication'),
#    (0.0, 'google drive essential training tutorial'),
#    (0.0, 'analytics essential training'),
#    (0.0, 'creating a business plan'),
#    (0.0, 'sales secrets for small business'),
#    (0.0, 'cbt nuggets microsoft sharepoint'),
#    (0.0, 'cbt nuggets - mpls fundamentals'),
#    (0.0, 'cbt nuggets cloud computing'),
#    (0.0, 'powerful speaking'),
#    (0.0, 'microsoft powerpoint'),
#    (0.0, 'microsoft excel'),
#    (0.0, 'microsoft word'),
#    (0.0, 'google cloud platform fundamentals'),
#    (0.0, 'marketing with facebook and twitter'),
#    (0.0, 'html'),
#    (0.0, 'microsoft office 365'),
#    (0.0, 'tpl - learning management system'),
#    (0.0, 'stress management at workplace'),
#    (0.0, 'campusnexus crm'),
#    (0.0, 'leadership'),
#    (0.0, 'helpful technique while operating computers'),
#    (0.0, 'microsoft onedrive'),
#    (0.0, 'microsoft sharepoint'),
#    (0.0, 'excel 2016 pivot tables in depth'),
#    (0.0, 'techniques and concepts of big data'),
#    (0.0, 'complete beginners introduction to sql'),
#    (0.0, 'sample'),
#    (0.0, 'et cases'),
#    (0.0, 'strategy - innovation'),
#    (0.0, 'hrm'),
#    (0.0, 'analytics'),
#    (0.0, 'business-intellegence features in depth'),
#    (0.0, 'timesshiksha')]},
#  'stress management at workplace': {'id': 49,
#   'similarities': [(0.020334670873944447, 'microsoft sharepoint'),
#    (0.01949927972959015, 'google drive essential training tutorial'),
#    (0.019288356466714653, 'microsoft dynamics crm customization config'),
#    (0.013590377678593609, 'complete beginners introduction to sql'),
#    (0.012679796866727917, 'microsoft office 365'),
#    (0.011504022416499298, 'business-intellegence features in depth'),
#    (0.008095618556061801, 'creating a business plan'),
#    (0.00733719910447041, 'cloud computing'),
#    (0.007234448639620971, 'techniques and concepts of big data'),
#    (0.007023898961253048, 'time management'),
#    (0.006846104918035031, 'sales secrets for small business'),
#    (0.006375714575306797, 'project management fundamentals'),
#    (0.0, 'cbt nuggets - mpls fundamentals'),
#    (0.0, 'cbt nuggets cloud computing'),
#    (0.0, 'adwords essential training'),
#    (0.0, 'analytics essential training'),
#    (0.0, 'powerful speaking'),
#    (0.0, 'microsoft powerpoint'),
#    (0.0, 'microsoft excel'),
#    (0.0, 'email communication'),
#    (0.0, 'yammer 2018 essential training'),
#    (0.0, 'microsoft word'),
#    (0.0, 'cbt nuggets microsoft sharepoint'),
#    (0.0, 'marketing with facebook and twitter'),
#    (0.0, 'google cloud platform fundamentals'),
#    (0.0, 'html'),
#    (0.0, 'analytics'),
#    (0.0, 'hrm'),
#    (0.0, 'strategy - innovation'),
#    (0.0, 'et cases'),
#    (0.0, 'sample'),
#    (0.0, 'excel 2016 pivot tables in depth'),
#    (0.0, 'microsoft onedrive'),
#    (0.0, 'helpful technique while operating computers'),
#    (0.0, 'leadership'),
#    (0.0, 'campusnexus crm'),
#    (0.0, 'tpl - learning management system'),
#    (0.0, 'timesshiksha')]},
#  'tpl - learning management system': {'id': 50,
#   'similarities': [(0.0, 'adwords essential training'),
#    (0.0, 'microsoft dynamics crm customization config'),
#    (0.0, 'time management'),
#    (0.0, 'project management fundamentals'),
#    (0.0, 'yammer 2018 essential training'),
#    (0.0, 'email communication'),
#    (0.0, 'google drive essential training tutorial'),
#    (0.0, 'analytics essential training'),
#    (0.0, 'creating a business plan'),
#    (0.0, 'sales secrets for small business'),
#    (0.0, 'cbt nuggets microsoft sharepoint'),
#    (0.0, 'cbt nuggets - mpls fundamentals'),
#    (0.0, 'cbt nuggets cloud computing'),
#    (0.0, 'powerful speaking'),
#    (0.0, 'microsoft powerpoint'),
#    (0.0, 'microsoft excel'),
#    (0.0, 'microsoft word'),
#    (0.0, 'google cloud platform fundamentals'),
#    (0.0, 'marketing with facebook and twitter'),
#    (0.0, 'html'),
#    (0.0, 'microsoft office 365'),
#    (0.0, 'tpl - learning management system'),
#    (0.0, 'stress management at workplace'),
#    (0.0, 'campusnexus crm'),
#    (0.0, 'leadership'),
#    (0.0, 'helpful technique while operating computers'),
#    (0.0, 'microsoft onedrive'),
#    (0.0, 'microsoft sharepoint'),
#    (0.0, 'excel 2016 pivot tables in depth'),
#    (0.0, 'techniques and concepts of big data'),
#    (0.0, 'complete beginners introduction to sql'),
#    (0.0, 'sample'),
#    (0.0, 'et cases'),
#    (0.0, 'strategy - innovation'),
#    (0.0, 'hrm'),
#    (0.0, 'analytics'),
#    (0.0, 'business-intellegence features in depth'),
#    (0.0, 'timesshiksha')]},
#  'html': {'id': 51,
#   'similarities': [(0.03322282414315095, 'adwords essential training'),
#    (0.019221927049358892, 'yammer 2018 essential training'),
#    (0.011949974174841156, 'microsoft onedrive'),
#    (0.011091761809252731, 'email communication'),
#    (0.010707407169730813, 'microsoft office 365'),
#    (0.009964413061433083, 'analytics essential training'),
#    (0.007219763334626501, 'techniques and concepts of big data'),
#    (0.007119548050189065, 'complete beginners introduction to sql'),
#    (0.006701246662113969, 'business-intellegence features in depth'),
#    (0.005733484993989474, 'microsoft powerpoint'),
#    (0.0, 'google drive essential training tutorial'),
#    (0.0, 'cloud computing'),
#    (0.0, 'creating a business plan'),
#    (0.0, 'time management'),
#    (0.0, 'cbt nuggets microsoft sharepoint'),
#    (0.0, 'cbt nuggets - mpls fundamentals'),
#    (0.0, 'cbt nuggets cloud computing'),
#    (0.0, 'powerful speaking'),
#    (0.0, 'microsoft excel'),
#    (0.0, 'microsoft word'),
#    (0.0, 'project management fundamentals'),
#    (0.0, 'marketing with facebook and twitter'),
#    (0.0, 'microsoft dynamics crm customization config'),
#    (0.0, 'google cloud platform fundamentals'),
#    (0.0, 'sales secrets for small business'),
#    (0.0, 'analytics'),
#    (0.0, 'hrm'),
#    (0.0, 'strategy - innovation'),
#    (0.0, 'et cases'),
#    (0.0, 'sample'),
#    (0.0, 'excel 2016 pivot tables in depth'),
#    (0.0, 'microsoft sharepoint'),
#    (0.0, 'helpful technique while operating computers'),
#    (0.0, 'leadership'),
#    (0.0, 'campusnexus crm'),
#    (0.0, 'stress management at workplace'),
#    (0.0, 'tpl - learning management system'),
#    (0.0, 'timesshiksha')]},
#  'cloud computing': {'id': 52,
#   'similarities': [(0.030024257494909633, 'microsoft sharepoint'),
#    (0.01887904019433679, 'microsoft onedrive'),
#    (0.015057705090207216, 'email communication'),
#    (0.010452922843046, 'techniques and concepts of big data'),
#    (0.009028231931821977, 'google drive essential training tutorial'),
#    (0.00733719910447041, 'stress management at workplace'),
#    (0.00700074768454221, 'time management'),
#    (0.006645185070856205, 'microsoft dynamics crm customization config'),
#    (0.00643506757712784, 'complete beginners introduction to sql'),
#    (0.006354699761002589, 'project management fundamentals'),
#    (0.0, 'powerful speaking'),
#    (0.0, 'cbt nuggets cloud computing'),
#    (0.0, 'cbt nuggets - mpls fundamentals'),
#    (0.0, 'cbt nuggets microsoft sharepoint'),
#    (0.0, 'creating a business plan'),
#    (0.0, 'adwords essential training'),
#    (0.0, 'analytics essential training'),
#    (0.0, 'microsoft powerpoint'),
#    (0.0, 'microsoft excel'),
#    (0.0, 'microsoft word'),
#    (0.0, 'yammer 2018 essential training'),
#    (0.0, 'marketing with facebook and twitter'),
#    (0.0, 'google cloud platform fundamentals'),
#    (0.0, 'sales secrets for small business'),
#    (0.0, 'html'),
#    (0.0, 'business-intellegence features in depth'),
#    (0.0, 'analytics'),
#    (0.0, 'hrm'),
#    (0.0, 'strategy - innovation'),
#    (0.0, 'et cases'),
#    (0.0, 'sample'),
#    (0.0, 'excel 2016 pivot tables in depth'),
#    (0.0, 'microsoft office 365'),
#    (0.0, 'helpful technique while operating computers'),
#    (0.0, 'leadership'),
#    (0.0, 'campusnexus crm'),
#    (0.0, 'tpl - learning management system'),
#    (0.0, 'timesshiksha')]}}

# %%
corr = []
for progName, details in results.items():
#     print(details)
#     print(progName)
#     break
    corr.append({'id': details['id'], 'programName': progName, 'similarities': details['similarities']})

# %%
corr
# Out:
# [{'id': 1,
#   'programName': 'timesshiksha',
#   'similarities': [(0.03108797179007013, 'microsoft powerpoint'),
#    (0.0, 'adwords essential training'),
#    (0.0, 'microsoft dynamics crm customization config'),
#    (0.0, 'time management'),
#    (0.0, 'project management fundamentals'),
#    (0.0, 'yammer 2018 essential training'),
#    (0.0, 'email communication'),
#    (0.0, 'google drive essential training tutorial'),
#    (0.0, 'analytics essential training'),
#    (0.0, 'creating a business plan'),
#    (0.0, 'sales secrets for small business'),
#    (0.0, 'cbt nuggets microsoft sharepoint'),
#    (0.0, 'cbt nuggets - mpls fundamentals'),
#    (0.0, 'cbt nuggets cloud computing'),
#    (0.0, 'powerful speaking'),
#    (0.0, 'microsoft excel'),
#    (0.0, 'microsoft word'),
#    (0.0, 'google cloud platform fundamentals'),
#    (0.0, 'cloud computing'),
#    (0.0, 'html'),
#    (0.0, 'microsoft office 365'),
#    (0.0, 'tpl - learning management system'),
#    (0.0, 'stress management at workplace'),
#    (0.0, 'campusnexus crm'),
#    (0.0, 'leadership'),
#    (0.0, 'helpful technique while operating computers'),
#    (0.0, 'microsoft onedrive'),
#    (0.0, 'microsoft sharepoint'),
#    (0.0, 'excel 2016 pivot tables in depth'),
#    (0.0, 'techniques and concepts of big data'),
#    (0.0, 'complete beginners introduction to sql'),
#    (0.0, 'sample'),
#    (0.0, 'et cases'),
#    (0.0, 'strategy - innovation'),
#    (0.0, 'hrm'),
#    (0.0, 'analytics'),
#    (0.0, 'business-intellegence features in depth'),
#    (0.0, 'marketing with facebook and twitter')]},
#  {'id': 6,
#   'programName': 'microsoft word',
#   'similarities': [(0.02127814188250297, 'microsoft powerpoint'),
#    (0.017865862864608957, 'microsoft office 365'),
#    (0.01778329404525629, 'microsoft dynamics crm customization config'),
#    (0.01713636386917567, 'yammer 2018 essential training'),
#    (0.011838091921246225, 'microsoft sharepoint'),
#    (0.010954319869803079, 'google drive essential training tutorial'),
#    (0.00784549323917507, 'email communication'),
#    (0.0, 'adwords essential training'),
#    (0.0, 'time management'),
#    (0.0, 'project management fundamentals'),
#    (0.0, 'analytics essential training'),
#    (0.0, 'cloud computing'),
#    (0.0, 'creating a business plan'),
#    (0.0, 'google cloud platform fundamentals'),
#    (0.0, 'cbt nuggets - mpls fundamentals'),
#    (0.0, 'cbt nuggets cloud computing'),
#    (0.0, 'powerful speaking'),
#    (0.0, 'microsoft excel'),
#    (0.0, 'cbt nuggets microsoft sharepoint'),
#    (0.0, 'marketing with facebook and twitter'),
#    (0.0, 'sales secrets for small business'),
#    (0.0, 'html'),
#    (0.0, 'tpl - learning management system'),
#    (0.0, 'stress management at workplace'),
#    (0.0, 'campusnexus crm'),
#    (0.0, 'leadership'),
#    (0.0, 'helpful technique while operating computers'),
#    (0.0, 'microsoft onedrive'),
#    (0.0, 'excel 2016 pivot tables in depth'),
#    (0.0, 'complete beginners introduction to sql'),
#    (0.0, 'sample'),
#    (0.0, 'et cases'),
#    (0.0, 'strategy - innovation'),
#    (0.0, 'hrm'),
#    (0.0, 'analytics'),
#    (0.0, 'business-intellegence features in depth'),
#    (0.0, 'techniques and concepts of big data'),
#    (0.0, 'timesshiksha')]},
#  {'id': 7,
#   'programName': 'microsoft excel',
#   'similarities': [(0.016785065984257837, 'excel 2016 pivot tables in depth'),
#    (0.0124404182327976, 'email communication'),
#    (0.010956826818232531, 'microsoft sharepoint'),
#    (0.010441302062703255, 'microsoft office 365'),
#    (0.008579125199100479, 'google drive essential training tutorial'),
#    (0.008343462238635394, 'microsoft onedrive'),
#    (0.006767407101504312, 'microsoft dynamics crm customization config'),
#    (0.006553425007093747, 'complete beginners introduction to sql'),
#    (0.006168385569507459, 'business-intellegence features in depth'),
#    (0.0, 'cbt nuggets cloud computing'),
#    (0.0, 'powerful speaking'),
#    (0.0, 'time management'),
#    (0.0, 'cbt nuggets - mpls fundamentals'),
#    (0.0, 'cbt nuggets microsoft sharepoint'),
#    (0.0, 'creating a business plan'),
#    (0.0, 'adwords essential training'),
#    (0.0, 'analytics essential training'),
#    (0.0, 'microsoft powerpoint'),
#    (0.0, 'microsoft word'),
#    (0.0, 'yammer 2018 essential training'),
#    (0.0, 'project management fundamentals'),
#    (0.0, 'cloud computing'),
#    (0.0, 'marketing with facebook and twitter'),
#    (0.0, 'google cloud platform fundamentals'),
#    (0.0, 'sales secrets for small business'),
#    (0.0, 'html'),
#    (0.0, 'techniques and concepts of big data'),
#    (0.0, 'analytics'),
#    (0.0, 'hrm'),
#    (0.0, 'strategy - innovation'),
#    (0.0, 'et cases'),
#    (0.0, 'sample'),
#    (0.0, 'helpful technique while operating computers'),
#    (0.0, 'leadership'),
#    (0.0, 'campusnexus crm'),
#    (0.0, 'stress management at workplace'),
#    (0.0, 'tpl - learning management system'),
#    (0.0, 'timesshiksha')]},
#  {'id': 8,
#   'programName': 'microsoft powerpoint',
#   'similarities': [(0.03108797179007013, 'timesshiksha'),
#    (0.021660635907515383, 'microsoft dynamics crm customization config'),
#    (0.02127814188250297, 'microsoft word'),
#    (0.019157505044844696, 'yammer 2018 essential training'),
#    (0.01609733997202804, 'excel 2016 pivot tables in depth'),
#    (0.013671243818585678, 'complete beginners introduction to sql'),
#    (0.012868004592484016, 'business-intellegence features in depth'),
#    (0.009391326004291317, 'time management'),
#    (0.008594931151104705, 'adwords essential training'),
#    (0.007952176189963365, 'microsoft sharepoint'),
#    (0.00794817393062047, 'marketing with facebook and twitter'),
#    (0.0073585069473527335, 'google drive essential training tutorial'),
#    (0.006961866658890943, 'powerful speaking'),
#    (0.0062283074181738955, 'email communication'),
#    (0.005733484993989474, 'html'),
#    (0.0052274479744645035, 'microsoft office 365'),
#    (0.005109689380715637, 'techniques and concepts of big data'),
#    (0.0, 'sample'),
#    (0.0, 'analytics essential training'),
#    (0.0, 'tpl - learning management system'),
#    (0.0, 'microsoft excel'),
#    (0.0, 'stress management at workplace'),
#    (0.0, 'cbt nuggets cloud computing'),
#    (0.0, 'cbt nuggets - mpls fundamentals'),
#    (0.0, 'cbt nuggets microsoft sharepoint'),
#    (0.0, 'creating a business plan'),
#    (0.0, 'campusnexus crm'),
#    (0.0, 'leadership'),
#    (0.0, 'et cases'),
#    (0.0, 'project management fundamentals'),
#    (0.0, 'helpful technique while operating computers'),
#    (0.0, 'microsoft onedrive'),
#    (0.0, 'google cloud platform fundamentals'),
#    (0.0, 'sales secrets for small business'),
#    (0.0, 'analytics'),
#    (0.0, 'hrm'),
#    (0.0, 'strategy - innovation'),
#    (0.0, 'cloud computing')]},
#  {'id': 12,
#   'programName': 'powerful speaking',
#   'similarities': [(0.011344940233265304, 'analytics essential training'),
#    (0.011260136305227993, 'yammer 2018 essential training'),
#    (0.010550156864895957, 'microsoft dynamics crm customization config'),
#    (0.009804232396579958, 'sales secrets for small business'),
#    (0.009411423986220894, 'microsoft sharepoint'),
#    (0.006961866658890943, 'microsoft powerpoint'),
#    (0.0, 'cloud computing'),
#    (0.0, 'time management'),
#    (0.0, 'project management fundamentals'),
#    (0.0, 'email communication'),
#    (0.0, 'google drive essential training tutorial'),
#    (0.0, 'creating a business plan'),
#    (0.0, 'adwords essential training'),
#    (0.0, 'cbt nuggets microsoft sharepoint'),
#    (0.0, 'cbt nuggets - mpls fundamentals'),
#    (0.0, 'cbt nuggets cloud computing'),
#    (0.0, 'microsoft excel'),
#    (0.0, 'microsoft word'),
#    (0.0, 'google cloud platform fundamentals'),
#    (0.0, 'marketing with facebook and twitter'),
#    (0.0, 'html'),
#    (0.0, 'techniques and concepts of big data'),
#    (0.0, 'tpl - learning management system'),
#    (0.0, 'stress management at workplace'),
#    (0.0, 'campusnexus crm'),
#    (0.0, 'leadership'),
#    (0.0, 'helpful technique while operating computers'),
#    (0.0, 'microsoft onedrive'),
#    (0.0, 'microsoft office 365'),
#    (0.0, 'excel 2016 pivot tables in depth'),
#    (0.0, 'complete beginners introduction to sql'),
#    (0.0, 'sample'),
#    (0.0, 'et cases'),
#    (0.0, 'strategy - innovation'),
#    (0.0, 'hrm'),
#    (0.0, 'analytics'),
#    (0.0, 'business-intellegence features in depth'),
#    (0.0, 'timesshiksha')]},
#  {'id': 14,
#   'programName': 'cbt nuggets cloud computing',
#   'similarities': [(0.0, 'adwords essential training'),
#    (0.0, 'microsoft dynamics crm customization config'),
#    (0.0, 'time management'),
#    (0.0, 'project management fundamentals'),
#    (0.0, 'yammer 2018 essential training'),
#    (0.0, 'email communication'),
#    (0.0, 'google drive essential training tutorial'),
#    (0.0, 'analytics essential training'),
#    (0.0, 'creating a business plan'),
#    (0.0, 'sales secrets for small business'),
#    (0.0, 'cbt nuggets microsoft sharepoint'),
#    (0.0, 'cbt nuggets - mpls fundamentals'),
#    (0.0, 'cbt nuggets cloud computing'),
#    (0.0, 'powerful speaking'),
#    (0.0, 'microsoft powerpoint'),
#    (0.0, 'microsoft excel'),
#    (0.0, 'microsoft word'),
#    (0.0, 'google cloud platform fundamentals'),
#    (0.0, 'marketing with facebook and twitter'),
#    (0.0, 'html'),
#    (0.0, 'microsoft office 365'),
#    (0.0, 'tpl - learning management system'),
#    (0.0, 'stress management at workplace'),
#    (0.0, 'campusnexus crm'),
#    (0.0, 'leadership'),
#    (0.0, 'helpful technique while operating computers'),
#    (0.0, 'microsoft onedrive'),
#    (0.0, 'microsoft sharepoint'),
#    (0.0, 'excel 2016 pivot tables in depth'),
#    (0.0, 'techniques and concepts of big data'),
#    (0.0, 'complete beginners introduction to sql'),
#    (0.0, 'sample'),
#    (0.0, 'et cases'),
#    (0.0, 'strategy - innovation'),
#    (0.0, 'hrm'),
#    (0.0, 'analytics'),
#    (0.0, 'business-intellegence features in depth'),
#    (0.0, 'timesshiksha')]},
#  {'id': 15,
#   'programName': 'cbt nuggets - mpls fundamentals',
#   'similarities': [(0.0, 'adwords essential training'),
#    (0.0, 'microsoft dynamics crm customization config'),
#    (0.0, 'time management'),
#    (0.0, 'project management fundamentals'),
#    (0.0, 'yammer 2018 essential training'),
#    (0.0, 'email communication'),
#    (0.0, 'google drive essential training tutorial'),
#    (0.0, 'analytics essential training'),
#    (0.0, 'creating a business plan'),
#    (0.0, 'sales secrets for small business'),
#    (0.0, 'cbt nuggets microsoft sharepoint'),
#    (0.0, 'cbt nuggets - mpls fundamentals'),
#    (0.0, 'cbt nuggets cloud computing'),
#    (0.0, 'powerful speaking'),
#    (0.0, 'microsoft powerpoint'),
#    (0.0, 'microsoft excel'),
#    (0.0, 'microsoft word'),
#    (0.0, 'google cloud platform fundamentals'),
#    (0.0, 'marketing with facebook and twitter'),
#    (0.0, 'html'),
#    (0.0, 'microsoft office 365'),
#    (0.0, 'tpl - learning management system'),
#    (0.0, 'stress management at workplace'),
#    (0.0, 'campusnexus crm'),
#    (0.0, 'leadership'),
#    (0.0, 'helpful technique while operating computers'),
#    (0.0, 'microsoft onedrive'),
#    (0.0, 'microsoft sharepoint'),
#    (0.0, 'excel 2016 pivot tables in depth'),
#    (0.0, 'techniques and concepts of big data'),
#    (0.0, 'complete beginners introduction to sql'),
#    (0.0, 'sample'),
#    (0.0, 'et cases'),
#    (0.0, 'strategy - innovation'),
#    (0.0, 'hrm'),
#    (0.0, 'analytics'),
#    (0.0, 'business-intellegence features in depth'),
#    (0.0, 'timesshiksha')]},
#  {'id': 16,
#   'programName': 'cbt nuggets microsoft sharepoint',
#   'similarities': [(0.0, 'adwords essential training'),
#    (0.0, 'microsoft dynamics crm customization config'),
#    (0.0, 'time management'),
#    (0.0, 'project management fundamentals'),
#    (0.0, 'yammer 2018 essential training'),
#    (0.0, 'email communication'),
#    (0.0, 'google drive essential training tutorial'),
#    (0.0, 'analytics essential training'),
#    (0.0, 'creating a business plan'),
#    (0.0, 'sales secrets for small business'),
#    (0.0, 'cbt nuggets microsoft sharepoint'),
#    (0.0, 'cbt nuggets - mpls fundamentals'),
#    (0.0, 'cbt nuggets cloud computing'),
#    (0.0, 'powerful speaking'),
#    (0.0, 'microsoft powerpoint'),
#    (0.0, 'microsoft excel'),
#    (0.0, 'microsoft word'),
#    (0.0, 'google cloud platform fundamentals'),
#    (0.0, 'marketing with facebook and twitter'),
#    (0.0, 'html'),
#    (0.0, 'microsoft office 365'),
#    (0.0, 'tpl - learning management system'),
#    (0.0, 'stress management at workplace'),
#    (0.0, 'campusnexus crm'),
#    (0.0, 'leadership'),
#    (0.0, 'helpful technique while operating computers'),
#    (0.0, 'microsoft onedrive'),
#    (0.0, 'microsoft sharepoint'),
#    (0.0, 'excel 2016 pivot tables in depth'),
#    (0.0, 'techniques and concepts of big data'),
#    (0.0, 'complete beginners introduction to sql'),
#    (0.0, 'sample'),
#    (0.0, 'et cases'),
#    (0.0, 'strategy - innovation'),
#    (0.0, 'hrm'),
#    (0.0, 'analytics'),
#    (0.0, 'business-intellegence features in depth'),
#    (0.0, 'timesshiksha')]},
#  {'id': 18,
#   'programName': 'creating a business plan',
#   'similarities': [(0.02647230395290067,
#     'marketing with facebook and twitter'),
#    (0.02180262192988628, 'microsoft dynamics crm customization config'),
#    (0.015401507971672149, 'sales secrets for small business'),
#    (0.008423218296821636, 'business-intellegence features in depth'),
#    (0.008095618556061801, 'stress management at workplace'),
#    (0.007200180450852355, 'techniques and concepts of big data'),
#    (0.007152740148527754, 'google drive essential training tutorial'),
#    (0.007100236990320576, 'complete beginners introduction to sql'),
#    (0.0, 'cbt nuggets microsoft sharepoint'),
#    (0.0, 'cbt nuggets - mpls fundamentals'),
#    (0.0, 'cbt nuggets cloud computing'),
#    (0.0, 'adwords essential training'),
#    (0.0, 'analytics essential training'),
#    (0.0, 'powerful speaking'),
#    (0.0, 'email communication'),
#    (0.0, 'yammer 2018 essential training'),
#    (0.0, 'microsoft powerpoint'),
#    (0.0, 'microsoft excel'),
#    (0.0, 'project management fundamentals'),
#    (0.0, 'microsoft word'),
#    (0.0, 'time management'),
#    (0.0, 'cloud computing'),
#    (0.0, 'google cloud platform fundamentals'),
#    (0.0, 'html'),
#    (0.0, 'analytics'),
#    (0.0, 'hrm'),
#    (0.0, 'strategy - innovation'),
#    (0.0, 'et cases'),
#    (0.0, 'sample'),
#    (0.0, 'excel 2016 pivot tables in depth'),
#    (0.0, 'microsoft office 365'),
#    (0.0, 'microsoft sharepoint'),
#    (0.0, 'microsoft onedrive'),
#    (0.0, 'helpful technique while operating computers'),
#    (0.0, 'leadership'),
#    (0.0, 'campusnexus crm'),
#    (0.0, 'tpl - learning management system'),
#    (0.0, 'timesshiksha')]},
#  {'id': 19,
#   'programName': 'adwords essential training',
#   'similarities': [(0.03322282414315095, 'html'),
#    (0.02746619832949375, 'analytics essential training'),
#    (0.01700748313126698, 'google drive essential training tutorial'),
#    (0.009824760196299064, 'time management'),
#    (0.009705381638094415, 'email communication'),
#    (0.00866641125700674, 'sales secrets for small business'),
#    (0.008653767852678577, 'yammer 2018 essential training'),
#    (0.008594931151104705, 'microsoft powerpoint'),
#    (0.0, 'google cloud platform fundamentals'),
#    (0.0, 'microsoft dynamics crm customization config'),
#    (0.0, 'project management fundamentals'),
#    (0.0, 'microsoft word'),
#    (0.0, 'microsoft excel'),
#    (0.0, 'creating a business plan'),
#    (0.0, 'cbt nuggets microsoft sharepoint'),
#    (0.0, 'cbt nuggets - mpls fundamentals'),
#    (0.0, 'cbt nuggets cloud computing'),
#    (0.0, 'powerful speaking'),
#    (0.0, 'cloud computing'),
#    (0.0, 'marketing with facebook and twitter'),
#    (0.0, 'techniques and concepts of big data'),
#    (0.0, 'business-intellegence features in depth'),
#    (0.0, 'tpl - learning management system'),
#    (0.0, 'stress management at workplace'),
#    (0.0, 'campusnexus crm'),
#    (0.0, 'leadership'),
#    (0.0, 'helpful technique while operating computers'),
#    (0.0, 'microsoft onedrive'),
#    (0.0, 'microsoft sharepoint'),
#    (0.0, 'microsoft office 365'),
#    (0.0, 'excel 2016 pivot tables in depth'),
#    (0.0, 'complete beginners introduction to sql'),
#    (0.0, 'sample'),
#    (0.0, 'et cases'),
#    (0.0, 'strategy - innovation'),
#    (0.0, 'hrm'),
#    (0.0, 'analytics'),
#    (0.0, 'timesshiksha')]},
#  {'id': 20,
#   'programName': 'analytics essential training',
#   'similarities': [(0.02746619832949375, 'adwords essential training'),
#    (0.019303039584758017, 'yammer 2018 essential training'),
#    (0.0189683919021663, 'google drive essential training tutorial'),
#    (0.012958731906235867, 'microsoft sharepoint'),
#    (0.011344940233265304, 'powerful speaking'),
#    (0.01082438130619209, 'email communication'),
#    (0.009964413061433083, 'html'),
#    (0.009528713457019795, 'marketing with facebook and twitter'),
#    (0.009042967601286497, 'microsoft dynamics crm customization config'),
#    (0.0, 'cbt nuggets microsoft sharepoint'),
#    (0.0, 'google cloud platform fundamentals'),
#    (0.0, 'cbt nuggets - mpls fundamentals'),
#    (0.0, 'cbt nuggets cloud computing'),
#    (0.0, 'microsoft powerpoint'),
#    (0.0, 'microsoft excel'),
#    (0.0, 'microsoft word'),
#    (0.0, 'project management fundamentals'),
#    (0.0, 'time management'),
#    (0.0, 'creating a business plan'),
#    (0.0, 'cloud computing'),
#    (0.0, 'sales secrets for small business'),
#    (0.0, 'techniques and concepts of big data'),
#    (0.0, 'tpl - learning management system'),
#    (0.0, 'stress management at workplace'),
#    (0.0, 'campusnexus crm'),
#    (0.0, 'leadership'),
#    (0.0, 'helpful technique while operating computers'),
#    (0.0, 'microsoft onedrive'),
#    (0.0, 'microsoft office 365'),
#    (0.0, 'excel 2016 pivot tables in depth'),
#    (0.0, 'complete beginners introduction to sql'),
#    (0.0, 'sample'),
#    (0.0, 'et cases'),
#    (0.0, 'strategy - innovation'),
#    (0.0, 'hrm'),
#    (0.0, 'analytics'),
#    (0.0, 'business-intellegence features in depth'),
#    (0.0, 'timesshiksha')]},
#  {'id': 21,
#   'programName': 'google drive essential training tutorial',
#   'similarities': [(0.05463013118332469, 'microsoft onedrive'),
#    (0.027582446929493496, 'yammer 2018 essential training'),
#    (0.01949927972959015, 'stress management at workplace'),
#    (0.0189683919021663, 'analytics essential training'),
#    (0.01700748313126698, 'adwords essential training'),
#    (0.010954319869803079, 'microsoft word'),
#    (0.00943577156386661, 'microsoft dynamics crm customization config'),
#    (0.009028231931821977, 'cloud computing'),
#    (0.008648787722924583, 'microsoft sharepoint'),
#    (0.008579125199100479, 'microsoft excel'),
#    (0.00824185748203897, 'microsoft office 365'),
#    (0.0073585069473527335, 'microsoft powerpoint'),
#    (0.007152740148527754, 'creating a business plan'),
#    (0.006391868747117867, 'techniques and concepts of big data'),
#    (0.006303145209393716, 'complete beginners introduction to sql'),
#    (0.006048754541627474, 'sales secrets for small business'),
#    (0.0, 'cbt nuggets cloud computing'),
#    (0.0, 'project management fundamentals'),
#    (0.0, 'cbt nuggets - mpls fundamentals'),
#    (0.0, 'cbt nuggets microsoft sharepoint'),
#    (0.0, 'powerful speaking'),
#    (0.0, 'email communication'),
#    (0.0, 'marketing with facebook and twitter'),
#    (0.0, 'time management'),
#    (0.0, 'google cloud platform fundamentals'),
#    (0.0, 'html'),
#    (0.0, 'business-intellegence features in depth'),
#    (0.0, 'analytics'),
#    (0.0, 'hrm'),
#    (0.0, 'strategy - innovation'),
#    (0.0, 'et cases'),
#    (0.0, 'sample'),
#    (0.0, 'excel 2016 pivot tables in depth'),
#    (0.0, 'helpful technique while operating computers'),
#    (0.0, 'leadership'),
#    (0.0, 'campusnexus crm'),
#    (0.0, 'tpl - learning management system'),
#    (0.0, 'timesshiksha')]},
#  {'id': 22,
#   'programName': 'email communication',
#   'similarities': [(0.037730790874581796, 'yammer 2018 essential training'),
#    (0.015057705090207216, 'cloud computing'),
#    (0.0124404182327976, 'microsoft excel'),
#    (0.011091761809252731, 'html'),
#    (0.01082438130619209, 'analytics essential training'),
#    (0.009705381638094415, 'adwords essential training'),
#    (0.008023605011608571, 'microsoft office 365'),
#    (0.007986523142247922, 'microsoft dynamics crm customization config'),
#    (0.00784549323917507, 'microsoft word'),
#    (0.0062283074181738955, 'microsoft powerpoint'),
#    (0.0, 'powerful speaking'),
#    (0.0, 'cbt nuggets cloud computing'),
#    (0.0, 'cbt nuggets - mpls fundamentals'),
#    (0.0, 'cbt nuggets microsoft sharepoint'),
#    (0.0, 'google cloud platform fundamentals'),
#    (0.0, 'google drive essential training tutorial'),
#    (0.0, 'project management fundamentals'),
#    (0.0, 'time management'),
#    (0.0, 'creating a business plan'),
#    (0.0, 'marketing with facebook and twitter'),
#    (0.0, 'sales secrets for small business'),
#    (0.0, 'techniques and concepts of big data'),
#    (0.0, 'tpl - learning management system'),
#    (0.0, 'stress management at workplace'),
#    (0.0, 'campusnexus crm'),
#    (0.0, 'leadership'),
#    (0.0, 'helpful technique while operating computers'),
#    (0.0, 'microsoft onedrive'),
#    (0.0, 'microsoft sharepoint'),
#    (0.0, 'excel 2016 pivot tables in depth'),
#    (0.0, 'complete beginners introduction to sql'),
#    (0.0, 'sample'),
#    (0.0, 'et cases'),
#    (0.0, 'strategy - innovation'),
#    (0.0, 'hrm'),
#    (0.0, 'analytics'),
#    (0.0, 'business-intellegence features in depth'),
#    (0.0, 'timesshiksha')]},
#  {'id': 23,
#   'programName': 'yammer 2018 essential training',
#   'similarities': [(0.037730790874581796, 'email communication'),
#    (0.02829658642249245, 'microsoft dynamics crm customization config'),
#    (0.027582446929493496, 'google drive essential training tutorial'),
#    (0.02654244516009299, 'microsoft office 365'),
#    (0.019303039584758017, 'analytics essential training'),
#    (0.019221927049358892, 'html'),
#    (0.019157505044844696, 'microsoft powerpoint'),
#    (0.01830944787908185, 'microsoft onedrive'),
#    (0.01713636386917567, 'microsoft word'),
#    (0.011260136305227993, 'powerful speaking'),
#    (0.009457485904147559, 'marketing with facebook and twitter'),
#    (0.008653767852678577, 'adwords essential training'),
#    (0.0069930550139616875, 'techniques and concepts of big data'),
#    (0.006895986597058094, 'complete beginners introduction to sql'),
#    (0.0064908203217044136, 'business-intellegence features in depth'),
#    (0.0, 'creating a business plan'),
#    (0.0, 'time management'),
#    (0.0, 'cbt nuggets microsoft sharepoint'),
#    (0.0, 'cbt nuggets - mpls fundamentals'),
#    (0.0, 'cbt nuggets cloud computing'),
#    (0.0, 'microsoft excel'),
#    (0.0, 'project management fundamentals'),
#    (0.0, 'cloud computing'),
#    (0.0, 'google cloud platform fundamentals'),
#    (0.0, 'sales secrets for small business'),
#    (0.0, 'analytics'),
#    (0.0, 'hrm'),
#    (0.0, 'strategy - innovation'),
#    (0.0, 'et cases'),
#    (0.0, 'sample'),
#    (0.0, 'excel 2016 pivot tables in depth'),
#    (0.0, 'microsoft sharepoint'),
#    (0.0, 'helpful technique while operating computers'),
#    (0.0, 'leadership'),
#    (0.0, 'campusnexus crm'),
#    (0.0, 'stress management at workplace'),
#    (0.0, 'tpl - learning management system'),
#    (0.0, 'timesshiksha')]},
#  {'id': 24,
#   'programName': 'project management fundamentals',
#   'similarities': [(0.017599377235525272, 'time management'),
#    (0.006375714575306797, 'stress management at workplace'),
#    (0.006354699761002589, 'cloud computing'),
#    (0.006087620443390566, 'microsoft sharepoint'),
#    (0.005774383754429558, 'microsoft dynamics crm customization config'),
#    (0.005591800571362515, 'complete beginners introduction to sql'),
#    (0.0, 'powerful speaking'),
#    (0.0, 'cbt nuggets cloud computing'),
#    (0.0, 'microsoft powerpoint'),
#    (0.0, 'cbt nuggets - mpls fundamentals'),
#    (0.0, 'google cloud platform fundamentals'),
#    (0.0, 'creating a business plan'),
#    (0.0, 'adwords essential training'),
#    (0.0, 'analytics essential training'),
#    (0.0, 'google drive essential training tutorial'),
#    (0.0, 'email communication'),
#    (0.0, 'yammer 2018 essential training'),
#    (0.0, 'microsoft excel'),
#    (0.0, 'microsoft word'),
#    (0.0, 'cbt nuggets microsoft sharepoint'),
#    (0.0, 'marketing with facebook and twitter'),
#    (0.0, 'sales secrets for small business'),
#    (0.0, 'excel 2016 pivot tables in depth'),
#    (0.0, 'tpl - learning management system'),
#    (0.0, 'campusnexus crm'),
#    (0.0, 'leadership'),
#    (0.0, 'helpful technique while operating computers'),
#    (0.0, 'microsoft onedrive'),
#    (0.0, 'microsoft office 365'),
#    (0.0, 'sample'),
#    (0.0, 'html'),
#    (0.0, 'et cases'),
#    (0.0, 'strategy - innovation'),
#    (0.0, 'hrm'),
#    (0.0, 'analytics'),
#    (0.0, 'business-intellegence features in depth'),
#    (0.0, 'techniques and concepts of big data'),
#    (0.0, 'timesshiksha')]},
#  {'id': 25,
#   'programName': 'time management',
#   'similarities': [(0.03185145074872411, 'sales secrets for small business'),
#    (0.023426541611360707, 'marketing with facebook and twitter'),
#    (0.017599377235525272, 'project management fundamentals'),
#    (0.01655131547531532, 'microsoft dynamics crm customization config'),
#    (0.011825818192667504, 'techniques and concepts of big data'),
#    (0.009824760196299064, 'adwords essential training'),
#    (0.009391326004291317, 'microsoft powerpoint'),
#    (0.007023898961253048, 'stress management at workplace'),
#    (0.00700074768454221, 'cloud computing'),
#    (0.0067065158585422205, 'microsoft sharepoint'),
#    (0.006160288664245515, 'complete beginners introduction to sql'),
#    (0.0, 'excel 2016 pivot tables in depth'),
#    (0.0, 'email communication'),
#    (0.0, 'microsoft word'),
#    (0.0, 'microsoft excel'),
#    (0.0, 'tpl - learning management system'),
#    (0.0, 'powerful speaking'),
#    (0.0, 'cbt nuggets cloud computing'),
#    (0.0, 'cbt nuggets - mpls fundamentals'),
#    (0.0, 'cbt nuggets microsoft sharepoint'),
#    (0.0, 'creating a business plan'),
#    (0.0, 'campusnexus crm'),
#    (0.0, 'analytics essential training'),
#    (0.0, 'google drive essential training tutorial'),
#    (0.0, 'leadership'),
#    (0.0, 'yammer 2018 essential training'),
#    (0.0, 'helpful technique while operating computers'),
#    (0.0, 'microsoft onedrive'),
#    (0.0, 'google cloud platform fundamentals'),
#    (0.0, 'html'),
#    (0.0, 'microsoft office 365'),
#    (0.0, 'business-intellegence features in depth'),
#    (0.0, 'analytics'),
#    (0.0, 'hrm'),
#    (0.0, 'strategy - innovation'),
#    (0.0, 'et cases'),
#    (0.0, 'sample'),
#    (0.0, 'timesshiksha')]},
#  {'id': 26,
#   'programName': 'microsoft dynamics crm customization config',
#   'similarities': [(0.03109789353265017,
#     'marketing with facebook and twitter'),
#    (0.02829658642249245, 'yammer 2018 essential training'),
#    (0.02180262192988628, 'creating a business plan'),
#    (0.021660635907515383, 'microsoft powerpoint'),
#    (0.019288356466714653, 'stress management at workplace'),
#    (0.01778329404525629, 'microsoft word'),
#    (0.01655131547531532, 'time management'),
#    (0.014449397244906799, 'business-intellegence features in depth'),
#    (0.013055212637363308, 'complete beginners introduction to sql'),
#    (0.010550156864895957, 'powerful speaking'),
#    (0.00943577156386661, 'google drive essential training tutorial'),
#    (0.009042967601286497, 'analytics essential training'),
#    (0.007986523142247922, 'email communication'),
#    (0.007814880827471584, 'sales secrets for small business'),
#    (0.007280328955481258, 'excel 2016 pivot tables in depth'),
#    (0.006767407101504312, 'microsoft excel'),
#    (0.00670312677584537, 'microsoft office 365'),
#    (0.006645185070856205, 'cloud computing'),
#    (0.00636589705397437, 'microsoft sharepoint'),
#    (0.005774383754429558, 'project management fundamentals'),
#    (0.0, 'html'),
#    (0.0, 'microsoft onedrive'),
#    (0.0, 'tpl - learning management system'),
#    (0.0, 'campusnexus crm'),
#    (0.0, 'leadership'),
#    (0.0, 'helpful technique while operating computers'),
#    (0.0, 'cbt nuggets cloud computing'),
#    (0.0, 'cbt nuggets - mpls fundamentals'),
#    (0.0, 'cbt nuggets microsoft sharepoint'),
#    (0.0, 'adwords essential training'),
#    (0.0, 'techniques and concepts of big data'),
#    (0.0, 'sample'),
#    (0.0, 'et cases'),
#    (0.0, 'strategy - innovation'),
#    (0.0, 'hrm'),
#    (0.0, 'analytics'),
#    (0.0, 'google cloud platform fundamentals'),
#    (0.0, 'timesshiksha')]},
#  {'id': 27,
#   'programName': 'google cloud platform fundamentals',
#   'similarities': [(0.0, 'adwords essential training'),
#    (0.0, 'microsoft dynamics crm customization config'),
#    (0.0, 'time management'),
#    (0.0, 'project management fundamentals'),
#    (0.0, 'yammer 2018 essential training'),
#    (0.0, 'email communication'),
#    (0.0, 'google drive essential training tutorial'),
#    (0.0, 'analytics essential training'),
#    (0.0, 'creating a business plan'),
#    (0.0, 'sales secrets for small business'),
#    (0.0, 'cbt nuggets microsoft sharepoint'),
#    (0.0, 'cbt nuggets - mpls fundamentals'),
#    (0.0, 'cbt nuggets cloud computing'),
#    (0.0, 'powerful speaking'),
#    (0.0, 'microsoft powerpoint'),
#    (0.0, 'microsoft excel'),
#    (0.0, 'microsoft word'),
#    (0.0, 'google cloud platform fundamentals'),
#    (0.0, 'marketing with facebook and twitter'),
#    (0.0, 'html'),
#    (0.0, 'microsoft office 365'),
#    (0.0, 'tpl - learning management system'),
#    (0.0, 'stress management at workplace'),
#    (0.0, 'campusnexus crm'),
#    (0.0, 'leadership'),
#    (0.0, 'helpful technique while operating computers'),
#    (0.0, 'microsoft onedrive'),
#    (0.0, 'microsoft sharepoint'),
#    (0.0, 'excel 2016 pivot tables in depth'),
#    (0.0, 'techniques and concepts of big data'),
#    (0.0, 'complete beginners introduction to sql'),
#    (0.0, 'sample'),
#    (0.0, 'et cases'),
#    (0.0, 'strategy - innovation'),
#    (0.0, 'hrm'),
#    (0.0, 'analytics'),
#    (0.0, 'business-intellegence features in depth'),
#    (0.0, 'timesshiksha')]},
#  {'id': 29,
#   'programName': 'sales secrets for small business',
#   'similarities': [(0.03185145074872411, 'time management'),
#    (0.015401507971672149, 'creating a business plan'),
#    (0.011193225633634214, 'marketing with facebook and twitter'),
#    (0.010078151888990885, 'microsoft onedrive'),
#    (0.009804232396579958, 'powerful speaking'),
#    (0.00866641125700674, 'adwords essential training'),
#    (0.007814880827471584, 'microsoft dynamics crm customization config'),
#    (0.007123141463276355, 'business-intellegence features in depth'),
#    (0.006846104918035031, 'stress management at workplace'),
#    (0.006088872697492702, 'techniques and concepts of big data'),
#    (0.006048754541627474, 'google drive essential training tutorial'),
#    (0.006004354953489098, 'complete beginners introduction to sql'),
#    (0.0, 'cbt nuggets cloud computing'),
#    (0.0, 'cbt nuggets - mpls fundamentals'),
#    (0.0, 'cbt nuggets microsoft sharepoint'),
#    (0.0, 'microsoft powerpoint'),
#    (0.0, 'microsoft excel'),
#    (0.0, 'analytics essential training'),
#    (0.0, 'email communication'),
#    (0.0, 'yammer 2018 essential training'),
#    (0.0, 'microsoft word'),
#    (0.0, 'project management fundamentals'),
#    (0.0, 'cloud computing'),
#    (0.0, 'google cloud platform fundamentals'),
#    (0.0, 'html'),
#    (0.0, 'analytics'),
#    (0.0, 'hrm'),
#    (0.0, 'strategy - innovation'),
#    (0.0, 'et cases'),
#    (0.0, 'sample'),
#    (0.0, 'excel 2016 pivot tables in depth'),
#    (0.0, 'microsoft office 365'),
#    (0.0, 'microsoft sharepoint'),
#    (0.0, 'helpful technique while operating computers'),
#    (0.0, 'leadership'),
#    (0.0, 'campusnexus crm'),
#    (0.0, 'tpl - learning management system'),
#    (0.0, 'timesshiksha')]},
#  {'id': 30,
#   'programName': 'marketing with facebook and twitter',
#   'similarities': [(0.03109789353265017,
#     'microsoft dynamics crm customization config'),
#    (0.02647230395290067, 'creating a business plan'),
#    (0.023426541611360707, 'time management'),
#    (0.02332795157904411, 'complete beginners introduction to sql'),
#    (0.011193225633634214, 'sales secrets for small business'),
#    (0.009968948764524173, 'excel 2016 pivot tables in depth'),
#    (0.009528713457019795, 'analytics essential training'),
#    (0.009457485904147559, 'yammer 2018 essential training'),
#    (0.00794817393062047, 'microsoft powerpoint'),
#    (0.0, 'cbt nuggets cloud computing'),
#    (0.0, 'cbt nuggets - mpls fundamentals'),
#    (0.0, 'cbt nuggets microsoft sharepoint'),
#    (0.0, 'powerful speaking'),
#    (0.0, 'google cloud platform fundamentals'),
#    (0.0, 'adwords essential training'),
#    (0.0, 'google drive essential training tutorial'),
#    (0.0, 'email communication'),
#    (0.0, 'project management fundamentals'),
#    (0.0, 'microsoft excel'),
#    (0.0, 'microsoft word'),
#    (0.0, 'cloud computing'),
#    (0.0, 'html'),
#    (0.0, 'microsoft sharepoint'),
#    (0.0, 'tpl - learning management system'),
#    (0.0, 'stress management at workplace'),
#    (0.0, 'campusnexus crm'),
#    (0.0, 'leadership'),
#    (0.0, 'helpful technique while operating computers'),
#    (0.0, 'microsoft onedrive'),
#    (0.0, 'microsoft office 365'),
#    (0.0, 'techniques and concepts of big data'),
#    (0.0, 'sample'),
#    (0.0, 'et cases'),
#    (0.0, 'strategy - innovation'),
#    (0.0, 'hrm'),
#    (0.0, 'analytics'),
#    (0.0, 'business-intellegence features in depth'),
#    (0.0, 'timesshiksha')]},
#  {'id': 31,
#   'programName': 'techniques and concepts of big data',
#   'similarities': [(0.012689901205177052,
#     'complete beginners introduction to sql'),
#    (0.011834114779026425, 'microsoft sharepoint'),
#    (0.011825818192667504, 'time management'),
#    (0.010452922843046, 'cloud computing'),
#    (0.009011504099177827, 'microsoft onedrive'),
#    (0.007234448639620971, 'stress management at workplace'),
#    (0.007219763334626501, 'html'),
#    (0.007200180450852355, 'creating a business plan'),
#    (0.0069930550139616875, 'yammer 2018 essential training'),
#    (0.006391868747117867, 'google drive essential training tutorial'),
#    (0.006088872697492702, 'sales secrets for small business'),
#    (0.005972159854408911, 'business-intellegence features in depth'),
#    (0.005109689380715637, 'microsoft powerpoint'),
#    (0.0, 'email communication'),
#    (0.0, 'microsoft word'),
#    (0.0, 'adwords essential training'),
#    (0.0, 'analytics essential training'),
#    (0.0, 'powerful speaking'),
#    (0.0, 'project management fundamentals'),
#    (0.0, 'cbt nuggets - mpls fundamentals'),
#    (0.0, 'cbt nuggets cloud computing'),
#    (0.0, 'microsoft excel'),
#    (0.0, 'cbt nuggets microsoft sharepoint'),
#    (0.0, 'marketing with facebook and twitter'),
#    (0.0, 'microsoft dynamics crm customization config'),
#    (0.0, 'google cloud platform fundamentals'),
#    (0.0, 'analytics'),
#    (0.0, 'hrm'),
#    (0.0, 'strategy - innovation'),
#    (0.0, 'et cases'),
#    (0.0, 'sample'),
#    (0.0, 'excel 2016 pivot tables in depth'),
#    (0.0, 'microsoft office 365'),
#    (0.0, 'helpful technique while operating computers'),
#    (0.0, 'leadership'),
#    (0.0, 'campusnexus crm'),
#    (0.0, 'tpl - learning management system'),
#    (0.0, 'timesshiksha')]},
#  {'id': 32,
#   'programName': 'business-intellegence features in depth',
#   'similarities': [(0.014449397244906799,
#     'microsoft dynamics crm customization config'),
#    (0.012868004592484016, 'microsoft powerpoint'),
#    (0.012459059251997608, 'complete beginners introduction to sql'),
#    (0.011504022416499298, 'stress management at workplace'),
#    (0.010467387023083464, 'microsoft office 365'),
#    (0.008423218296821636, 'creating a business plan'),
#    (0.007123141463276355, 'sales secrets for small business'),
#    (0.006701246662113969, 'html'),
#    (0.006635905805086771, 'excel 2016 pivot tables in depth'),
#    (0.0064908203217044136, 'yammer 2018 essential training'),
#    (0.006168385569507459, 'microsoft excel'),
#    (0.005972159854408911, 'techniques and concepts of big data'),
#    (0.0, 'google drive essential training tutorial'),
#    (0.0, 'email communication'),
#    (0.0, 'cloud computing'),
#    (0.0, 'analytics essential training'),
#    (0.0, 'adwords essential training'),
#    (0.0, 'project management fundamentals'),
#    (0.0, 'cbt nuggets - mpls fundamentals'),
#    (0.0, 'cbt nuggets cloud computing'),
#    (0.0, 'powerful speaking'),
#    (0.0, 'microsoft word'),
#    (0.0, 'cbt nuggets microsoft sharepoint'),
#    (0.0, 'marketing with facebook and twitter'),
#    (0.0, 'time management'),
#    (0.0, 'google cloud platform fundamentals'),
#    (0.0, 'analytics'),
#    (0.0, 'hrm'),
#    (0.0, 'strategy - innovation'),
#    (0.0, 'et cases'),
#    (0.0, 'sample'),
#    (0.0, 'microsoft sharepoint'),
#    (0.0, 'microsoft onedrive'),
#    (0.0, 'helpful technique while operating computers'),
#    (0.0, 'leadership'),
#    (0.0, 'campusnexus crm'),
#    (0.0, 'tpl - learning management system'),
#    (0.0, 'timesshiksha')]},
#  {'id': 34,
#   'programName': 'analytics',
#   'similarities': [(0.0, 'adwords essential training'),
#    (0.0, 'microsoft dynamics crm customization config'),
#    (0.0, 'time management'),
#    (0.0, 'project management fundamentals'),
#    (0.0, 'yammer 2018 essential training'),
#    (0.0, 'email communication'),
#    (0.0, 'google drive essential training tutorial'),
#    (0.0, 'analytics essential training'),
#    (0.0, 'creating a business plan'),
#    (0.0, 'sales secrets for small business'),
#    (0.0, 'cbt nuggets microsoft sharepoint'),
#    (0.0, 'cbt nuggets - mpls fundamentals'),
#    (0.0, 'cbt nuggets cloud computing'),
#    (0.0, 'powerful speaking'),
#    (0.0, 'microsoft powerpoint'),
#    (0.0, 'microsoft excel'),
#    (0.0, 'microsoft word'),
#    (0.0, 'google cloud platform fundamentals'),
#    (0.0, 'marketing with facebook and twitter'),
#    (0.0, 'html'),
#    (0.0, 'microsoft office 365'),
#    (0.0, 'tpl - learning management system'),
#    (0.0, 'stress management at workplace'),
#    (0.0, 'campusnexus crm'),
#    (0.0, 'leadership'),
#    (0.0, 'helpful technique while operating computers'),
#    (0.0, 'microsoft onedrive'),
#    (0.0, 'microsoft sharepoint'),
#    (0.0, 'excel 2016 pivot tables in depth'),
#    (0.0, 'techniques and concepts of big data'),
#    (0.0, 'complete beginners introduction to sql'),
#    (0.0, 'sample'),
#    (0.0, 'et cases'),
#    (0.0, 'strategy - innovation'),
#    (0.0, 'hrm'),
#    (0.0, 'analytics'),
#    (0.0, 'business-intellegence features in depth'),
#    (0.0, 'timesshiksha')]},
#  {'id': 35,
#   'programName': 'hrm',
#   'similarities': [(0.0, 'adwords essential training'),
#    (0.0, 'microsoft dynamics crm customization config'),
#    (0.0, 'time management'),
#    (0.0, 'project management fundamentals'),
#    (0.0, 'yammer 2018 essential training'),
#    (0.0, 'email communication'),
#    (0.0, 'google drive essential training tutorial'),
#    (0.0, 'analytics essential training'),
#    (0.0, 'creating a business plan'),
#    (0.0, 'sales secrets for small business'),
#    (0.0, 'cbt nuggets microsoft sharepoint'),
#    (0.0, 'cbt nuggets - mpls fundamentals'),
#    (0.0, 'cbt nuggets cloud computing'),
#    (0.0, 'powerful speaking'),
#    (0.0, 'microsoft powerpoint'),
#    (0.0, 'microsoft excel'),
#    (0.0, 'microsoft word'),
#    (0.0, 'google cloud platform fundamentals'),
#    (0.0, 'marketing with facebook and twitter'),
#    (0.0, 'html'),
#    (0.0, 'microsoft office 365'),
#    (0.0, 'tpl - learning management system'),
#    (0.0, 'stress management at workplace'),
#    (0.0, 'campusnexus crm'),
#    (0.0, 'leadership'),
#    (0.0, 'helpful technique while operating computers'),
#    (0.0, 'microsoft onedrive'),
#    (0.0, 'microsoft sharepoint'),
#    (0.0, 'excel 2016 pivot tables in depth'),
#    (0.0, 'techniques and concepts of big data'),
#    (0.0, 'complete beginners introduction to sql'),
#    (0.0, 'sample'),
#    (0.0, 'et cases'),
#    (0.0, 'strategy - innovation'),
#    (0.0, 'hrm'),
#    (0.0, 'analytics'),
#    (0.0, 'business-intellegence features in depth'),
#    (0.0, 'timesshiksha')]},
#  {'id': 36,
#   'programName': 'strategy - innovation',
#   'similarities': [(0.0, 'adwords essential training'),
#    (0.0, 'microsoft dynamics crm customization config'),
#    (0.0, 'time management'),
#    (0.0, 'project management fundamentals'),
#    (0.0, 'yammer 2018 essential training'),
#    (0.0, 'email communication'),
#    (0.0, 'google drive essential training tutorial'),
#    (0.0, 'analytics essential training'),
#    (0.0, 'creating a business plan'),
#    (0.0, 'sales secrets for small business'),
#    (0.0, 'cbt nuggets microsoft sharepoint'),
#    (0.0, 'cbt nuggets - mpls fundamentals'),
#    (0.0, 'cbt nuggets cloud computing'),
#    (0.0, 'powerful speaking'),
#    (0.0, 'microsoft powerpoint'),
#    (0.0, 'microsoft excel'),
#    (0.0, 'microsoft word'),
#    (0.0, 'google cloud platform fundamentals'),
#    (0.0, 'marketing with facebook and twitter'),
#    (0.0, 'html'),
#    (0.0, 'microsoft office 365'),
#    (0.0, 'tpl - learning management system'),
#    (0.0, 'stress management at workplace'),
#    (0.0, 'campusnexus crm'),
#    (0.0, 'leadership'),
#    (0.0, 'helpful technique while operating computers'),
#    (0.0, 'microsoft onedrive'),
#    (0.0, 'microsoft sharepoint'),
#    (0.0, 'excel 2016 pivot tables in depth'),
#    (0.0, 'techniques and concepts of big data'),
#    (0.0, 'complete beginners introduction to sql'),
#    (0.0, 'sample'),
#    (0.0, 'et cases'),
#    (0.0, 'strategy - innovation'),
#    (0.0, 'hrm'),
#    (0.0, 'analytics'),
#    (0.0, 'business-intellegence features in depth'),
#    (0.0, 'timesshiksha')]},
#  {'id': 38,
#   'programName': 'et cases',
#   'similarities': [(0.0, 'adwords essential training'),
#    (0.0, 'microsoft dynamics crm customization config'),
#    (0.0, 'time management'),
#    (0.0, 'project management fundamentals'),
#    (0.0, 'yammer 2018 essential training'),
#    (0.0, 'email communication'),
#    (0.0, 'google drive essential training tutorial'),
#    (0.0, 'analytics essential training'),
#    (0.0, 'creating a business plan'),
#    (0.0, 'sales secrets for small business'),
#    (0.0, 'cbt nuggets microsoft sharepoint'),
#    (0.0, 'cbt nuggets - mpls fundamentals'),
#    (0.0, 'cbt nuggets cloud computing'),
#    (0.0, 'powerful speaking'),
#    (0.0, 'microsoft powerpoint'),
#    (0.0, 'microsoft excel'),
#    (0.0, 'microsoft word'),
#    (0.0, 'google cloud platform fundamentals'),
#    (0.0, 'marketing with facebook and twitter'),
#    (0.0, 'html'),
#    (0.0, 'microsoft office 365'),
#    (0.0, 'tpl - learning management system'),
#    (0.0, 'stress management at workplace'),
#    (0.0, 'campusnexus crm'),
#    (0.0, 'leadership'),
#    (0.0, 'helpful technique while operating computers'),
#    (0.0, 'microsoft onedrive'),
#    (0.0, 'microsoft sharepoint'),
#    (0.0, 'excel 2016 pivot tables in depth'),
#    (0.0, 'techniques and concepts of big data'),
#    (0.0, 'complete beginners introduction to sql'),
#    (0.0, 'sample'),
#    (0.0, 'et cases'),
#    (0.0, 'strategy - innovation'),
#    (0.0, 'hrm'),
#    (0.0, 'analytics'),
#    (0.0, 'business-intellegence features in depth'),
#    (0.0, 'timesshiksha')]},
#  {'id': 39,
#   'programName': 'sample',
#   'similarities': [(0.0, 'adwords essential training'),
#    (0.0, 'microsoft dynamics crm customization config'),
#    (0.0, 'time management'),
#    (0.0, 'project management fundamentals'),
#    (0.0, 'yammer 2018 essential training'),
#    (0.0, 'email communication'),
#    (0.0, 'google drive essential training tutorial'),
#    (0.0, 'analytics essential training'),
#    (0.0, 'creating a business plan'),
#    (0.0, 'sales secrets for small business'),
#    (0.0, 'cbt nuggets microsoft sharepoint'),
#    (0.0, 'cbt nuggets - mpls fundamentals'),
#    (0.0, 'cbt nuggets cloud computing'),
#    (0.0, 'powerful speaking'),
#    (0.0, 'microsoft powerpoint'),
#    (0.0, 'microsoft excel'),
#    (0.0, 'microsoft word'),
#    (0.0, 'google cloud platform fundamentals'),
#    (0.0, 'marketing with facebook and twitter'),
#    (0.0, 'html'),
#    (0.0, 'microsoft office 365'),
#    (0.0, 'tpl - learning management system'),
#    (0.0, 'stress management at workplace'),
#    (0.0, 'campusnexus crm'),
#    (0.0, 'leadership'),
#    (0.0, 'helpful technique while operating computers'),
#    (0.0, 'microsoft onedrive'),
#    (0.0, 'microsoft sharepoint'),
#    (0.0, 'excel 2016 pivot tables in depth'),
#    (0.0, 'techniques and concepts of big data'),
#    (0.0, 'complete beginners introduction to sql'),
#    (0.0, 'sample'),
#    (0.0, 'et cases'),
#    (0.0, 'strategy - innovation'),
#    (0.0, 'hrm'),
#    (0.0, 'analytics'),
#    (0.0, 'business-intellegence features in depth'),
#    (0.0, 'timesshiksha')]},
#  {'id': 41,
#   'programName': 'complete beginners introduction to sql',
#   'similarities': [(0.02332795157904411,
#     'marketing with facebook and twitter'),
#    (0.013671243818585678, 'microsoft powerpoint'),
#    (0.013590377678593609, 'stress management at workplace'),
#    (0.013055212637363308, 'microsoft dynamics crm customization config'),
#    (0.012689901205177052, 'techniques and concepts of big data'),
#    (0.012459059251997608, 'business-intellegence features in depth'),
#    (0.007119548050189065, 'html'),
#    (0.007100236990320576, 'creating a business plan'),
#    (0.007050128523539538, 'excel 2016 pivot tables in depth'),
#    (0.006895986597058094, 'yammer 2018 essential training'),
#    (0.006553425007093747, 'microsoft excel'),
#    (0.00643506757712784, 'cloud computing'),
#    (0.006303145209393716, 'google drive essential training tutorial'),
#    (0.006164610510401622, 'microsoft sharepoint'),
#    (0.006160288664245515, 'time management'),
#    (0.006004354953489098, 'sales secrets for small business'),
#    (0.005591800571362515, 'project management fundamentals'),
#    (0.0, 'et cases'),
#    (0.0, 'adwords essential training'),
#    (0.0, 'microsoft word'),
#    (0.0, 'tpl - learning management system'),
#    (0.0, 'campusnexus crm'),
#    (0.0, 'powerful speaking'),
#    (0.0, 'cbt nuggets cloud computing'),
#    (0.0, 'cbt nuggets - mpls fundamentals'),
#    (0.0, 'cbt nuggets microsoft sharepoint'),
#    (0.0, 'leadership'),
#    (0.0, 'email communication'),
#    (0.0, 'analytics essential training'),
#    (0.0, 'strategy - innovation'),
#    (0.0, 'helpful technique while operating computers'),
#    (0.0, 'microsoft onedrive'),
#    (0.0, 'google cloud platform fundamentals'),
#    (0.0, 'microsoft office 365'),
#    (0.0, 'sample'),
#    (0.0, 'analytics'),
#    (0.0, 'hrm'),
#    (0.0, 'timesshiksha')]},
#  {'id': 42,
#   'programName': 'excel 2016 pivot tables in depth',
#   'similarities': [(0.016785065984257837, 'microsoft excel'),
#    (0.01609733997202804, 'microsoft powerpoint'),
#    (0.009968948764524173, 'marketing with facebook and twitter'),
#    (0.007280328955481258, 'microsoft dynamics crm customization config'),
#    (0.007050128523539538, 'complete beginners introduction to sql'),
#    (0.006635905805086771, 'business-intellegence features in depth'),
#    (0.0, 'analytics essential training'),
#    (0.0, 'time management'),
#    (0.0, 'project management fundamentals'),
#    (0.0, 'yammer 2018 essential training'),
#    (0.0, 'email communication'),
#    (0.0, 'google drive essential training tutorial'),
#    (0.0, 'microsoft word'),
#    (0.0, 'powerful speaking'),
#    (0.0, 'google cloud platform fundamentals'),
#    (0.0, 'creating a business plan'),
#    (0.0, 'cbt nuggets microsoft sharepoint'),
#    (0.0, 'cbt nuggets - mpls fundamentals'),
#    (0.0, 'cbt nuggets cloud computing'),
#    (0.0, 'adwords essential training'),
#    (0.0, 'cloud computing'),
#    (0.0, 'sales secrets for small business'),
#    (0.0, 'microsoft sharepoint'),
#    (0.0, 'tpl - learning management system'),
#    (0.0, 'stress management at workplace'),
#    (0.0, 'campusnexus crm'),
#    (0.0, 'leadership'),
#    (0.0, 'helpful technique while operating computers'),
#    (0.0, 'microsoft onedrive'),
#    (0.0, 'microsoft office 365'),
#    (0.0, 'html'),
#    (0.0, 'sample'),
#    (0.0, 'et cases'),
#    (0.0, 'strategy - innovation'),
#    (0.0, 'hrm'),
#    (0.0, 'analytics'),
#    (0.0, 'techniques and concepts of big data'),
#    (0.0, 'timesshiksha')]},
#  {'id': 43,
#   'programName': 'microsoft office 365',
#   'similarities': [(0.02654244516009299, 'yammer 2018 essential training'),
#    (0.017865862864608957, 'microsoft word'),
#    (0.012679796866727917, 'stress management at workplace'),
#    (0.010707407169730813, 'html'),
#    (0.010467387023083464, 'business-intellegence features in depth'),
#    (0.010441302062703255, 'microsoft excel'),
#    (0.00824185748203897, 'google drive essential training tutorial'),
#    (0.008023605011608571, 'email communication'),
#    (0.008015459045266854, 'microsoft onedrive'),
#    (0.00670312677584537, 'microsoft dynamics crm customization config'),
#    (0.0052274479744645035, 'microsoft powerpoint'),
#    (0.0, 'cloud computing'),
#    (0.0, 'project management fundamentals'),
#    (0.0, 'cbt nuggets microsoft sharepoint'),
#    (0.0, 'analytics essential training'),
#    (0.0, 'adwords essential training'),
#    (0.0, 'creating a business plan'),
#    (0.0, 'cbt nuggets - mpls fundamentals'),
#    (0.0, 'cbt nuggets cloud computing'),
#    (0.0, 'powerful speaking'),
#    (0.0, 'time management'),
#    (0.0, 'marketing with facebook and twitter'),
#    (0.0, 'google cloud platform fundamentals'),
#    (0.0, 'sales secrets for small business'),
#    (0.0, 'techniques and concepts of big data'),
#    (0.0, 'analytics'),
#    (0.0, 'hrm'),
#    (0.0, 'strategy - innovation'),
#    (0.0, 'et cases'),
#    (0.0, 'sample'),
#    (0.0, 'complete beginners introduction to sql'),
#    (0.0, 'excel 2016 pivot tables in depth'),
#    (0.0, 'microsoft sharepoint'),
#    (0.0, 'helpful technique while operating computers'),
#    (0.0, 'leadership'),
#    (0.0, 'campusnexus crm'),
#    (0.0, 'tpl - learning management system'),
#    (0.0, 'timesshiksha')]},
#  {'id': 44,
#   'programName': 'microsoft sharepoint',
#   'similarities': [(0.030024257494909633, 'cloud computing'),
#    (0.020334670873944447, 'stress management at workplace'),
#    (0.012958731906235867, 'analytics essential training'),
#    (0.011838091921246225, 'microsoft word'),
#    (0.011834114779026425, 'techniques and concepts of big data'),
#    (0.010956826818232531, 'microsoft excel'),
#    (0.009411423986220894, 'powerful speaking'),
#    (0.008648787722924583, 'google drive essential training tutorial'),
#    (0.008411211178473151, 'microsoft onedrive'),
#    (0.007952176189963365, 'microsoft powerpoint'),
#    (0.0067065158585422205, 'time management'),
#    (0.00636589705397437, 'microsoft dynamics crm customization config'),
#    (0.006164610510401622, 'complete beginners introduction to sql'),
#    (0.006087620443390566, 'project management fundamentals'),
#    (0.0, 'cbt nuggets microsoft sharepoint'),
#    (0.0, 'creating a business plan'),
#    (0.0, 'adwords essential training'),
#    (0.0, 'cbt nuggets - mpls fundamentals'),
#    (0.0, 'email communication'),
#    (0.0, 'cbt nuggets cloud computing'),
#    (0.0, 'yammer 2018 essential training'),
#    (0.0, 'marketing with facebook and twitter'),
#    (0.0, 'google cloud platform fundamentals'),
#    (0.0, 'sales secrets for small business'),
#    (0.0, 'html'),
#    (0.0, 'business-intellegence features in depth'),
#    (0.0, 'analytics'),
#    (0.0, 'hrm'),
#    (0.0, 'strategy - innovation'),
#    (0.0, 'et cases'),
#    (0.0, 'sample'),
#    (0.0, 'excel 2016 pivot tables in depth'),
#    (0.0, 'microsoft office 365'),
#    (0.0, 'helpful technique while operating computers'),
#    (0.0, 'leadership'),
#    (0.0, 'campusnexus crm'),
#    (0.0, 'tpl - learning management system'),
#    (0.0, 'timesshiksha')]},
#  {'id': 45,
#   'programName': 'microsoft onedrive',
#   'similarities': [(0.05463013118332469,
#     'google drive essential training tutorial'),
#    (0.01887904019433679, 'cloud computing'),
#    (0.01830944787908185, 'yammer 2018 essential training'),
#    (0.011949974174841156, 'html'),
#    (0.010078151888990885, 'sales secrets for small business'),
#    (0.009011504099177827, 'techniques and concepts of big data'),
#    (0.008411211178473151, 'microsoft sharepoint'),
#    (0.008343462238635394, 'microsoft excel'),
#    (0.008015459045266854, 'microsoft office 365'),
#    (0.0, 'adwords essential training'),
#    (0.0, 'email communication'),
#    (0.0, 'analytics essential training'),
#    (0.0, 'cbt nuggets microsoft sharepoint'),
#    (0.0, 'creating a business plan'),
#    (0.0, 'time management'),
#    (0.0, 'cbt nuggets - mpls fundamentals'),
#    (0.0, 'cbt nuggets cloud computing'),
#    (0.0, 'powerful speaking'),
#    (0.0, 'microsoft powerpoint'),
#    (0.0, 'microsoft word'),
#    (0.0, 'project management fundamentals'),
#    (0.0, 'marketing with facebook and twitter'),
#    (0.0, 'microsoft dynamics crm customization config'),
#    (0.0, 'google cloud platform fundamentals'),
#    (0.0, 'business-intellegence features in depth'),
#    (0.0, 'analytics'),
#    (0.0, 'hrm'),
#    (0.0, 'strategy - innovation'),
#    (0.0, 'et cases'),
#    (0.0, 'sample'),
#    (0.0, 'complete beginners introduction to sql'),
#    (0.0, 'excel 2016 pivot tables in depth'),
#    (0.0, 'helpful technique while operating computers'),
#    (0.0, 'leadership'),
#    (0.0, 'campusnexus crm'),
#    (0.0, 'stress management at workplace'),
#    (0.0, 'tpl - learning management system'),
#    (0.0, 'timesshiksha')]},
#  {'id': 46,
#   'programName': 'helpful technique while operating computers',
#   'similarities': [(0.0, 'adwords essential training'),
#    (0.0, 'microsoft dynamics crm customization config'),
#    (0.0, 'time management'),
#    (0.0, 'project management fundamentals'),
#    (0.0, 'yammer 2018 essential training'),
#    (0.0, 'email communication'),
#    (0.0, 'google drive essential training tutorial'),
#    (0.0, 'analytics essential training'),
#    (0.0, 'creating a business plan'),
#    (0.0, 'sales secrets for small business'),
#    (0.0, 'cbt nuggets microsoft sharepoint'),
#    (0.0, 'cbt nuggets - mpls fundamentals'),
#    (0.0, 'cbt nuggets cloud computing'),
#    (0.0, 'powerful speaking'),
#    (0.0, 'microsoft powerpoint'),
#    (0.0, 'microsoft excel'),
#    (0.0, 'microsoft word'),
#    (0.0, 'google cloud platform fundamentals'),
#    (0.0, 'marketing with facebook and twitter'),
#    (0.0, 'html'),
#    (0.0, 'microsoft office 365'),
#    (0.0, 'tpl - learning management system'),
#    (0.0, 'stress management at workplace'),
#    (0.0, 'campusnexus crm'),
#    (0.0, 'leadership'),
#    (0.0, 'helpful technique while operating computers'),
#    (0.0, 'microsoft onedrive'),
#    (0.0, 'microsoft sharepoint'),
#    (0.0, 'excel 2016 pivot tables in depth'),
#    (0.0, 'techniques and concepts of big data'),
#    (0.0, 'complete beginners introduction to sql'),
#    (0.0, 'sample'),
#    (0.0, 'et cases'),
#    (0.0, 'strategy - innovation'),
#    (0.0, 'hrm'),
#    (0.0, 'analytics'),
#    (0.0, 'business-intellegence features in depth'),
#    (0.0, 'timesshiksha')]},
#  {'id': 47,
#   'programName': 'leadership',
#   'similarities': [(0.0, 'adwords essential training'),
#    (0.0, 'microsoft dynamics crm customization config'),
#    (0.0, 'time management'),
#    (0.0, 'project management fundamentals'),
#    (0.0, 'yammer 2018 essential training'),
#    (0.0, 'email communication'),
#    (0.0, 'google drive essential training tutorial'),
#    (0.0, 'analytics essential training'),
#    (0.0, 'creating a business plan'),
#    (0.0, 'sales secrets for small business'),
#    (0.0, 'cbt nuggets microsoft sharepoint'),
#    (0.0, 'cbt nuggets - mpls fundamentals'),
#    (0.0, 'cbt nuggets cloud computing'),
#    (0.0, 'powerful speaking'),
#    (0.0, 'microsoft powerpoint'),
#    (0.0, 'microsoft excel'),
#    (0.0, 'microsoft word'),
#    (0.0, 'google cloud platform fundamentals'),
#    (0.0, 'marketing with facebook and twitter'),
#    (0.0, 'html'),
#    (0.0, 'microsoft office 365'),
#    (0.0, 'tpl - learning management system'),
#    (0.0, 'stress management at workplace'),
#    (0.0, 'campusnexus crm'),
#    (0.0, 'leadership'),
#    (0.0, 'helpful technique while operating computers'),
#    (0.0, 'microsoft onedrive'),
#    (0.0, 'microsoft sharepoint'),
#    (0.0, 'excel 2016 pivot tables in depth'),
#    (0.0, 'techniques and concepts of big data'),
#    (0.0, 'complete beginners introduction to sql'),
#    (0.0, 'sample'),
#    (0.0, 'et cases'),
#    (0.0, 'strategy - innovation'),
#    (0.0, 'hrm'),
#    (0.0, 'analytics'),
#    (0.0, 'business-intellegence features in depth'),
#    (0.0, 'timesshiksha')]},
#  {'id': 48,
#   'programName': 'campusnexus crm',
#   'similarities': [(0.0, 'adwords essential training'),
#    (0.0, 'microsoft dynamics crm customization config'),
#    (0.0, 'time management'),
#    (0.0, 'project management fundamentals'),
#    (0.0, 'yammer 2018 essential training'),
#    (0.0, 'email communication'),
#    (0.0, 'google drive essential training tutorial'),
#    (0.0, 'analytics essential training'),
#    (0.0, 'creating a business plan'),
#    (0.0, 'sales secrets for small business'),
#    (0.0, 'cbt nuggets microsoft sharepoint'),
#    (0.0, 'cbt nuggets - mpls fundamentals'),
#    (0.0, 'cbt nuggets cloud computing'),
#    (0.0, 'powerful speaking'),
#    (0.0, 'microsoft powerpoint'),
#    (0.0, 'microsoft excel'),
#    (0.0, 'microsoft word'),
#    (0.0, 'google cloud platform fundamentals'),
#    (0.0, 'marketing with facebook and twitter'),
#    (0.0, 'html'),
#    (0.0, 'microsoft office 365'),
#    (0.0, 'tpl - learning management system'),
#    (0.0, 'stress management at workplace'),
#    (0.0, 'campusnexus crm'),
#    (0.0, 'leadership'),
#    (0.0, 'helpful technique while operating computers'),
#    (0.0, 'microsoft onedrive'),
#    (0.0, 'microsoft sharepoint'),
#    (0.0, 'excel 2016 pivot tables in depth'),
#    (0.0, 'techniques and concepts of big data'),
#    (0.0, 'complete beginners introduction to sql'),
#    (0.0, 'sample'),
#    (0.0, 'et cases'),
#    (0.0, 'strategy - innovation'),
#    (0.0, 'hrm'),
#    (0.0, 'analytics'),
#    (0.0, 'business-intellegence features in depth'),
#    (0.0, 'timesshiksha')]},
#  {'id': 49,
#   'programName': 'stress management at workplace',
#   'similarities': [(0.020334670873944447, 'microsoft sharepoint'),
#    (0.01949927972959015, 'google drive essential training tutorial'),
#    (0.019288356466714653, 'microsoft dynamics crm customization config'),
#    (0.013590377678593609, 'complete beginners introduction to sql'),
#    (0.012679796866727917, 'microsoft office 365'),
#    (0.011504022416499298, 'business-intellegence features in depth'),
#    (0.008095618556061801, 'creating a business plan'),
#    (0.00733719910447041, 'cloud computing'),
#    (0.007234448639620971, 'techniques and concepts of big data'),
#    (0.007023898961253048, 'time management'),
#    (0.006846104918035031, 'sales secrets for small business'),
#    (0.006375714575306797, 'project management fundamentals'),
#    (0.0, 'cbt nuggets - mpls fundamentals'),
#    (0.0, 'cbt nuggets cloud computing'),
#    (0.0, 'adwords essential training'),
#    (0.0, 'analytics essential training'),
#    (0.0, 'powerful speaking'),
#    (0.0, 'microsoft powerpoint'),
#    (0.0, 'microsoft excel'),
#    (0.0, 'email communication'),
#    (0.0, 'yammer 2018 essential training'),
#    (0.0, 'microsoft word'),
#    (0.0, 'cbt nuggets microsoft sharepoint'),
#    (0.0, 'marketing with facebook and twitter'),
#    (0.0, 'google cloud platform fundamentals'),
#    (0.0, 'html'),
#    (0.0, 'analytics'),
#    (0.0, 'hrm'),
#    (0.0, 'strategy - innovation'),
#    (0.0, 'et cases'),
#    (0.0, 'sample'),
#    (0.0, 'excel 2016 pivot tables in depth'),
#    (0.0, 'microsoft onedrive'),
#    (0.0, 'helpful technique while operating computers'),
#    (0.0, 'leadership'),
#    (0.0, 'campusnexus crm'),
#    (0.0, 'tpl - learning management system'),
#    (0.0, 'timesshiksha')]},
#  {'id': 50,
#   'programName': 'tpl - learning management system',
#   'similarities': [(0.0, 'adwords essential training'),
#    (0.0, 'microsoft dynamics crm customization config'),
#    (0.0, 'time management'),
#    (0.0, 'project management fundamentals'),
#    (0.0, 'yammer 2018 essential training'),
#    (0.0, 'email communication'),
#    (0.0, 'google drive essential training tutorial'),
#    (0.0, 'analytics essential training'),
#    (0.0, 'creating a business plan'),
#    (0.0, 'sales secrets for small business'),
#    (0.0, 'cbt nuggets microsoft sharepoint'),
#    (0.0, 'cbt nuggets - mpls fundamentals'),
#    (0.0, 'cbt nuggets cloud computing'),
#    (0.0, 'powerful speaking'),
#    (0.0, 'microsoft powerpoint'),
#    (0.0, 'microsoft excel'),
#    (0.0, 'microsoft word'),
#    (0.0, 'google cloud platform fundamentals'),
#    (0.0, 'marketing with facebook and twitter'),
#    (0.0, 'html'),
#    (0.0, 'microsoft office 365'),
#    (0.0, 'tpl - learning management system'),
#    (0.0, 'stress management at workplace'),
#    (0.0, 'campusnexus crm'),
#    (0.0, 'leadership'),
#    (0.0, 'helpful technique while operating computers'),
#    (0.0, 'microsoft onedrive'),
#    (0.0, 'microsoft sharepoint'),
#    (0.0, 'excel 2016 pivot tables in depth'),
#    (0.0, 'techniques and concepts of big data'),
#    (0.0, 'complete beginners introduction to sql'),
#    (0.0, 'sample'),
#    (0.0, 'et cases'),
#    (0.0, 'strategy - innovation'),
#    (0.0, 'hrm'),
#    (0.0, 'analytics'),
#    (0.0, 'business-intellegence features in depth'),
#    (0.0, 'timesshiksha')]},
#  {'id': 51,
#   'programName': 'html',
#   'similarities': [(0.03322282414315095, 'adwords essential training'),
#    (0.019221927049358892, 'yammer 2018 essential training'),
#    (0.011949974174841156, 'microsoft onedrive'),
#    (0.011091761809252731, 'email communication'),
#    (0.010707407169730813, 'microsoft office 365'),
#    (0.009964413061433083, 'analytics essential training'),
#    (0.007219763334626501, 'techniques and concepts of big data'),
#    (0.007119548050189065, 'complete beginners introduction to sql'),
#    (0.006701246662113969, 'business-intellegence features in depth'),
#    (0.005733484993989474, 'microsoft powerpoint'),
#    (0.0, 'google drive essential training tutorial'),
#    (0.0, 'cloud computing'),
#    (0.0, 'creating a business plan'),
#    (0.0, 'time management'),
#    (0.0, 'cbt nuggets microsoft sharepoint'),
#    (0.0, 'cbt nuggets - mpls fundamentals'),
#    (0.0, 'cbt nuggets cloud computing'),
#    (0.0, 'powerful speaking'),
#    (0.0, 'microsoft excel'),
#    (0.0, 'microsoft word'),
#    (0.0, 'project management fundamentals'),
#    (0.0, 'marketing with facebook and twitter'),
#    (0.0, 'microsoft dynamics crm customization config'),
#    (0.0, 'google cloud platform fundamentals'),
#    (0.0, 'sales secrets for small business'),
#    (0.0, 'analytics'),
#    (0.0, 'hrm'),
#    (0.0, 'strategy - innovation'),
#    (0.0, 'et cases'),
#    (0.0, 'sample'),
#    (0.0, 'excel 2016 pivot tables in depth'),
#    (0.0, 'microsoft sharepoint'),
#    (0.0, 'helpful technique while operating computers'),
#    (0.0, 'leadership'),
#    (0.0, 'campusnexus crm'),
#    (0.0, 'stress management at workplace'),
#    (0.0, 'tpl - learning management system'),
#    (0.0, 'timesshiksha')]},
#  {'id': 52,
#   'programName': 'cloud computing',
#   'similarities': [(0.030024257494909633, 'microsoft sharepoint'),
#    (0.01887904019433679, 'microsoft onedrive'),
#    (0.015057705090207216, 'email communication'),
#    (0.010452922843046, 'techniques and concepts of big data'),
#    (0.009028231931821977, 'google drive essential training tutorial'),
#    (0.00733719910447041, 'stress management at workplace'),
#    (0.00700074768454221, 'time management'),
#    (0.006645185070856205, 'microsoft dynamics crm customization config'),
#    (0.00643506757712784, 'complete beginners introduction to sql'),
#    (0.006354699761002589, 'project management fundamentals'),
#    (0.0, 'powerful speaking'),
#    (0.0, 'cbt nuggets cloud computing'),
#    (0.0, 'cbt nuggets - mpls fundamentals'),
#    (0.0, 'cbt nuggets microsoft sharepoint'),
#    (0.0, 'creating a business plan'),
#    (0.0, 'adwords essential training'),
#    (0.0, 'analytics essential training'),
#    (0.0, 'microsoft powerpoint'),
#    (0.0, 'microsoft excel'),
#    (0.0, 'microsoft word'),
#    (0.0, 'yammer 2018 essential training'),
#    (0.0, 'marketing with facebook and twitter'),
#    (0.0, 'google cloud platform fundamentals'),
#    (0.0, 'sales secrets for small business'),
#    (0.0, 'html'),
#    (0.0, 'business-intellegence features in depth'),
#    (0.0, 'analytics'),
#    (0.0, 'hrm'),
#    (0.0, 'strategy - innovation'),
#    (0.0, 'et cases'),
#    (0.0, 'sample'),
#    (0.0, 'excel 2016 pivot tables in depth'),
#    (0.0, 'microsoft office 365'),
#    (0.0, 'helpful technique while operating computers'),
#    (0.0, 'leadership'),
#    (0.0, 'campusnexus crm'),
#    (0.0, 'tpl - learning management system'),
#    (0.0, 'timesshiksha')]}]

# %%
for i in corr:
    print(i['programName'])
# Out:
# timesshiksha
# microsoft word
# microsoft excel
# microsoft powerpoint
# powerful speaking
# cbt nuggets cloud computing
# cbt nuggets - mpls fundamentals
# cbt nuggets microsoft sharepoint
# creating a business plan
# adwords essential training
# analytics essential training
# google drive essential training tutorial
# email communication
# yammer 2018 essential training
# project management fundamentals
# time management
# microsoft dynamics crm customization config
# google cloud platform fundamentals
# sales secrets for small business
# marketing with facebook and twitter
# techniques and concepts of big data
# business-intellegence features in depth
# analytics
# hrm
# strategy - innovation
# et cases
# sample
# complete beginners introduction to sql
# excel 2016 pivot tables in depth
# microsoft office 365
# microsoft sharepoint
# microsoft onedrive
# helpful technique while operating computers
# leadership
# campusnexus crm
# stress management at workplace
# tpl - learning management system
# html
# cloud computing

# %%
corr
# Out:
# [{'id': 1,
#   'programName': 'timesshiksha',
#   'similarities': [(0.03108797179007013, 'microsoft powerpoint'),
#    (0.0, 'adwords essential training'),
#    (0.0, 'microsoft dynamics crm customization config'),
#    (0.0, 'time management'),
#    (0.0, 'project management fundamentals'),
#    (0.0, 'yammer 2018 essential training'),
#    (0.0, 'email communication'),
#    (0.0, 'google drive essential training tutorial'),
#    (0.0, 'analytics essential training'),
#    (0.0, 'creating a business plan'),
#    (0.0, 'sales secrets for small business'),
#    (0.0, 'cbt nuggets microsoft sharepoint'),
#    (0.0, 'cbt nuggets - mpls fundamentals'),
#    (0.0, 'cbt nuggets cloud computing'),
#    (0.0, 'powerful speaking'),
#    (0.0, 'microsoft excel'),
#    (0.0, 'microsoft word'),
#    (0.0, 'google cloud platform fundamentals'),
#    (0.0, 'cloud computing'),
#    (0.0, 'html'),
#    (0.0, 'microsoft office 365'),
#    (0.0, 'tpl - learning management system'),
#    (0.0, 'stress management at workplace'),
#    (0.0, 'campusnexus crm'),
#    (0.0, 'leadership'),
#    (0.0, 'helpful technique while operating computers'),
#    (0.0, 'microsoft onedrive'),
#    (0.0, 'microsoft sharepoint'),
#    (0.0, 'excel 2016 pivot tables in depth'),
#    (0.0, 'techniques and concepts of big data'),
#    (0.0, 'complete beginners introduction to sql'),
#    (0.0, 'sample'),
#    (0.0, 'et cases'),
#    (0.0, 'strategy - innovation'),
#    (0.0, 'hrm'),
#    (0.0, 'analytics'),
#    (0.0, 'business-intellegence features in depth'),
#    (0.0, 'marketing with facebook and twitter')]},
#  {'id': 6,
#   'programName': 'microsoft word',
#   'similarities': [(0.02127814188250297, 'microsoft powerpoint'),
#    (0.017865862864608957, 'microsoft office 365'),
#    (0.01778329404525629, 'microsoft dynamics crm customization config'),
#    (0.01713636386917567, 'yammer 2018 essential training'),
#    (0.011838091921246225, 'microsoft sharepoint'),
#    (0.010954319869803079, 'google drive essential training tutorial'),
#    (0.00784549323917507, 'email communication'),
#    (0.0, 'adwords essential training'),
#    (0.0, 'time management'),
#    (0.0, 'project management fundamentals'),
#    (0.0, 'analytics essential training'),
#    (0.0, 'cloud computing'),
#    (0.0, 'creating a business plan'),
#    (0.0, 'google cloud platform fundamentals'),
#    (0.0, 'cbt nuggets - mpls fundamentals'),
#    (0.0, 'cbt nuggets cloud computing'),
#    (0.0, 'powerful speaking'),
#    (0.0, 'microsoft excel'),
#    (0.0, 'cbt nuggets microsoft sharepoint'),
#    (0.0, 'marketing with facebook and twitter'),
#    (0.0, 'sales secrets for small business'),
#    (0.0, 'html'),
#    (0.0, 'tpl - learning management system'),
#    (0.0, 'stress management at workplace'),
#    (0.0, 'campusnexus crm'),
#    (0.0, 'leadership'),
#    (0.0, 'helpful technique while operating computers'),
#    (0.0, 'microsoft onedrive'),
#    (0.0, 'excel 2016 pivot tables in depth'),
#    (0.0, 'complete beginners introduction to sql'),
#    (0.0, 'sample'),
#    (0.0, 'et cases'),
#    (0.0, 'strategy - innovation'),
#    (0.0, 'hrm'),
#    (0.0, 'analytics'),
#    (0.0, 'business-intellegence features in depth'),
#    (0.0, 'techniques and concepts of big data'),
#    (0.0, 'timesshiksha')]},
#  {'id': 7,
#   'programName': 'microsoft excel',
#   'similarities': [(0.016785065984257837, 'excel 2016 pivot tables in depth'),
#    (0.0124404182327976, 'email communication'),
#    (0.010956826818232531, 'microsoft sharepoint'),
#    (0.010441302062703255, 'microsoft office 365'),
#    (0.008579125199100479, 'google drive essential training tutorial'),
#    (0.008343462238635394, 'microsoft onedrive'),
#    (0.006767407101504312, 'microsoft dynamics crm customization config'),
#    (0.006553425007093747, 'complete beginners introduction to sql'),
#    (0.006168385569507459, 'business-intellegence features in depth'),
#    (0.0, 'cbt nuggets cloud computing'),
#    (0.0, 'powerful speaking'),
#    (0.0, 'time management'),
#    (0.0, 'cbt nuggets - mpls fundamentals'),
#    (0.0, 'cbt nuggets microsoft sharepoint'),
#    (0.0, 'creating a business plan'),
#    (0.0, 'adwords essential training'),
#    (0.0, 'analytics essential training'),
#    (0.0, 'microsoft powerpoint'),
#    (0.0, 'microsoft word'),
#    (0.0, 'yammer 2018 essential training'),
#    (0.0, 'project management fundamentals'),
#    (0.0, 'cloud computing'),
#    (0.0, 'marketing with facebook and twitter'),
#    (0.0, 'google cloud platform fundamentals'),
#    (0.0, 'sales secrets for small business'),
#    (0.0, 'html'),
#    (0.0, 'techniques and concepts of big data'),
#    (0.0, 'analytics'),
#    (0.0, 'hrm'),
#    (0.0, 'strategy - innovation'),
#    (0.0, 'et cases'),
#    (0.0, 'sample'),
#    (0.0, 'helpful technique while operating computers'),
#    (0.0, 'leadership'),
#    (0.0, 'campusnexus crm'),
#    (0.0, 'stress management at workplace'),
#    (0.0, 'tpl - learning management system'),
#    (0.0, 'timesshiksha')]},
#  {'id': 8,
#   'programName': 'microsoft powerpoint',
#   'similarities': [(0.03108797179007013, 'timesshiksha'),
#    (0.021660635907515383, 'microsoft dynamics crm customization config'),
#    (0.02127814188250297, 'microsoft word'),
#    (0.019157505044844696, 'yammer 2018 essential training'),
#    (0.01609733997202804, 'excel 2016 pivot tables in depth'),
#    (0.013671243818585678, 'complete beginners introduction to sql'),
#    (0.012868004592484016, 'business-intellegence features in depth'),
#    (0.009391326004291317, 'time management'),
#    (0.008594931151104705, 'adwords essential training'),
#    (0.007952176189963365, 'microsoft sharepoint'),
#    (0.00794817393062047, 'marketing with facebook and twitter'),
#    (0.0073585069473527335, 'google drive essential training tutorial'),
#    (0.006961866658890943, 'powerful speaking'),
#    (0.0062283074181738955, 'email communication'),
#    (0.005733484993989474, 'html'),
#    (0.0052274479744645035, 'microsoft office 365'),
#    (0.005109689380715637, 'techniques and concepts of big data'),
#    (0.0, 'sample'),
#    (0.0, 'analytics essential training'),
#    (0.0, 'tpl - learning management system'),
#    (0.0, 'microsoft excel'),
#    (0.0, 'stress management at workplace'),
#    (0.0, 'cbt nuggets cloud computing'),
#    (0.0, 'cbt nuggets - mpls fundamentals'),
#    (0.0, 'cbt nuggets microsoft sharepoint'),
#    (0.0, 'creating a business plan'),
#    (0.0, 'campusnexus crm'),
#    (0.0, 'leadership'),
#    (0.0, 'et cases'),
#    (0.0, 'project management fundamentals'),
#    (0.0, 'helpful technique while operating computers'),
#    (0.0, 'microsoft onedrive'),
#    (0.0, 'google cloud platform fundamentals'),
#    (0.0, 'sales secrets for small business'),
#    (0.0, 'analytics'),
#    (0.0, 'hrm'),
#    (0.0, 'strategy - innovation'),
#    (0.0, 'cloud computing')]},
#  {'id': 12,
#   'programName': 'powerful speaking',
#   'similarities': [(0.011344940233265304, 'analytics essential training'),
#    (0.011260136305227993, 'yammer 2018 essential training'),
#    (0.010550156864895957, 'microsoft dynamics crm customization config'),
#    (0.009804232396579958, 'sales secrets for small business'),
#    (0.009411423986220894, 'microsoft sharepoint'),
#    (0.006961866658890943, 'microsoft powerpoint'),
#    (0.0, 'cloud computing'),
#    (0.0, 'time management'),
#    (0.0, 'project management fundamentals'),
#    (0.0, 'email communication'),
#    (0.0, 'google drive essential training tutorial'),
#    (0.0, 'creating a business plan'),
#    (0.0, 'adwords essential training'),
#    (0.0, 'cbt nuggets microsoft sharepoint'),
#    (0.0, 'cbt nuggets - mpls fundamentals'),
#    (0.0, 'cbt nuggets cloud computing'),
#    (0.0, 'microsoft excel'),
#    (0.0, 'microsoft word'),
#    (0.0, 'google cloud platform fundamentals'),
#    (0.0, 'marketing with facebook and twitter'),
#    (0.0, 'html'),
#    (0.0, 'techniques and concepts of big data'),
#    (0.0, 'tpl - learning management system'),
#    (0.0, 'stress management at workplace'),
#    (0.0, 'campusnexus crm'),
#    (0.0, 'leadership'),
#    (0.0, 'helpful technique while operating computers'),
#    (0.0, 'microsoft onedrive'),
#    (0.0, 'microsoft office 365'),
#    (0.0, 'excel 2016 pivot tables in depth'),
#    (0.0, 'complete beginners introduction to sql'),
#    (0.0, 'sample'),
#    (0.0, 'et cases'),
#    (0.0, 'strategy - innovation'),
#    (0.0, 'hrm'),
#    (0.0, 'analytics'),
#    (0.0, 'business-intellegence features in depth'),
#    (0.0, 'timesshiksha')]},
#  {'id': 14,
#   'programName': 'cbt nuggets cloud computing',
#   'similarities': [(0.0, 'adwords essential training'),
#    (0.0, 'microsoft dynamics crm customization config'),
#    (0.0, 'time management'),
#    (0.0, 'project management fundamentals'),
#    (0.0, 'yammer 2018 essential training'),
#    (0.0, 'email communication'),
#    (0.0, 'google drive essential training tutorial'),
#    (0.0, 'analytics essential training'),
#    (0.0, 'creating a business plan'),
#    (0.0, 'sales secrets for small business'),
#    (0.0, 'cbt nuggets microsoft sharepoint'),
#    (0.0, 'cbt nuggets - mpls fundamentals'),
#    (0.0, 'cbt nuggets cloud computing'),
#    (0.0, 'powerful speaking'),
#    (0.0, 'microsoft powerpoint'),
#    (0.0, 'microsoft excel'),
#    (0.0, 'microsoft word'),
#    (0.0, 'google cloud platform fundamentals'),
#    (0.0, 'marketing with facebook and twitter'),
#    (0.0, 'html'),
#    (0.0, 'microsoft office 365'),
#    (0.0, 'tpl - learning management system'),
#    (0.0, 'stress management at workplace'),
#    (0.0, 'campusnexus crm'),
#    (0.0, 'leadership'),
#    (0.0, 'helpful technique while operating computers'),
#    (0.0, 'microsoft onedrive'),
#    (0.0, 'microsoft sharepoint'),
#    (0.0, 'excel 2016 pivot tables in depth'),
#    (0.0, 'techniques and concepts of big data'),
#    (0.0, 'complete beginners introduction to sql'),
#    (0.0, 'sample'),
#    (0.0, 'et cases'),
#    (0.0, 'strategy - innovation'),
#    (0.0, 'hrm'),
#    (0.0, 'analytics'),
#    (0.0, 'business-intellegence features in depth'),
#    (0.0, 'timesshiksha')]},
#  {'id': 15,
#   'programName': 'cbt nuggets - mpls fundamentals',
#   'similarities': [(0.0, 'adwords essential training'),
#    (0.0, 'microsoft dynamics crm customization config'),
#    (0.0, 'time management'),
#    (0.0, 'project management fundamentals'),
#    (0.0, 'yammer 2018 essential training'),
#    (0.0, 'email communication'),
#    (0.0, 'google drive essential training tutorial'),
#    (0.0, 'analytics essential training'),
#    (0.0, 'creating a business plan'),
#    (0.0, 'sales secrets for small business'),
#    (0.0, 'cbt nuggets microsoft sharepoint'),
#    (0.0, 'cbt nuggets - mpls fundamentals'),
#    (0.0, 'cbt nuggets cloud computing'),
#    (0.0, 'powerful speaking'),
#    (0.0, 'microsoft powerpoint'),
#    (0.0, 'microsoft excel'),
#    (0.0, 'microsoft word'),
#    (0.0, 'google cloud platform fundamentals'),
#    (0.0, 'marketing with facebook and twitter'),
#    (0.0, 'html'),
#    (0.0, 'microsoft office 365'),
#    (0.0, 'tpl - learning management system'),
#    (0.0, 'stress management at workplace'),
#    (0.0, 'campusnexus crm'),
#    (0.0, 'leadership'),
#    (0.0, 'helpful technique while operating computers'),
#    (0.0, 'microsoft onedrive'),
#    (0.0, 'microsoft sharepoint'),
#    (0.0, 'excel 2016 pivot tables in depth'),
#    (0.0, 'techniques and concepts of big data'),
#    (0.0, 'complete beginners introduction to sql'),
#    (0.0, 'sample'),
#    (0.0, 'et cases'),
#    (0.0, 'strategy - innovation'),
#    (0.0, 'hrm'),
#    (0.0, 'analytics'),
#    (0.0, 'business-intellegence features in depth'),
#    (0.0, 'timesshiksha')]},
#  {'id': 16,
#   'programName': 'cbt nuggets microsoft sharepoint',
#   'similarities': [(0.0, 'adwords essential training'),
#    (0.0, 'microsoft dynamics crm customization config'),
#    (0.0, 'time management'),
#    (0.0, 'project management fundamentals'),
#    (0.0, 'yammer 2018 essential training'),
#    (0.0, 'email communication'),
#    (0.0, 'google drive essential training tutorial'),
#    (0.0, 'analytics essential training'),
#    (0.0, 'creating a business plan'),
#    (0.0, 'sales secrets for small business'),
#    (0.0, 'cbt nuggets microsoft sharepoint'),
#    (0.0, 'cbt nuggets - mpls fundamentals'),
#    (0.0, 'cbt nuggets cloud computing'),
#    (0.0, 'powerful speaking'),
#    (0.0, 'microsoft powerpoint'),
#    (0.0, 'microsoft excel'),
#    (0.0, 'microsoft word'),
#    (0.0, 'google cloud platform fundamentals'),
#    (0.0, 'marketing with facebook and twitter'),
#    (0.0, 'html'),
#    (0.0, 'microsoft office 365'),
#    (0.0, 'tpl - learning management system'),
#    (0.0, 'stress management at workplace'),
#    (0.0, 'campusnexus crm'),
#    (0.0, 'leadership'),
#    (0.0, 'helpful technique while operating computers'),
#    (0.0, 'microsoft onedrive'),
#    (0.0, 'microsoft sharepoint'),
#    (0.0, 'excel 2016 pivot tables in depth'),
#    (0.0, 'techniques and concepts of big data'),
#    (0.0, 'complete beginners introduction to sql'),
#    (0.0, 'sample'),
#    (0.0, 'et cases'),
#    (0.0, 'strategy - innovation'),
#    (0.0, 'hrm'),
#    (0.0, 'analytics'),
#    (0.0, 'business-intellegence features in depth'),
#    (0.0, 'timesshiksha')]},
#  {'id': 18,
#   'programName': 'creating a business plan',
#   'similarities': [(0.02647230395290067,
#     'marketing with facebook and twitter'),
#    (0.02180262192988628, 'microsoft dynamics crm customization config'),
#    (0.015401507971672149, 'sales secrets for small business'),
#    (0.008423218296821636, 'business-intellegence features in depth'),
#    (0.008095618556061801, 'stress management at workplace'),
#    (0.007200180450852355, 'techniques and concepts of big data'),
#    (0.007152740148527754, 'google drive essential training tutorial'),
#    (0.007100236990320576, 'complete beginners introduction to sql'),
#    (0.0, 'cbt nuggets microsoft sharepoint'),
#    (0.0, 'cbt nuggets - mpls fundamentals'),
#    (0.0, 'cbt nuggets cloud computing'),
#    (0.0, 'adwords essential training'),
#    (0.0, 'analytics essential training'),
#    (0.0, 'powerful speaking'),
#    (0.0, 'email communication'),
#    (0.0, 'yammer 2018 essential training'),
#    (0.0, 'microsoft powerpoint'),
#    (0.0, 'microsoft excel'),
#    (0.0, 'project management fundamentals'),
#    (0.0, 'microsoft word'),
#    (0.0, 'time management'),
#    (0.0, 'cloud computing'),
#    (0.0, 'google cloud platform fundamentals'),
#    (0.0, 'html'),
#    (0.0, 'analytics'),
#    (0.0, 'hrm'),
#    (0.0, 'strategy - innovation'),
#    (0.0, 'et cases'),
#    (0.0, 'sample'),
#    (0.0, 'excel 2016 pivot tables in depth'),
#    (0.0, 'microsoft office 365'),
#    (0.0, 'microsoft sharepoint'),
#    (0.0, 'microsoft onedrive'),
#    (0.0, 'helpful technique while operating computers'),
#    (0.0, 'leadership'),
#    (0.0, 'campusnexus crm'),
#    (0.0, 'tpl - learning management system'),
#    (0.0, 'timesshiksha')]},
#  {'id': 19,
#   'programName': 'adwords essential training',
#   'similarities': [(0.03322282414315095, 'html'),
#    (0.02746619832949375, 'analytics essential training'),
#    (0.01700748313126698, 'google drive essential training tutorial'),
#    (0.009824760196299064, 'time management'),
#    (0.009705381638094415, 'email communication'),
#    (0.00866641125700674, 'sales secrets for small business'),
#    (0.008653767852678577, 'yammer 2018 essential training'),
#    (0.008594931151104705, 'microsoft powerpoint'),
#    (0.0, 'google cloud platform fundamentals'),
#    (0.0, 'microsoft dynamics crm customization config'),
#    (0.0, 'project management fundamentals'),
#    (0.0, 'microsoft word'),
#    (0.0, 'microsoft excel'),
#    (0.0, 'creating a business plan'),
#    (0.0, 'cbt nuggets microsoft sharepoint'),
#    (0.0, 'cbt nuggets - mpls fundamentals'),
#    (0.0, 'cbt nuggets cloud computing'),
#    (0.0, 'powerful speaking'),
#    (0.0, 'cloud computing'),
#    (0.0, 'marketing with facebook and twitter'),
#    (0.0, 'techniques and concepts of big data'),
#    (0.0, 'business-intellegence features in depth'),
#    (0.0, 'tpl - learning management system'),
#    (0.0, 'stress management at workplace'),
#    (0.0, 'campusnexus crm'),
#    (0.0, 'leadership'),
#    (0.0, 'helpful technique while operating computers'),
#    (0.0, 'microsoft onedrive'),
#    (0.0, 'microsoft sharepoint'),
#    (0.0, 'microsoft office 365'),
#    (0.0, 'excel 2016 pivot tables in depth'),
#    (0.0, 'complete beginners introduction to sql'),
#    (0.0, 'sample'),
#    (0.0, 'et cases'),
#    (0.0, 'strategy - innovation'),
#    (0.0, 'hrm'),
#    (0.0, 'analytics'),
#    (0.0, 'timesshiksha')]},
#  {'id': 20,
#   'programName': 'analytics essential training',
#   'similarities': [(0.02746619832949375, 'adwords essential training'),
#    (0.019303039584758017, 'yammer 2018 essential training'),
#    (0.0189683919021663, 'google drive essential training tutorial'),
#    (0.012958731906235867, 'microsoft sharepoint'),
#    (0.011344940233265304, 'powerful speaking'),
#    (0.01082438130619209, 'email communication'),
#    (0.009964413061433083, 'html'),
#    (0.009528713457019795, 'marketing with facebook and twitter'),
#    (0.009042967601286497, 'microsoft dynamics crm customization config'),
#    (0.0, 'cbt nuggets microsoft sharepoint'),
#    (0.0, 'google cloud platform fundamentals'),
#    (0.0, 'cbt nuggets - mpls fundamentals'),
#    (0.0, 'cbt nuggets cloud computing'),
#    (0.0, 'microsoft powerpoint'),
#    (0.0, 'microsoft excel'),
#    (0.0, 'microsoft word'),
#    (0.0, 'project management fundamentals'),
#    (0.0, 'time management'),
#    (0.0, 'creating a business plan'),
#    (0.0, 'cloud computing'),
#    (0.0, 'sales secrets for small business'),
#    (0.0, 'techniques and concepts of big data'),
#    (0.0, 'tpl - learning management system'),
#    (0.0, 'stress management at workplace'),
#    (0.0, 'campusnexus crm'),
#    (0.0, 'leadership'),
#    (0.0, 'helpful technique while operating computers'),
#    (0.0, 'microsoft onedrive'),
#    (0.0, 'microsoft office 365'),
#    (0.0, 'excel 2016 pivot tables in depth'),
#    (0.0, 'complete beginners introduction to sql'),
#    (0.0, 'sample'),
#    (0.0, 'et cases'),
#    (0.0, 'strategy - innovation'),
#    (0.0, 'hrm'),
#    (0.0, 'analytics'),
#    (0.0, 'business-intellegence features in depth'),
#    (0.0, 'timesshiksha')]},
#  {'id': 21,
#   'programName': 'google drive essential training tutorial',
#   'similarities': [(0.05463013118332469, 'microsoft onedrive'),
#    (0.027582446929493496, 'yammer 2018 essential training'),
#    (0.01949927972959015, 'stress management at workplace'),
#    (0.0189683919021663, 'analytics essential training'),
#    (0.01700748313126698, 'adwords essential training'),
#    (0.010954319869803079, 'microsoft word'),
#    (0.00943577156386661, 'microsoft dynamics crm customization config'),
#    (0.009028231931821977, 'cloud computing'),
#    (0.008648787722924583, 'microsoft sharepoint'),
#    (0.008579125199100479, 'microsoft excel'),
#    (0.00824185748203897, 'microsoft office 365'),
#    (0.0073585069473527335, 'microsoft powerpoint'),
#    (0.007152740148527754, 'creating a business plan'),
#    (0.006391868747117867, 'techniques and concepts of big data'),
#    (0.006303145209393716, 'complete beginners introduction to sql'),
#    (0.006048754541627474, 'sales secrets for small business'),
#    (0.0, 'cbt nuggets cloud computing'),
#    (0.0, 'project management fundamentals'),
#    (0.0, 'cbt nuggets - mpls fundamentals'),
#    (0.0, 'cbt nuggets microsoft sharepoint'),
#    (0.0, 'powerful speaking'),
#    (0.0, 'email communication'),
#    (0.0, 'marketing with facebook and twitter'),
#    (0.0, 'time management'),
#    (0.0, 'google cloud platform fundamentals'),
#    (0.0, 'html'),
#    (0.0, 'business-intellegence features in depth'),
#    (0.0, 'analytics'),
#    (0.0, 'hrm'),
#    (0.0, 'strategy - innovation'),
#    (0.0, 'et cases'),
#    (0.0, 'sample'),
#    (0.0, 'excel 2016 pivot tables in depth'),
#    (0.0, 'helpful technique while operating computers'),
#    (0.0, 'leadership'),
#    (0.0, 'campusnexus crm'),
#    (0.0, 'tpl - learning management system'),
#    (0.0, 'timesshiksha')]},
#  {'id': 22,
#   'programName': 'email communication',
#   'similarities': [(0.037730790874581796, 'yammer 2018 essential training'),
#    (0.015057705090207216, 'cloud computing'),
#    (0.0124404182327976, 'microsoft excel'),
#    (0.011091761809252731, 'html'),
#    (0.01082438130619209, 'analytics essential training'),
#    (0.009705381638094415, 'adwords essential training'),
#    (0.008023605011608571, 'microsoft office 365'),
#    (0.007986523142247922, 'microsoft dynamics crm customization config'),
#    (0.00784549323917507, 'microsoft word'),
#    (0.0062283074181738955, 'microsoft powerpoint'),
#    (0.0, 'powerful speaking'),
#    (0.0, 'cbt nuggets cloud computing'),
#    (0.0, 'cbt nuggets - mpls fundamentals'),
#    (0.0, 'cbt nuggets microsoft sharepoint'),
#    (0.0, 'google cloud platform fundamentals'),
#    (0.0, 'google drive essential training tutorial'),
#    (0.0, 'project management fundamentals'),
#    (0.0, 'time management'),
#    (0.0, 'creating a business plan'),
#    (0.0, 'marketing with facebook and twitter'),
#    (0.0, 'sales secrets for small business'),
#    (0.0, 'techniques and concepts of big data'),
#    (0.0, 'tpl - learning management system'),
#    (0.0, 'stress management at workplace'),
#    (0.0, 'campusnexus crm'),
#    (0.0, 'leadership'),
#    (0.0, 'helpful technique while operating computers'),
#    (0.0, 'microsoft onedrive'),
#    (0.0, 'microsoft sharepoint'),
#    (0.0, 'excel 2016 pivot tables in depth'),
#    (0.0, 'complete beginners introduction to sql'),
#    (0.0, 'sample'),
#    (0.0, 'et cases'),
#    (0.0, 'strategy - innovation'),
#    (0.0, 'hrm'),
#    (0.0, 'analytics'),
#    (0.0, 'business-intellegence features in depth'),
#    (0.0, 'timesshiksha')]},
#  {'id': 23,
#   'programName': 'yammer 2018 essential training',
#   'similarities': [(0.037730790874581796, 'email communication'),
#    (0.02829658642249245, 'microsoft dynamics crm customization config'),
#    (0.027582446929493496, 'google drive essential training tutorial'),
#    (0.02654244516009299, 'microsoft office 365'),
#    (0.019303039584758017, 'analytics essential training'),
#    (0.019221927049358892, 'html'),
#    (0.019157505044844696, 'microsoft powerpoint'),
#    (0.01830944787908185, 'microsoft onedrive'),
#    (0.01713636386917567, 'microsoft word'),
#    (0.011260136305227993, 'powerful speaking'),
#    (0.009457485904147559, 'marketing with facebook and twitter'),
#    (0.008653767852678577, 'adwords essential training'),
#    (0.0069930550139616875, 'techniques and concepts of big data'),
#    (0.006895986597058094, 'complete beginners introduction to sql'),
#    (0.0064908203217044136, 'business-intellegence features in depth'),
#    (0.0, 'creating a business plan'),
#    (0.0, 'time management'),
#    (0.0, 'cbt nuggets microsoft sharepoint'),
#    (0.0, 'cbt nuggets - mpls fundamentals'),
#    (0.0, 'cbt nuggets cloud computing'),
#    (0.0, 'microsoft excel'),
#    (0.0, 'project management fundamentals'),
#    (0.0, 'cloud computing'),
#    (0.0, 'google cloud platform fundamentals'),
#    (0.0, 'sales secrets for small business'),
#    (0.0, 'analytics'),
#    (0.0, 'hrm'),
#    (0.0, 'strategy - innovation'),
#    (0.0, 'et cases'),
#    (0.0, 'sample'),
#    (0.0, 'excel 2016 pivot tables in depth'),
#    (0.0, 'microsoft sharepoint'),
#    (0.0, 'helpful technique while operating computers'),
#    (0.0, 'leadership'),
#    (0.0, 'campusnexus crm'),
#    (0.0, 'stress management at workplace'),
#    (0.0, 'tpl - learning management system'),
#    (0.0, 'timesshiksha')]},
#  {'id': 24,
#   'programName': 'project management fundamentals',
#   'similarities': [(0.017599377235525272, 'time management'),
#    (0.006375714575306797, 'stress management at workplace'),
#    (0.006354699761002589, 'cloud computing'),
#    (0.006087620443390566, 'microsoft sharepoint'),
#    (0.005774383754429558, 'microsoft dynamics crm customization config'),
#    (0.005591800571362515, 'complete beginners introduction to sql'),
#    (0.0, 'powerful speaking'),
#    (0.0, 'cbt nuggets cloud computing'),
#    (0.0, 'microsoft powerpoint'),
#    (0.0, 'cbt nuggets - mpls fundamentals'),
#    (0.0, 'google cloud platform fundamentals'),
#    (0.0, 'creating a business plan'),
#    (0.0, 'adwords essential training'),
#    (0.0, 'analytics essential training'),
#    (0.0, 'google drive essential training tutorial'),
#    (0.0, 'email communication'),
#    (0.0, 'yammer 2018 essential training'),
#    (0.0, 'microsoft excel'),
#    (0.0, 'microsoft word'),
#    (0.0, 'cbt nuggets microsoft sharepoint'),
#    (0.0, 'marketing with facebook and twitter'),
#    (0.0, 'sales secrets for small business'),
#    (0.0, 'excel 2016 pivot tables in depth'),
#    (0.0, 'tpl - learning management system'),
#    (0.0, 'campusnexus crm'),
#    (0.0, 'leadership'),
#    (0.0, 'helpful technique while operating computers'),
#    (0.0, 'microsoft onedrive'),
#    (0.0, 'microsoft office 365'),
#    (0.0, 'sample'),
#    (0.0, 'html'),
#    (0.0, 'et cases'),
#    (0.0, 'strategy - innovation'),
#    (0.0, 'hrm'),
#    (0.0, 'analytics'),
#    (0.0, 'business-intellegence features in depth'),
#    (0.0, 'techniques and concepts of big data'),
#    (0.0, 'timesshiksha')]},
#  {'id': 25,
#   'programName': 'time management',
#   'similarities': [(0.03185145074872411, 'sales secrets for small business'),
#    (0.023426541611360707, 'marketing with facebook and twitter'),
#    (0.017599377235525272, 'project management fundamentals'),
#    (0.01655131547531532, 'microsoft dynamics crm customization config'),
#    (0.011825818192667504, 'techniques and concepts of big data'),
#    (0.009824760196299064, 'adwords essential training'),
#    (0.009391326004291317, 'microsoft powerpoint'),
#    (0.007023898961253048, 'stress management at workplace'),
#    (0.00700074768454221, 'cloud computing'),
#    (0.0067065158585422205, 'microsoft sharepoint'),
#    (0.006160288664245515, 'complete beginners introduction to sql'),
#    (0.0, 'excel 2016 pivot tables in depth'),
#    (0.0, 'email communication'),
#    (0.0, 'microsoft word'),
#    (0.0, 'microsoft excel'),
#    (0.0, 'tpl - learning management system'),
#    (0.0, 'powerful speaking'),
#    (0.0, 'cbt nuggets cloud computing'),
#    (0.0, 'cbt nuggets - mpls fundamentals'),
#    (0.0, 'cbt nuggets microsoft sharepoint'),
#    (0.0, 'creating a business plan'),
#    (0.0, 'campusnexus crm'),
#    (0.0, 'analytics essential training'),
#    (0.0, 'google drive essential training tutorial'),
#    (0.0, 'leadership'),
#    (0.0, 'yammer 2018 essential training'),
#    (0.0, 'helpful technique while operating computers'),
#    (0.0, 'microsoft onedrive'),
#    (0.0, 'google cloud platform fundamentals'),
#    (0.0, 'html'),
#    (0.0, 'microsoft office 365'),
#    (0.0, 'business-intellegence features in depth'),
#    (0.0, 'analytics'),
#    (0.0, 'hrm'),
#    (0.0, 'strategy - innovation'),
#    (0.0, 'et cases'),
#    (0.0, 'sample'),
#    (0.0, 'timesshiksha')]},
#  {'id': 26,
#   'programName': 'microsoft dynamics crm customization config',
#   'similarities': [(0.03109789353265017,
#     'marketing with facebook and twitter'),
#    (0.02829658642249245, 'yammer 2018 essential training'),
#    (0.02180262192988628, 'creating a business plan'),
#    (0.021660635907515383, 'microsoft powerpoint'),
#    (0.019288356466714653, 'stress management at workplace'),
#    (0.01778329404525629, 'microsoft word'),
#    (0.01655131547531532, 'time management'),
#    (0.014449397244906799, 'business-intellegence features in depth'),
#    (0.013055212637363308, 'complete beginners introduction to sql'),
#    (0.010550156864895957, 'powerful speaking'),
#    (0.00943577156386661, 'google drive essential training tutorial'),
#    (0.009042967601286497, 'analytics essential training'),
#    (0.007986523142247922, 'email communication'),
#    (0.007814880827471584, 'sales secrets for small business'),
#    (0.007280328955481258, 'excel 2016 pivot tables in depth'),
#    (0.006767407101504312, 'microsoft excel'),
#    (0.00670312677584537, 'microsoft office 365'),
#    (0.006645185070856205, 'cloud computing'),
#    (0.00636589705397437, 'microsoft sharepoint'),
#    (0.005774383754429558, 'project management fundamentals'),
#    (0.0, 'html'),
#    (0.0, 'microsoft onedrive'),
#    (0.0, 'tpl - learning management system'),
#    (0.0, 'campusnexus crm'),
#    (0.0, 'leadership'),
#    (0.0, 'helpful technique while operating computers'),
#    (0.0, 'cbt nuggets cloud computing'),
#    (0.0, 'cbt nuggets - mpls fundamentals'),
#    (0.0, 'cbt nuggets microsoft sharepoint'),
#    (0.0, 'adwords essential training'),
#    (0.0, 'techniques and concepts of big data'),
#    (0.0, 'sample'),
#    (0.0, 'et cases'),
#    (0.0, 'strategy - innovation'),
#    (0.0, 'hrm'),
#    (0.0, 'analytics'),
#    (0.0, 'google cloud platform fundamentals'),
#    (0.0, 'timesshiksha')]},
#  {'id': 27,
#   'programName': 'google cloud platform fundamentals',
#   'similarities': [(0.0, 'adwords essential training'),
#    (0.0, 'microsoft dynamics crm customization config'),
#    (0.0, 'time management'),
#    (0.0, 'project management fundamentals'),
#    (0.0, 'yammer 2018 essential training'),
#    (0.0, 'email communication'),
#    (0.0, 'google drive essential training tutorial'),
#    (0.0, 'analytics essential training'),
#    (0.0, 'creating a business plan'),
#    (0.0, 'sales secrets for small business'),
#    (0.0, 'cbt nuggets microsoft sharepoint'),
#    (0.0, 'cbt nuggets - mpls fundamentals'),
#    (0.0, 'cbt nuggets cloud computing'),
#    (0.0, 'powerful speaking'),
#    (0.0, 'microsoft powerpoint'),
#    (0.0, 'microsoft excel'),
#    (0.0, 'microsoft word'),
#    (0.0, 'google cloud platform fundamentals'),
#    (0.0, 'marketing with facebook and twitter'),
#    (0.0, 'html'),
#    (0.0, 'microsoft office 365'),
#    (0.0, 'tpl - learning management system'),
#    (0.0, 'stress management at workplace'),
#    (0.0, 'campusnexus crm'),
#    (0.0, 'leadership'),
#    (0.0, 'helpful technique while operating computers'),
#    (0.0, 'microsoft onedrive'),
#    (0.0, 'microsoft sharepoint'),
#    (0.0, 'excel 2016 pivot tables in depth'),
#    (0.0, 'techniques and concepts of big data'),
#    (0.0, 'complete beginners introduction to sql'),
#    (0.0, 'sample'),
#    (0.0, 'et cases'),
#    (0.0, 'strategy - innovation'),
#    (0.0, 'hrm'),
#    (0.0, 'analytics'),
#    (0.0, 'business-intellegence features in depth'),
#    (0.0, 'timesshiksha')]},
#  {'id': 29,
#   'programName': 'sales secrets for small business',
#   'similarities': [(0.03185145074872411, 'time management'),
#    (0.015401507971672149, 'creating a business plan'),
#    (0.011193225633634214, 'marketing with facebook and twitter'),
#    (0.010078151888990885, 'microsoft onedrive'),
#    (0.009804232396579958, 'powerful speaking'),
#    (0.00866641125700674, 'adwords essential training'),
#    (0.007814880827471584, 'microsoft dynamics crm customization config'),
#    (0.007123141463276355, 'business-intellegence features in depth'),
#    (0.006846104918035031, 'stress management at workplace'),
#    (0.006088872697492702, 'techniques and concepts of big data'),
#    (0.006048754541627474, 'google drive essential training tutorial'),
#    (0.006004354953489098, 'complete beginners introduction to sql'),
#    (0.0, 'cbt nuggets cloud computing'),
#    (0.0, 'cbt nuggets - mpls fundamentals'),
#    (0.0, 'cbt nuggets microsoft sharepoint'),
#    (0.0, 'microsoft powerpoint'),
#    (0.0, 'microsoft excel'),
#    (0.0, 'analytics essential training'),
#    (0.0, 'email communication'),
#    (0.0, 'yammer 2018 essential training'),
#    (0.0, 'microsoft word'),
#    (0.0, 'project management fundamentals'),
#    (0.0, 'cloud computing'),
#    (0.0, 'google cloud platform fundamentals'),
#    (0.0, 'html'),
#    (0.0, 'analytics'),
#    (0.0, 'hrm'),
#    (0.0, 'strategy - innovation'),
#    (0.0, 'et cases'),
#    (0.0, 'sample'),
#    (0.0, 'excel 2016 pivot tables in depth'),
#    (0.0, 'microsoft office 365'),
#    (0.0, 'microsoft sharepoint'),
#    (0.0, 'helpful technique while operating computers'),
#    (0.0, 'leadership'),
#    (0.0, 'campusnexus crm'),
#    (0.0, 'tpl - learning management system'),
#    (0.0, 'timesshiksha')]},
#  {'id': 30,
#   'programName': 'marketing with facebook and twitter',
#   'similarities': [(0.03109789353265017,
#     'microsoft dynamics crm customization config'),
#    (0.02647230395290067, 'creating a business plan'),
#    (0.023426541611360707, 'time management'),
#    (0.02332795157904411, 'complete beginners introduction to sql'),
#    (0.011193225633634214, 'sales secrets for small business'),
#    (0.009968948764524173, 'excel 2016 pivot tables in depth'),
#    (0.009528713457019795, 'analytics essential training'),
#    (0.009457485904147559, 'yammer 2018 essential training'),
#    (0.00794817393062047, 'microsoft powerpoint'),
#    (0.0, 'cbt nuggets cloud computing'),
#    (0.0, 'cbt nuggets - mpls fundamentals'),
#    (0.0, 'cbt nuggets microsoft sharepoint'),
#    (0.0, 'powerful speaking'),
#    (0.0, 'google cloud platform fundamentals'),
#    (0.0, 'adwords essential training'),
#    (0.0, 'google drive essential training tutorial'),
#    (0.0, 'email communication'),
#    (0.0, 'project management fundamentals'),
#    (0.0, 'microsoft excel'),
#    (0.0, 'microsoft word'),
#    (0.0, 'cloud computing'),
#    (0.0, 'html'),
#    (0.0, 'microsoft sharepoint'),
#    (0.0, 'tpl - learning management system'),
#    (0.0, 'stress management at workplace'),
#    (0.0, 'campusnexus crm'),
#    (0.0, 'leadership'),
#    (0.0, 'helpful technique while operating computers'),
#    (0.0, 'microsoft onedrive'),
#    (0.0, 'microsoft office 365'),
#    (0.0, 'techniques and concepts of big data'),
#    (0.0, 'sample'),
#    (0.0, 'et cases'),
#    (0.0, 'strategy - innovation'),
#    (0.0, 'hrm'),
#    (0.0, 'analytics'),
#    (0.0, 'business-intellegence features in depth'),
#    (0.0, 'timesshiksha')]},
#  {'id': 31,
#   'programName': 'techniques and concepts of big data',
#   'similarities': [(0.012689901205177052,
#     'complete beginners introduction to sql'),
#    (0.011834114779026425, 'microsoft sharepoint'),
#    (0.011825818192667504, 'time management'),
#    (0.010452922843046, 'cloud computing'),
#    (0.009011504099177827, 'microsoft onedrive'),
#    (0.007234448639620971, 'stress management at workplace'),
#    (0.007219763334626501, 'html'),
#    (0.007200180450852355, 'creating a business plan'),
#    (0.0069930550139616875, 'yammer 2018 essential training'),
#    (0.006391868747117867, 'google drive essential training tutorial'),
#    (0.006088872697492702, 'sales secrets for small business'),
#    (0.005972159854408911, 'business-intellegence features in depth'),
#    (0.005109689380715637, 'microsoft powerpoint'),
#    (0.0, 'email communication'),
#    (0.0, 'microsoft word'),
#    (0.0, 'adwords essential training'),
#    (0.0, 'analytics essential training'),
#    (0.0, 'powerful speaking'),
#    (0.0, 'project management fundamentals'),
#    (0.0, 'cbt nuggets - mpls fundamentals'),
#    (0.0, 'cbt nuggets cloud computing'),
#    (0.0, 'microsoft excel'),
#    (0.0, 'cbt nuggets microsoft sharepoint'),
#    (0.0, 'marketing with facebook and twitter'),
#    (0.0, 'microsoft dynamics crm customization config'),
#    (0.0, 'google cloud platform fundamentals'),
#    (0.0, 'analytics'),
#    (0.0, 'hrm'),
#    (0.0, 'strategy - innovation'),
#    (0.0, 'et cases'),
#    (0.0, 'sample'),
#    (0.0, 'excel 2016 pivot tables in depth'),
#    (0.0, 'microsoft office 365'),
#    (0.0, 'helpful technique while operating computers'),
#    (0.0, 'leadership'),
#    (0.0, 'campusnexus crm'),
#    (0.0, 'tpl - learning management system'),
#    (0.0, 'timesshiksha')]},
#  {'id': 32,
#   'programName': 'business-intellegence features in depth',
#   'similarities': [(0.014449397244906799,
#     'microsoft dynamics crm customization config'),
#    (0.012868004592484016, 'microsoft powerpoint'),
#    (0.012459059251997608, 'complete beginners introduction to sql'),
#    (0.011504022416499298, 'stress management at workplace'),
#    (0.010467387023083464, 'microsoft office 365'),
#    (0.008423218296821636, 'creating a business plan'),
#    (0.007123141463276355, 'sales secrets for small business'),
#    (0.006701246662113969, 'html'),
#    (0.006635905805086771, 'excel 2016 pivot tables in depth'),
#    (0.0064908203217044136, 'yammer 2018 essential training'),
#    (0.006168385569507459, 'microsoft excel'),
#    (0.005972159854408911, 'techniques and concepts of big data'),
#    (0.0, 'google drive essential training tutorial'),
#    (0.0, 'email communication'),
#    (0.0, 'cloud computing'),
#    (0.0, 'analytics essential training'),
#    (0.0, 'adwords essential training'),
#    (0.0, 'project management fundamentals'),
#    (0.0, 'cbt nuggets - mpls fundamentals'),
#    (0.0, 'cbt nuggets cloud computing'),
#    (0.0, 'powerful speaking'),
#    (0.0, 'microsoft word'),
#    (0.0, 'cbt nuggets microsoft sharepoint'),
#    (0.0, 'marketing with facebook and twitter'),
#    (0.0, 'time management'),
#    (0.0, 'google cloud platform fundamentals'),
#    (0.0, 'analytics'),
#    (0.0, 'hrm'),
#    (0.0, 'strategy - innovation'),
#    (0.0, 'et cases'),
#    (0.0, 'sample'),
#    (0.0, 'microsoft sharepoint'),
#    (0.0, 'microsoft onedrive'),
#    (0.0, 'helpful technique while operating computers'),
#    (0.0, 'leadership'),
#    (0.0, 'campusnexus crm'),
#    (0.0, 'tpl - learning management system'),
#    (0.0, 'timesshiksha')]},
#  {'id': 34,
#   'programName': 'analytics',
#   'similarities': [(0.0, 'adwords essential training'),
#    (0.0, 'microsoft dynamics crm customization config'),
#    (0.0, 'time management'),
#    (0.0, 'project management fundamentals'),
#    (0.0, 'yammer 2018 essential training'),
#    (0.0, 'email communication'),
#    (0.0, 'google drive essential training tutorial'),
#    (0.0, 'analytics essential training'),
#    (0.0, 'creating a business plan'),
#    (0.0, 'sales secrets for small business'),
#    (0.0, 'cbt nuggets microsoft sharepoint'),
#    (0.0, 'cbt nuggets - mpls fundamentals'),
#    (0.0, 'cbt nuggets cloud computing'),
#    (0.0, 'powerful speaking'),
#    (0.0, 'microsoft powerpoint'),
#    (0.0, 'microsoft excel'),
#    (0.0, 'microsoft word'),
#    (0.0, 'google cloud platform fundamentals'),
#    (0.0, 'marketing with facebook and twitter'),
#    (0.0, 'html'),
#    (0.0, 'microsoft office 365'),
#    (0.0, 'tpl - learning management system'),
#    (0.0, 'stress management at workplace'),
#    (0.0, 'campusnexus crm'),
#    (0.0, 'leadership'),
#    (0.0, 'helpful technique while operating computers'),
#    (0.0, 'microsoft onedrive'),
#    (0.0, 'microsoft sharepoint'),
#    (0.0, 'excel 2016 pivot tables in depth'),
#    (0.0, 'techniques and concepts of big data'),
#    (0.0, 'complete beginners introduction to sql'),
#    (0.0, 'sample'),
#    (0.0, 'et cases'),
#    (0.0, 'strategy - innovation'),
#    (0.0, 'hrm'),
#    (0.0, 'analytics'),
#    (0.0, 'business-intellegence features in depth'),
#    (0.0, 'timesshiksha')]},
#  {'id': 35,
#   'programName': 'hrm',
#   'similarities': [(0.0, 'adwords essential training'),
#    (0.0, 'microsoft dynamics crm customization config'),
#    (0.0, 'time management'),
#    (0.0, 'project management fundamentals'),
#    (0.0, 'yammer 2018 essential training'),
#    (0.0, 'email communication'),
#    (0.0, 'google drive essential training tutorial'),
#    (0.0, 'analytics essential training'),
#    (0.0, 'creating a business plan'),
#    (0.0, 'sales secrets for small business'),
#    (0.0, 'cbt nuggets microsoft sharepoint'),
#    (0.0, 'cbt nuggets - mpls fundamentals'),
#    (0.0, 'cbt nuggets cloud computing'),
#    (0.0, 'powerful speaking'),
#    (0.0, 'microsoft powerpoint'),
#    (0.0, 'microsoft excel'),
#    (0.0, 'microsoft word'),
#    (0.0, 'google cloud platform fundamentals'),
#    (0.0, 'marketing with facebook and twitter'),
#    (0.0, 'html'),
#    (0.0, 'microsoft office 365'),
#    (0.0, 'tpl - learning management system'),
#    (0.0, 'stress management at workplace'),
#    (0.0, 'campusnexus crm'),
#    (0.0, 'leadership'),
#    (0.0, 'helpful technique while operating computers'),
#    (0.0, 'microsoft onedrive'),
#    (0.0, 'microsoft sharepoint'),
#    (0.0, 'excel 2016 pivot tables in depth'),
#    (0.0, 'techniques and concepts of big data'),
#    (0.0, 'complete beginners introduction to sql'),
#    (0.0, 'sample'),
#    (0.0, 'et cases'),
#    (0.0, 'strategy - innovation'),
#    (0.0, 'hrm'),
#    (0.0, 'analytics'),
#    (0.0, 'business-intellegence features in depth'),
#    (0.0, 'timesshiksha')]},
#  {'id': 36,
#   'programName': 'strategy - innovation',
#   'similarities': [(0.0, 'adwords essential training'),
#    (0.0, 'microsoft dynamics crm customization config'),
#    (0.0, 'time management'),
#    (0.0, 'project management fundamentals'),
#    (0.0, 'yammer 2018 essential training'),
#    (0.0, 'email communication'),
#    (0.0, 'google drive essential training tutorial'),
#    (0.0, 'analytics essential training'),
#    (0.0, 'creating a business plan'),
#    (0.0, 'sales secrets for small business'),
#    (0.0, 'cbt nuggets microsoft sharepoint'),
#    (0.0, 'cbt nuggets - mpls fundamentals'),
#    (0.0, 'cbt nuggets cloud computing'),
#    (0.0, 'powerful speaking'),
#    (0.0, 'microsoft powerpoint'),
#    (0.0, 'microsoft excel'),
#    (0.0, 'microsoft word'),
#    (0.0, 'google cloud platform fundamentals'),
#    (0.0, 'marketing with facebook and twitter'),
#    (0.0, 'html'),
#    (0.0, 'microsoft office 365'),
#    (0.0, 'tpl - learning management system'),
#    (0.0, 'stress management at workplace'),
#    (0.0, 'campusnexus crm'),
#    (0.0, 'leadership'),
#    (0.0, 'helpful technique while operating computers'),
#    (0.0, 'microsoft onedrive'),
#    (0.0, 'microsoft sharepoint'),
#    (0.0, 'excel 2016 pivot tables in depth'),
#    (0.0, 'techniques and concepts of big data'),
#    (0.0, 'complete beginners introduction to sql'),
#    (0.0, 'sample'),
#    (0.0, 'et cases'),
#    (0.0, 'strategy - innovation'),
#    (0.0, 'hrm'),
#    (0.0, 'analytics'),
#    (0.0, 'business-intellegence features in depth'),
#    (0.0, 'timesshiksha')]},
#  {'id': 38,
#   'programName': 'et cases',
#   'similarities': [(0.0, 'adwords essential training'),
#    (0.0, 'microsoft dynamics crm customization config'),
#    (0.0, 'time management'),
#    (0.0, 'project management fundamentals'),
#    (0.0, 'yammer 2018 essential training'),
#    (0.0, 'email communication'),
#    (0.0, 'google drive essential training tutorial'),
#    (0.0, 'analytics essential training'),
#    (0.0, 'creating a business plan'),
#    (0.0, 'sales secrets for small business'),
#    (0.0, 'cbt nuggets microsoft sharepoint'),
#    (0.0, 'cbt nuggets - mpls fundamentals'),
#    (0.0, 'cbt nuggets cloud computing'),
#    (0.0, 'powerful speaking'),
#    (0.0, 'microsoft powerpoint'),
#    (0.0, 'microsoft excel'),
#    (0.0, 'microsoft word'),
#    (0.0, 'google cloud platform fundamentals'),
#    (0.0, 'marketing with facebook and twitter'),
#    (0.0, 'html'),
#    (0.0, 'microsoft office 365'),
#    (0.0, 'tpl - learning management system'),
#    (0.0, 'stress management at workplace'),
#    (0.0, 'campusnexus crm'),
#    (0.0, 'leadership'),
#    (0.0, 'helpful technique while operating computers'),
#    (0.0, 'microsoft onedrive'),
#    (0.0, 'microsoft sharepoint'),
#    (0.0, 'excel 2016 pivot tables in depth'),
#    (0.0, 'techniques and concepts of big data'),
#    (0.0, 'complete beginners introduction to sql'),
#    (0.0, 'sample'),
#    (0.0, 'et cases'),
#    (0.0, 'strategy - innovation'),
#    (0.0, 'hrm'),
#    (0.0, 'analytics'),
#    (0.0, 'business-intellegence features in depth'),
#    (0.0, 'timesshiksha')]},
#  {'id': 39,
#   'programName': 'sample',
#   'similarities': [(0.0, 'adwords essential training'),
#    (0.0, 'microsoft dynamics crm customization config'),
#    (0.0, 'time management'),
#    (0.0, 'project management fundamentals'),
#    (0.0, 'yammer 2018 essential training'),
#    (0.0, 'email communication'),
#    (0.0, 'google drive essential training tutorial'),
#    (0.0, 'analytics essential training'),
#    (0.0, 'creating a business plan'),
#    (0.0, 'sales secrets for small business'),
#    (0.0, 'cbt nuggets microsoft sharepoint'),
#    (0.0, 'cbt nuggets - mpls fundamentals'),
#    (0.0, 'cbt nuggets cloud computing'),
#    (0.0, 'powerful speaking'),
#    (0.0, 'microsoft powerpoint'),
#    (0.0, 'microsoft excel'),
#    (0.0, 'microsoft word'),
#    (0.0, 'google cloud platform fundamentals'),
#    (0.0, 'marketing with facebook and twitter'),
#    (0.0, 'html'),
#    (0.0, 'microsoft office 365'),
#    (0.0, 'tpl - learning management system'),
#    (0.0, 'stress management at workplace'),
#    (0.0, 'campusnexus crm'),
#    (0.0, 'leadership'),
#    (0.0, 'helpful technique while operating computers'),
#    (0.0, 'microsoft onedrive'),
#    (0.0, 'microsoft sharepoint'),
#    (0.0, 'excel 2016 pivot tables in depth'),
#    (0.0, 'techniques and concepts of big data'),
#    (0.0, 'complete beginners introduction to sql'),
#    (0.0, 'sample'),
#    (0.0, 'et cases'),
#    (0.0, 'strategy - innovation'),
#    (0.0, 'hrm'),
#    (0.0, 'analytics'),
#    (0.0, 'business-intellegence features in depth'),
#    (0.0, 'timesshiksha')]},
#  {'id': 41,
#   'programName': 'complete beginners introduction to sql',
#   'similarities': [(0.02332795157904411,
#     'marketing with facebook and twitter'),
#    (0.013671243818585678, 'microsoft powerpoint'),
#    (0.013590377678593609, 'stress management at workplace'),
#    (0.013055212637363308, 'microsoft dynamics crm customization config'),
#    (0.012689901205177052, 'techniques and concepts of big data'),
#    (0.012459059251997608, 'business-intellegence features in depth'),
#    (0.007119548050189065, 'html'),
#    (0.007100236990320576, 'creating a business plan'),
#    (0.007050128523539538, 'excel 2016 pivot tables in depth'),
#    (0.006895986597058094, 'yammer 2018 essential training'),
#    (0.006553425007093747, 'microsoft excel'),
#    (0.00643506757712784, 'cloud computing'),
#    (0.006303145209393716, 'google drive essential training tutorial'),
#    (0.006164610510401622, 'microsoft sharepoint'),
#    (0.006160288664245515, 'time management'),
#    (0.006004354953489098, 'sales secrets for small business'),
#    (0.005591800571362515, 'project management fundamentals'),
#    (0.0, 'et cases'),
#    (0.0, 'adwords essential training'),
#    (0.0, 'microsoft word'),
#    (0.0, 'tpl - learning management system'),
#    (0.0, 'campusnexus crm'),
#    (0.0, 'powerful speaking'),
#    (0.0, 'cbt nuggets cloud computing'),
#    (0.0, 'cbt nuggets - mpls fundamentals'),
#    (0.0, 'cbt nuggets microsoft sharepoint'),
#    (0.0, 'leadership'),
#    (0.0, 'email communication'),
#    (0.0, 'analytics essential training'),
#    (0.0, 'strategy - innovation'),
#    (0.0, 'helpful technique while operating computers'),
#    (0.0, 'microsoft onedrive'),
#    (0.0, 'google cloud platform fundamentals'),
#    (0.0, 'microsoft office 365'),
#    (0.0, 'sample'),
#    (0.0, 'analytics'),
#    (0.0, 'hrm'),
#    (0.0, 'timesshiksha')]},
#  {'id': 42,
#   'programName': 'excel 2016 pivot tables in depth',
#   'similarities': [(0.016785065984257837, 'microsoft excel'),
#    (0.01609733997202804, 'microsoft powerpoint'),
#    (0.009968948764524173, 'marketing with facebook and twitter'),
#    (0.007280328955481258, 'microsoft dynamics crm customization config'),
#    (0.007050128523539538, 'complete beginners introduction to sql'),
#    (0.006635905805086771, 'business-intellegence features in depth'),
#    (0.0, 'analytics essential training'),
#    (0.0, 'time management'),
#    (0.0, 'project management fundamentals'),
#    (0.0, 'yammer 2018 essential training'),
#    (0.0, 'email communication'),
#    (0.0, 'google drive essential training tutorial'),
#    (0.0, 'microsoft word'),
#    (0.0, 'powerful speaking'),
#    (0.0, 'google cloud platform fundamentals'),
#    (0.0, 'creating a business plan'),
#    (0.0, 'cbt nuggets microsoft sharepoint'),
#    (0.0, 'cbt nuggets - mpls fundamentals'),
#    (0.0, 'cbt nuggets cloud computing'),
#    (0.0, 'adwords essential training'),
#    (0.0, 'cloud computing'),
#    (0.0, 'sales secrets for small business'),
#    (0.0, 'microsoft sharepoint'),
#    (0.0, 'tpl - learning management system'),
#    (0.0, 'stress management at workplace'),
#    (0.0, 'campusnexus crm'),
#    (0.0, 'leadership'),
#    (0.0, 'helpful technique while operating computers'),
#    (0.0, 'microsoft onedrive'),
#    (0.0, 'microsoft office 365'),
#    (0.0, 'html'),
#    (0.0, 'sample'),
#    (0.0, 'et cases'),
#    (0.0, 'strategy - innovation'),
#    (0.0, 'hrm'),
#    (0.0, 'analytics'),
#    (0.0, 'techniques and concepts of big data'),
#    (0.0, 'timesshiksha')]},
#  {'id': 43,
#   'programName': 'microsoft office 365',
#   'similarities': [(0.02654244516009299, 'yammer 2018 essential training'),
#    (0.017865862864608957, 'microsoft word'),
#    (0.012679796866727917, 'stress management at workplace'),
#    (0.010707407169730813, 'html'),
#    (0.010467387023083464, 'business-intellegence features in depth'),
#    (0.010441302062703255, 'microsoft excel'),
#    (0.00824185748203897, 'google drive essential training tutorial'),
#    (0.008023605011608571, 'email communication'),
#    (0.008015459045266854, 'microsoft onedrive'),
#    (0.00670312677584537, 'microsoft dynamics crm customization config'),
#    (0.0052274479744645035, 'microsoft powerpoint'),
#    (0.0, 'cloud computing'),
#    (0.0, 'project management fundamentals'),
#    (0.0, 'cbt nuggets microsoft sharepoint'),
#    (0.0, 'analytics essential training'),
#    (0.0, 'adwords essential training'),
#    (0.0, 'creating a business plan'),
#    (0.0, 'cbt nuggets - mpls fundamentals'),
#    (0.0, 'cbt nuggets cloud computing'),
#    (0.0, 'powerful speaking'),
#    (0.0, 'time management'),
#    (0.0, 'marketing with facebook and twitter'),
#    (0.0, 'google cloud platform fundamentals'),
#    (0.0, 'sales secrets for small business'),
#    (0.0, 'techniques and concepts of big data'),
#    (0.0, 'analytics'),
#    (0.0, 'hrm'),
#    (0.0, 'strategy - innovation'),
#    (0.0, 'et cases'),
#    (0.0, 'sample'),
#    (0.0, 'complete beginners introduction to sql'),
#    (0.0, 'excel 2016 pivot tables in depth'),
#    (0.0, 'microsoft sharepoint'),
#    (0.0, 'helpful technique while operating computers'),
#    (0.0, 'leadership'),
#    (0.0, 'campusnexus crm'),
#    (0.0, 'tpl - learning management system'),
#    (0.0, 'timesshiksha')]},
#  {'id': 44,
#   'programName': 'microsoft sharepoint',
#   'similarities': [(0.030024257494909633, 'cloud computing'),
#    (0.020334670873944447, 'stress management at workplace'),
#    (0.012958731906235867, 'analytics essential training'),
#    (0.011838091921246225, 'microsoft word'),
#    (0.011834114779026425, 'techniques and concepts of big data'),
#    (0.010956826818232531, 'microsoft excel'),
#    (0.009411423986220894, 'powerful speaking'),
#    (0.008648787722924583, 'google drive essential training tutorial'),
#    (0.008411211178473151, 'microsoft onedrive'),
#    (0.007952176189963365, 'microsoft powerpoint'),
#    (0.0067065158585422205, 'time management'),
#    (0.00636589705397437, 'microsoft dynamics crm customization config'),
#    (0.006164610510401622, 'complete beginners introduction to sql'),
#    (0.006087620443390566, 'project management fundamentals'),
#    (0.0, 'cbt nuggets microsoft sharepoint'),
#    (0.0, 'creating a business plan'),
#    (0.0, 'adwords essential training'),
#    (0.0, 'cbt nuggets - mpls fundamentals'),
#    (0.0, 'email communication'),
#    (0.0, 'cbt nuggets cloud computing'),
#    (0.0, 'yammer 2018 essential training'),
#    (0.0, 'marketing with facebook and twitter'),
#    (0.0, 'google cloud platform fundamentals'),
#    (0.0, 'sales secrets for small business'),
#    (0.0, 'html'),
#    (0.0, 'business-intellegence features in depth'),
#    (0.0, 'analytics'),
#    (0.0, 'hrm'),
#    (0.0, 'strategy - innovation'),
#    (0.0, 'et cases'),
#    (0.0, 'sample'),
#    (0.0, 'excel 2016 pivot tables in depth'),
#    (0.0, 'microsoft office 365'),
#    (0.0, 'helpful technique while operating computers'),
#    (0.0, 'leadership'),
#    (0.0, 'campusnexus crm'),
#    (0.0, 'tpl - learning management system'),
#    (0.0, 'timesshiksha')]},
#  {'id': 45,
#   'programName': 'microsoft onedrive',
#   'similarities': [(0.05463013118332469,
#     'google drive essential training tutorial'),
#    (0.01887904019433679, 'cloud computing'),
#    (0.01830944787908185, 'yammer 2018 essential training'),
#    (0.011949974174841156, 'html'),
#    (0.010078151888990885, 'sales secrets for small business'),
#    (0.009011504099177827, 'techniques and concepts of big data'),
#    (0.008411211178473151, 'microsoft sharepoint'),
#    (0.008343462238635394, 'microsoft excel'),
#    (0.008015459045266854, 'microsoft office 365'),
#    (0.0, 'adwords essential training'),
#    (0.0, 'email communication'),
#    (0.0, 'analytics essential training'),
#    (0.0, 'cbt nuggets microsoft sharepoint'),
#    (0.0, 'creating a business plan'),
#    (0.0, 'time management'),
#    (0.0, 'cbt nuggets - mpls fundamentals'),
#    (0.0, 'cbt nuggets cloud computing'),
#    (0.0, 'powerful speaking'),
#    (0.0, 'microsoft powerpoint'),
#    (0.0, 'microsoft word'),
#    (0.0, 'project management fundamentals'),
#    (0.0, 'marketing with facebook and twitter'),
#    (0.0, 'microsoft dynamics crm customization config'),
#    (0.0, 'google cloud platform fundamentals'),
#    (0.0, 'business-intellegence features in depth'),
#    (0.0, 'analytics'),
#    (0.0, 'hrm'),
#    (0.0, 'strategy - innovation'),
#    (0.0, 'et cases'),
#    (0.0, 'sample'),
#    (0.0, 'complete beginners introduction to sql'),
#    (0.0, 'excel 2016 pivot tables in depth'),
#    (0.0, 'helpful technique while operating computers'),
#    (0.0, 'leadership'),
#    (0.0, 'campusnexus crm'),
#    (0.0, 'stress management at workplace'),
#    (0.0, 'tpl - learning management system'),
#    (0.0, 'timesshiksha')]},
#  {'id': 46,
#   'programName': 'helpful technique while operating computers',
#   'similarities': [(0.0, 'adwords essential training'),
#    (0.0, 'microsoft dynamics crm customization config'),
#    (0.0, 'time management'),
#    (0.0, 'project management fundamentals'),
#    (0.0, 'yammer 2018 essential training'),
#    (0.0, 'email communication'),
#    (0.0, 'google drive essential training tutorial'),
#    (0.0, 'analytics essential training'),
#    (0.0, 'creating a business plan'),
#    (0.0, 'sales secrets for small business'),
#    (0.0, 'cbt nuggets microsoft sharepoint'),
#    (0.0, 'cbt nuggets - mpls fundamentals'),
#    (0.0, 'cbt nuggets cloud computing'),
#    (0.0, 'powerful speaking'),
#    (0.0, 'microsoft powerpoint'),
#    (0.0, 'microsoft excel'),
#    (0.0, 'microsoft word'),
#    (0.0, 'google cloud platform fundamentals'),
#    (0.0, 'marketing with facebook and twitter'),
#    (0.0, 'html'),
#    (0.0, 'microsoft office 365'),
#    (0.0, 'tpl - learning management system'),
#    (0.0, 'stress management at workplace'),
#    (0.0, 'campusnexus crm'),
#    (0.0, 'leadership'),
#    (0.0, 'helpful technique while operating computers'),
#    (0.0, 'microsoft onedrive'),
#    (0.0, 'microsoft sharepoint'),
#    (0.0, 'excel 2016 pivot tables in depth'),
#    (0.0, 'techniques and concepts of big data'),
#    (0.0, 'complete beginners introduction to sql'),
#    (0.0, 'sample'),
#    (0.0, 'et cases'),
#    (0.0, 'strategy - innovation'),
#    (0.0, 'hrm'),
#    (0.0, 'analytics'),
#    (0.0, 'business-intellegence features in depth'),
#    (0.0, 'timesshiksha')]},
#  {'id': 47,
#   'programName': 'leadership',
#   'similarities': [(0.0, 'adwords essential training'),
#    (0.0, 'microsoft dynamics crm customization config'),
#    (0.0, 'time management'),
#    (0.0, 'project management fundamentals'),
#    (0.0, 'yammer 2018 essential training'),
#    (0.0, 'email communication'),
#    (0.0, 'google drive essential training tutorial'),
#    (0.0, 'analytics essential training'),
#    (0.0, 'creating a business plan'),
#    (0.0, 'sales secrets for small business'),
#    (0.0, 'cbt nuggets microsoft sharepoint'),
#    (0.0, 'cbt nuggets - mpls fundamentals'),
#    (0.0, 'cbt nuggets cloud computing'),
#    (0.0, 'powerful speaking'),
#    (0.0, 'microsoft powerpoint'),
#    (0.0, 'microsoft excel'),
#    (0.0, 'microsoft word'),
#    (0.0, 'google cloud platform fundamentals'),
#    (0.0, 'marketing with facebook and twitter'),
#    (0.0, 'html'),
#    (0.0, 'microsoft office 365'),
#    (0.0, 'tpl - learning management system'),
#    (0.0, 'stress management at workplace'),
#    (0.0, 'campusnexus crm'),
#    (0.0, 'leadership'),
#    (0.0, 'helpful technique while operating computers'),
#    (0.0, 'microsoft onedrive'),
#    (0.0, 'microsoft sharepoint'),
#    (0.0, 'excel 2016 pivot tables in depth'),
#    (0.0, 'techniques and concepts of big data'),
#    (0.0, 'complete beginners introduction to sql'),
#    (0.0, 'sample'),
#    (0.0, 'et cases'),
#    (0.0, 'strategy - innovation'),
#    (0.0, 'hrm'),
#    (0.0, 'analytics'),
#    (0.0, 'business-intellegence features in depth'),
#    (0.0, 'timesshiksha')]},
#  {'id': 48,
#   'programName': 'campusnexus crm',
#   'similarities': [(0.0, 'adwords essential training'),
#    (0.0, 'microsoft dynamics crm customization config'),
#    (0.0, 'time management'),
#    (0.0, 'project management fundamentals'),
#    (0.0, 'yammer 2018 essential training'),
#    (0.0, 'email communication'),
#    (0.0, 'google drive essential training tutorial'),
#    (0.0, 'analytics essential training'),
#    (0.0, 'creating a business plan'),
#    (0.0, 'sales secrets for small business'),
#    (0.0, 'cbt nuggets microsoft sharepoint'),
#    (0.0, 'cbt nuggets - mpls fundamentals'),
#    (0.0, 'cbt nuggets cloud computing'),
#    (0.0, 'powerful speaking'),
#    (0.0, 'microsoft powerpoint'),
#    (0.0, 'microsoft excel'),
#    (0.0, 'microsoft word'),
#    (0.0, 'google cloud platform fundamentals'),
#    (0.0, 'marketing with facebook and twitter'),
#    (0.0, 'html'),
#    (0.0, 'microsoft office 365'),
#    (0.0, 'tpl - learning management system'),
#    (0.0, 'stress management at workplace'),
#    (0.0, 'campusnexus crm'),
#    (0.0, 'leadership'),
#    (0.0, 'helpful technique while operating computers'),
#    (0.0, 'microsoft onedrive'),
#    (0.0, 'microsoft sharepoint'),
#    (0.0, 'excel 2016 pivot tables in depth'),
#    (0.0, 'techniques and concepts of big data'),
#    (0.0, 'complete beginners introduction to sql'),
#    (0.0, 'sample'),
#    (0.0, 'et cases'),
#    (0.0, 'strategy - innovation'),
#    (0.0, 'hrm'),
#    (0.0, 'analytics'),
#    (0.0, 'business-intellegence features in depth'),
#    (0.0, 'timesshiksha')]},
#  {'id': 49,
#   'programName': 'stress management at workplace',
#   'similarities': [(0.020334670873944447, 'microsoft sharepoint'),
#    (0.01949927972959015, 'google drive essential training tutorial'),
#    (0.019288356466714653, 'microsoft dynamics crm customization config'),
#    (0.013590377678593609, 'complete beginners introduction to sql'),
#    (0.012679796866727917, 'microsoft office 365'),
#    (0.011504022416499298, 'business-intellegence features in depth'),
#    (0.008095618556061801, 'creating a business plan'),
#    (0.00733719910447041, 'cloud computing'),
#    (0.007234448639620971, 'techniques and concepts of big data'),
#    (0.007023898961253048, 'time management'),
#    (0.006846104918035031, 'sales secrets for small business'),
#    (0.006375714575306797, 'project management fundamentals'),
#    (0.0, 'cbt nuggets - mpls fundamentals'),
#    (0.0, 'cbt nuggets cloud computing'),
#    (0.0, 'adwords essential training'),
#    (0.0, 'analytics essential training'),
#    (0.0, 'powerful speaking'),
#    (0.0, 'microsoft powerpoint'),
#    (0.0, 'microsoft excel'),
#    (0.0, 'email communication'),
#    (0.0, 'yammer 2018 essential training'),
#    (0.0, 'microsoft word'),
#    (0.0, 'cbt nuggets microsoft sharepoint'),
#    (0.0, 'marketing with facebook and twitter'),
#    (0.0, 'google cloud platform fundamentals'),
#    (0.0, 'html'),
#    (0.0, 'analytics'),
#    (0.0, 'hrm'),
#    (0.0, 'strategy - innovation'),
#    (0.0, 'et cases'),
#    (0.0, 'sample'),
#    (0.0, 'excel 2016 pivot tables in depth'),
#    (0.0, 'microsoft onedrive'),
#    (0.0, 'helpful technique while operating computers'),
#    (0.0, 'leadership'),
#    (0.0, 'campusnexus crm'),
#    (0.0, 'tpl - learning management system'),
#    (0.0, 'timesshiksha')]},
#  {'id': 50,
#   'programName': 'tpl - learning management system',
#   'similarities': [(0.0, 'adwords essential training'),
#    (0.0, 'microsoft dynamics crm customization config'),
#    (0.0, 'time management'),
#    (0.0, 'project management fundamentals'),
#    (0.0, 'yammer 2018 essential training'),
#    (0.0, 'email communication'),
#    (0.0, 'google drive essential training tutorial'),
#    (0.0, 'analytics essential training'),
#    (0.0, 'creating a business plan'),
#    (0.0, 'sales secrets for small business'),
#    (0.0, 'cbt nuggets microsoft sharepoint'),
#    (0.0, 'cbt nuggets - mpls fundamentals'),
#    (0.0, 'cbt nuggets cloud computing'),
#    (0.0, 'powerful speaking'),
#    (0.0, 'microsoft powerpoint'),
#    (0.0, 'microsoft excel'),
#    (0.0, 'microsoft word'),
#    (0.0, 'google cloud platform fundamentals'),
#    (0.0, 'marketing with facebook and twitter'),
#    (0.0, 'html'),
#    (0.0, 'microsoft office 365'),
#    (0.0, 'tpl - learning management system'),
#    (0.0, 'stress management at workplace'),
#    (0.0, 'campusnexus crm'),
#    (0.0, 'leadership'),
#    (0.0, 'helpful technique while operating computers'),
#    (0.0, 'microsoft onedrive'),
#    (0.0, 'microsoft sharepoint'),
#    (0.0, 'excel 2016 pivot tables in depth'),
#    (0.0, 'techniques and concepts of big data'),
#    (0.0, 'complete beginners introduction to sql'),
#    (0.0, 'sample'),
#    (0.0, 'et cases'),
#    (0.0, 'strategy - innovation'),
#    (0.0, 'hrm'),
#    (0.0, 'analytics'),
#    (0.0, 'business-intellegence features in depth'),
#    (0.0, 'timesshiksha')]},
#  {'id': 51,
#   'programName': 'html',
#   'similarities': [(0.03322282414315095, 'adwords essential training'),
#    (0.019221927049358892, 'yammer 2018 essential training'),
#    (0.011949974174841156, 'microsoft onedrive'),
#    (0.011091761809252731, 'email communication'),
#    (0.010707407169730813, 'microsoft office 365'),
#    (0.009964413061433083, 'analytics essential training'),
#    (0.007219763334626501, 'techniques and concepts of big data'),
#    (0.007119548050189065, 'complete beginners introduction to sql'),
#    (0.006701246662113969, 'business-intellegence features in depth'),
#    (0.005733484993989474, 'microsoft powerpoint'),
#    (0.0, 'google drive essential training tutorial'),
#    (0.0, 'cloud computing'),
#    (0.0, 'creating a business plan'),
#    (0.0, 'time management'),
#    (0.0, 'cbt nuggets microsoft sharepoint'),
#    (0.0, 'cbt nuggets - mpls fundamentals'),
#    (0.0, 'cbt nuggets cloud computing'),
#    (0.0, 'powerful speaking'),
#    (0.0, 'microsoft excel'),
#    (0.0, 'microsoft word'),
#    (0.0, 'project management fundamentals'),
#    (0.0, 'marketing with facebook and twitter'),
#    (0.0, 'microsoft dynamics crm customization config'),
#    (0.0, 'google cloud platform fundamentals'),
#    (0.0, 'sales secrets for small business'),
#    (0.0, 'analytics'),
#    (0.0, 'hrm'),
#    (0.0, 'strategy - innovation'),
#    (0.0, 'et cases'),
#    (0.0, 'sample'),
#    (0.0, 'excel 2016 pivot tables in depth'),
#    (0.0, 'microsoft sharepoint'),
#    (0.0, 'helpful technique while operating computers'),
#    (0.0, 'leadership'),
#    (0.0, 'campusnexus crm'),
#    (0.0, 'stress management at workplace'),
#    (0.0, 'tpl - learning management system'),
#    (0.0, 'timesshiksha')]},
#  {'id': 52,
#   'programName': 'cloud computing',
#   'similarities': [(0.030024257494909633, 'microsoft sharepoint'),
#    (0.01887904019433679, 'microsoft onedrive'),
#    (0.015057705090207216, 'email communication'),
#    (0.010452922843046, 'techniques and concepts of big data'),
#    (0.009028231931821977, 'google drive essential training tutorial'),
#    (0.00733719910447041, 'stress management at workplace'),
#    (0.00700074768454221, 'time management'),
#    (0.006645185070856205, 'microsoft dynamics crm customization config'),
#    (0.00643506757712784, 'complete beginners introduction to sql'),
#    (0.006354699761002589, 'project management fundamentals'),
#    (0.0, 'powerful speaking'),
#    (0.0, 'cbt nuggets cloud computing'),
#    (0.0, 'cbt nuggets - mpls fundamentals'),
#    (0.0, 'cbt nuggets microsoft sharepoint'),
#    (0.0, 'creating a business plan'),
#    (0.0, 'adwords essential training'),
#    (0.0, 'analytics essential training'),
#    (0.0, 'microsoft powerpoint'),
#    (0.0, 'microsoft excel'),
#    (0.0, 'microsoft word'),
#    (0.0, 'yammer 2018 essential training'),
#    (0.0, 'marketing with facebook and twitter'),
#    (0.0, 'google cloud platform fundamentals'),
#    (0.0, 'sales secrets for small business'),
#    (0.0, 'html'),
#    (0.0, 'business-intellegence features in depth'),
#    (0.0, 'analytics'),
#    (0.0, 'hrm'),
#    (0.0, 'strategy - innovation'),
#    (0.0, 'et cases'),
#    (0.0, 'sample'),
#    (0.0, 'excel 2016 pivot tables in depth'),
#    (0.0, 'microsoft office 365'),
#    (0.0, 'helpful technique while operating computers'),
#    (0.0, 'leadership'),
#    (0.0, 'campusnexus crm'),
#    (0.0, 'tpl - learning management system'),
#    (0.0, 'timesshiksha')]}]

# %%
for i in corr:
    if i['programName'] == 'timesshiksha':
        i['id']
# Out:
# 1

# %%
def getRecommendations(userData, corr=corr):
    recommendations = []
    
    print(userData['skills'])
    for i in userData['skills']:
        for j in corr:
            
            if i.strip() in j['programName'].strip():
                for k in j['similarities']:
                    
                    if k[0] > 0:
                        if k[1] not in recommendations:
                            for l in corr:
                                if l['programName'] == k[1]:
                                    recommendations.append(dict({'id': l['id'], 'courseName': k[1]}))
                    else:
                        break       
                
    return recommendations

# %%
userData = {
#     'aoi': 'finance',
    'skills': ['microsoft', 'cloud']
}

# %%
getRecommendations(userData)
# Out:
# ['microsoft', 'cloud']
# [{'id': 8, 'courseName': 'microsoft powerpoint'},
#  {'id': 43, 'courseName': 'microsoft office 365'},
#  {'id': 26, 'courseName': 'microsoft dynamics crm customization config'},
#  {'id': 23, 'courseName': 'yammer 2018 essential training'},
#  {'id': 44, 'courseName': 'microsoft sharepoint'},
#  {'id': 21, 'courseName': 'google drive essential training tutorial'},
#  {'id': 22, 'courseName': 'email communication'},
#  {'id': 42, 'courseName': 'excel 2016 pivot tables in depth'},
#  {'id': 22, 'courseName': 'email communication'},
#  {'id': 44, 'courseName': 'microsoft sharepoint'},
#  {'id': 43, 'courseName': 'microsoft office 365'},
#  {'id': 21, 'courseName': 'google drive essential training tutorial'},
#  {'id': 45, 'courseName': 'microsoft onedrive'},
#  {'id': 26, 'courseName': 'microsoft dynamics crm customization config'},
#  {'id': 41, 'courseName': 'complete beginners introduction to sql'},
#  {'id': 32, 'courseName': 'business-intellegence features in depth'},
#  {'id': 1, 'courseName': 'timesshiksha'},
#  {'id': 26, 'courseName': 'microsoft dynamics crm customization config'},
#  {'id': 6, 'courseName': 'microsoft word'},
#  {'id': 23, 'courseName': 'yammer 2018 essential training'},
#  {'id': 42, 'courseName': 'excel 2016 pivot tables in depth'},
#  {'id': 41, 'courseName': 'complete beginners introduction to sql'},
#  {'id': 32, 'courseName': 'business-intellegence features in depth'},
#  {'id': 25, 'courseName': 'time management'},
#  {'id': 19, 'courseName': 'adwords essential training'},
#  {'id': 44, 'courseName': 'microsoft sharepoint'},
#  {'id': 30, 'courseName': 'marketing with facebook and twitter'},
#  {'id': 21, 'courseName': 'google drive essential training tutorial'},
#  {'id': 12, 'courseName': 'powerful speaking'},
#  {'id': 22, 'courseName': 'email communication'},
#  {'id': 51, 'courseName': 'html'},
#  {'id': 43, 'courseName': 'microsoft office 365'},
#  {'id': 31, 'courseName': 'techniques and concepts of big data'},
#  {'id': 30, 'courseName': 'marketing with facebook and twitter'},
#  {'id': 23, 'courseName': 'yammer 2018 essential training'},
#  {'id': 18, 'courseName': 'creating a business plan'},
#  {'id': 8, 'courseName': 'microsoft powerpoint'},
#  {'id': 49, 'courseName': 'stress management at workplace'},
#  {'id': 6, 'courseName': 'microsoft word'},
#  {'id': 25, 'courseName': 'time management'},
#  {'id': 32, 'courseName': 'business-intellegence features in depth'},
#  {'id': 41, 'courseName': 'complete beginners introduction to sql'},
#  {'id': 12, 'courseName': 'powerful speaking'},
#  {'id': 21, 'courseName': 'google drive essential training tutorial'},
#  {'id': 20, 'courseName': 'analytics essential training'},
#  {'id': 22, 'courseName': 'email communication'},
#  {'id': 29, 'courseName': 'sales secrets for small business'},
#  {'id': 42, 'courseName': 'excel 2016 pivot tables in depth'},
#  {'id': 7, 'courseName': 'microsoft excel'},
#  {'id': 43, 'courseName': 'microsoft office 365'},
#  {'id': 52, 'courseName': 'cloud computing'},
#  {'id': 44, 'courseName': 'microsoft sharepoint'},
#  {'id': 24, 'courseName': 'project management fundamentals'},
#  {'id': 23, 'courseName': 'yammer 2018 essential training'},
#  {'id': 6, 'courseName': 'microsoft word'},
#  {'id': 49, 'courseName': 'stress management at workplace'},
#  {'id': 51, 'courseName': 'html'},
#  {'id': 32, 'courseName': 'business-intellegence features in depth'},
#  {'id': 7, 'courseName': 'microsoft excel'},
#  {'id': 21, 'courseName': 'google drive essential training tutorial'},
#  {'id': 22, 'courseName': 'email communication'},
#  {'id': 45, 'courseName': 'microsoft onedrive'},
#  {'id': 26, 'courseName': 'microsoft dynamics crm customization config'},
#  {'id': 8, 'courseName': 'microsoft powerpoint'},
#  {'id': 52, 'courseName': 'cloud computing'},
#  {'id': 49, 'courseName': 'stress management at workplace'},
#  {'id': 20, 'courseName': 'analytics essential training'},
#  {'id': 6, 'courseName': 'microsoft word'},
#  {'id': 31, 'courseName': 'techniques and concepts of big data'},
#  {'id': 7, 'courseName': 'microsoft excel'},
#  {'id': 12, 'courseName': 'powerful speaking'},
#  {'id': 21, 'courseName': 'google drive essential training tutorial'},
#  {'id': 45, 'courseName': 'microsoft onedrive'},
#  {'id': 8, 'courseName': 'microsoft powerpoint'},
#  {'id': 25, 'courseName': 'time management'},
#  {'id': 26, 'courseName': 'microsoft dynamics crm customization config'},
#  {'id': 41, 'courseName': 'complete beginners introduction to sql'},
#  {'id': 24, 'courseName': 'project management fundamentals'},
#  {'id': 21, 'courseName': 'google drive essential training tutorial'},
#  {'id': 52, 'courseName': 'cloud computing'},
#  {'id': 23, 'courseName': 'yammer 2018 essential training'},
#  {'id': 51, 'courseName': 'html'},
#  {'id': 29, 'courseName': 'sales secrets for small business'},
#  {'id': 31, 'courseName': 'techniques and concepts of big data'},
#  {'id': 44, 'courseName': 'microsoft sharepoint'},
#  {'id': 7, 'courseName': 'microsoft excel'},
#  {'id': 43, 'courseName': 'microsoft office 365'},
#  {'id': 44, 'courseName': 'microsoft sharepoint'},
#  {'id': 45, 'courseName': 'microsoft onedrive'},
#  {'id': 22, 'courseName': 'email communication'},
#  {'id': 31, 'courseName': 'techniques and concepts of big data'},
#  {'id': 21, 'courseName': 'google drive essential training tutorial'},
#  {'id': 49, 'courseName': 'stress management at workplace'},
#  {'id': 25, 'courseName': 'time management'},
#  {'id': 26, 'courseName': 'microsoft dynamics crm customization config'},
#  {'id': 41, 'courseName': 'complete beginners introduction to sql'},
#  {'id': 24, 'courseName': 'project management fundamentals'}]

# %%
a = 'a, v,v, c'
list(pd.Series(a.split(',')).apply(lambda x: x.strip()))
# Out:
# ['a', 'v', 'v', 'c']

# %%
a = ['<a dsa>Hello, wow</a>', '<p><h1>Nope,                        "", kil</h1></p>']

# %%
import re
import string

def cleanHtml(sentence):
    cleanr = re.compile('<.*?>|&([a-z0-9]+|#[0-9]{1,6}|#x[0-9a-f]{1,6});')
    cleantext = re.sub(cleanr, '',sentence)
    return cleantext

# %%
for i in a:
    print(cleanHtml(i).translate(str.maketrans('', '', string.punctuation)))
# Out:
# Hello wow
# Nope                         kil
